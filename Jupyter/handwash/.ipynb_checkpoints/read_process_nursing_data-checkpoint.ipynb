# %%
import numpy as np
import pickle
import os

# %%
src_folder = "C:/Users/mm5gg/Box Sync/PublicData/nursing/labelled/Labelled/"
dest_folder = "C:/ASM/DevData/handwash/nursing_data/"

# %%
label_files = os.listdir(src_folder+"labels/")
sensor_files = os.listdir(src_folder+"sensors/")
print(len(label_files))
print(len(sensor_files))
# Out:
# 54
# 118

# %%
gt = []
nidix = 0
senix = 0
for f in label_files:
    nidix+=1
    print(nidix, ": ", f)
    nid = int(f[1:4])
    day_date = int(f[5:13])    
    labels = np.genfromtxt(src_folder+"labels_processed/"+f, delimiter=",")
    labels_hw = labels[labels[:,0]==39, 1:]
    
    sensor_data_times=[]
    sensor_data = []
    for sf in sensor_files:
        if sf[:13] == f[:13]:
            senix += 1
            print("      >> ", senix, ": ", sf)            
            h = int(sf[14:16])
            m = int(sf[16:18])
            s = int(sf[18:20])
            t = h*60*60+m*60+s
            d = np.genfromtxt(src_folder+"sensors/"+sf, delimiter=",", skip_header=1)           
            d[:, 0] = d[:, 0] + t
            print("data type: ", d.dtype)
            print(d.shape)
            #print(d[:10, :])
            sensor_data.append(d)
            
            h = int(sf[21:23])
            m = int(sf[23:25])
            s = int(sf[25:27])
            t2 = h*60*60+m*60+s
            sensor_data_times.append([t, t2])
            
    gt.append([nid, day_date, labels, labels_hw, sensor_data_times])
            
    with open(dest_folder+str(nid)+"_"+ str(day_date)+".pkl", "wb") as file:
        pickle.dump(sensor_data, file,  pickle.HIGHEST_PROTOCOL)
        print("Saved data for id ", nid, ", ", day_date)

with open(dest_folder+"meta_data.pkl", "wb") as file:
    pickle.dump(gt, file,  pickle.HIGHEST_PROTOCOL)
# Out:
# 1 :  N013_20140217.csv
#       >>  1 :  N013_20140217_081011-081201.csv
# data type:  float64
# (2198, 10)
# Saved data for id  13 ,  20140217
# 2 :  N013_20140224.csv
#       >>  2 :  N013_20140224_084602-111038.csv
# data type:  float64
# (173513, 10)
#       >>  3 :  N013_20140224_133248-181707.csv
# data type:  float64
# (341182, 10)
# Saved data for id  13 ,  20140224
# 3 :  N014_20140210.csv
#       >>  4 :  N014_20140210_081824-082136.csv
# data type:  float64
# (3853, 10)
#       >>  5 :  N014_20140210_084417-112824.csv
# data type:  float64
# (196942, 10)
#       >>  6 :  N014_20140210_122456-161137.csv
# data type:  float64
# (272016, 10)
#       >>  7 :  N014_20140210_202534-202819.csv
# data type:  float64
# (3292, 10)
# Saved data for id  14 ,  20140210
# 4 :  N027_20140214.csv
#       >>  8 :  N027_20140214_082849-165240.csv
# data type:  float64
# (604623, 10)
#       >>  9 :  N027_20140214_191611-192200.csv
# data type:  float64
# (6974, 10)
# Saved data for id  27 ,  20140214
# 5 :  N027_20140218.csv
#       >>  10 :  N027_20140218_084003-115725.csv
# data type:  float64
# (236829, 10)
#       >>  11 :  N027_20140218_205953-210043.csv
# data type:  float64
# (1001, 10)
# Saved data for id  27 ,  20140218
# 6 :  N027_20140226.csv
#       >>  12 :  N027_20140226_085042-165159.csv
# data type:  float64
# (577547, 10)
# Saved data for id  27 ,  20140226
# 7 :  N030_20140220.csv
#       >>  13 :  N030_20140220_083647-110533.csv
# data type:  float64
# (178513, 10)
#       >>  14 :  N030_20140220_120432-161702.csv
# data type:  float64
# (302996, 10)
#       >>  15 :  N030_20140220_165045-170110.csv
# data type:  float64
# (12505, 10)
#       >>  16 :  N030_20140220_195322-195652.csv
# data type:  float64
# (4205, 10)
# Saved data for id  30 ,  20140220
# 8 :  N030_20140225.csv
#       >>  17 :  N030_20140225_084722-110712.csv
# data type:  float64
# (167811, 10)
#       >>  18 :  N030_20140225_120531-155952.csv
# data type:  float64
# (281224, 10)
#       >>  19 :  N030_20140225_162755-171445.csv
# data type:  float64
# (56195, 10)
# Saved data for id  30 ,  20140225
# 9 :  N031_20140217.csv
#       >>  20 :  N031_20140217_081024-081143.csv
# data type:  float64
# (1578, 10)
#       >>  21 :  N031_20140217_084313-084717.csv
# data type:  float64
# (4881, 10)
#       >>  22 :  N031_20140217_091125-115939.csv
# data type:  float64
# (201874, 10)
#       >>  23 :  N031_20140217_121601-152559.csv
# data type:  float64
# (227955, 10)
# Saved data for id  31 ,  20140217
# 10 :  N031_20140221.csv
#       >>  24 :  N031_20140221_084836-173849.csv
# data type:  float64
# (636255, 10)
# Saved data for id  31 ,  20140221
# 11 :  N031_20140226.csv
#       >>  25 :  N031_20140226_084911-112140.csv
# data type:  float64
# (182987, 10)
#       >>  26 :  N031_20140226_120306-153532.csv
# data type:  float64
# (254927, 10)
#       >>  27 :  N031_20140226_160252-165717.csv
# data type:  float64
# (65301, 10)
# Saved data for id  31 ,  20140226
# 12 :  N041_20140219.csv
#       >>  28 :  N041_20140219_080854-081034.csv
# data type:  float64
# (2003, 10)
#       >>  29 :  N041_20140219_085024-120903.csv
# data type:  float64
# (238379, 10)
#       >>  30 :  N041_20140219_120908-161322.csv
# data type:  float64
# (293092, 10)
# Saved data for id  41 ,  20140219
# 13 :  N042_20140212.csv
#       >>  31 :  N042_20140212_085121-113858.csv
# data type:  float64
# (201134, 10)
#       >>  32 :  N042_20140212_121233-160047.csv
# data type:  float64
# (273878, 10)
#       >>  33 :  N042_20140212_162352-173021.csv
# data type:  float64
# (79769, 10)
#       >>  34 :  N042_20140212_190534-191012.csv
# data type:  float64
# (5561, 10)
# Saved data for id  42 ,  20140212
# 14 :  N042_20140218.csv
#       >>  35 :  N042_20140218_084040-114738.csv
# data type:  float64
# (224366, 10)
#       >>  36 :  N042_20140218_115014-164551.csv
# data type:  float64
# (354733, 10)
#       >>  37 :  N042_20140218_205952-210054.csv
# data type:  float64
# (1251, 10)
# Saved data for id  42 ,  20140218
# 15 :  N042_20140227.csv
#       >>  38 :  N042_20140227_084332-170157.csv
# data type:  float64
# (598102, 10)
# Saved data for id  42 ,  20140227
# 16 :  N043_20140213.csv
#       >>  39 :  N043_20140213_080031-080307.csv
# data type:  float64
# (3117, 10)
#       >>  40 :  N043_20140213_084522-111143.csv
# data type:  float64
# (175632, 10)
#       >>  41 :  N043_20140213_121913-155020.csv
# data type:  float64
# (253331, 10)
#       >>  42 :  N043_20140213_163712-165604.csv
# data type:  float64
# (22639, 10)
# Saved data for id  43 ,  20140213
# 17 :  N045_20140227.csv
#       >>  43 :  N045_20140227_090214-110157.csv
# data type:  float64
# (143644, 10)
#       >>  44 :  N045_20140227_120100-154159.csv
# data type:  float64
# (265184, 10)
# Saved data for id  45 ,  20140227
# 18 :  N046_20140210.csv
#       >>  45 :  N046_20140210_081827-082141.csv
# data type:  float64
# (3876, 10)
#       >>  46 :  N046_20140210_084421-110832.csv
# data type:  float64
# (173023, 10)
#       >>  47 :  N046_20140210_120520-162331.csv
# data type:  float64
# (309813, 10)
#       >>  48 :  N046_20140210_165251-174438.csv
# data type:  float64
# (62123, 10)
#       >>  49 :  N046_20140210_202543-202840.csv
# data type:  float64
# (3542, 10)
# Saved data for id  46 ,  20140210
# 19 :  N046_20140228.csv
#       >>  50 :  N046_20140228_084402-111711.csv
# data type:  float64
# (183762, 10)
#       >>  51 :  N046_20140228_121627-172646.csv
# data type:  float64
# (372382, 10)
# Saved data for id  46 ,  20140228
# 20 :  N050_20140212.csv
#       >>  52 :  N050_20140212_085040-111324.csv
# data type:  float64
# (171281, 10)
#       >>  53 :  N050_20140212_121121-160515.csv
# data type:  float64
# (280667, 10)
#       >>  54 :  N050_20140212_162520-165954.csv
# data type:  float64
# (41468, 10)
#       >>  55 :  N050_20140212_190533-191021.csv
# data type:  float64
# (5755, 10)
# Saved data for id  50 ,  20140212
# 21 :  N050_20140221.csv
#       >>  56 :  N050_20140221_084853-110601.csv
# data type:  float64
# (164564, 10)
#       >>  57 :  N050_20140221_115905-154950.csv
# data type:  float64
# (276912, 10)
#       >>  58 :  N050_20140221_161649-170058.csv
# data type:  float64
# (52977, 10)
# Saved data for id  50 ,  20140221
# 22 :  N052_20140224.csv
# Saved data for id  52 ,  20140224
# 23 :  N061_20140217.csv
#       >>  59 :  N061_20140217_081019-081142.csv
# data type:  float64
# (1652, 10)
#       >>  60 :  N061_20140217_085103-170638.csv
# data type:  float64
# (594698, 10)
# Saved data for id  61 ,  20140217
# 24 :  N061_20140221.csv
#       >>  61 :  N061_20140221_084755-180339.csv
# data type:  float64
# (666873, 10)
# Saved data for id  61 ,  20140221
# 25 :  N061_20140227.csv
#       >>  62 :  N061_20140227_083522-171024.csv
# data type:  float64
# (618043, 10)
# Saved data for id  61 ,  20140227
# 26 :  N064_20140210.csv
#       >>  63 :  N064_20140210_081826-082144.csv
# data type:  float64
# (3964, 10)
#       >>  64 :  N064_20140210_090806-171149.csv
# data type:  float64
# (580468, 10)
#       >>  65 :  N064_20140210_202536-202825.csv
# data type:  float64
# (3374, 10)
# Saved data for id  64 ,  20140210
# 27 :  N064_20140220.csv
#       >>  66 :  N064_20140220_195403-195552.csv
# data type:  float64
# (2173, 10)
# Saved data for id  64 ,  20140220
# 28 :  N066_20140214.csv
#       >>  67 :  N066_20140214_084400-170004.csv
# data type:  float64
# (595271, 10)
#       >>  68 :  N066_20140214_191612-192218.csv
# data type:  float64
# (7330, 10)
# Saved data for id  66 ,  20140214
# 29 :  N066_20140228.csv
#       >>  69 :  N066_20140228_084447-175905.csv
# data type:  float64
# (665158, 10)
# Saved data for id  66 ,  20140228
# 30 :  N067_20140212.csv
#       >>  70 :  N067_20140212_084649-172210.csv
# data type:  float64
# (618412, 10)
#       >>  71 :  N067_20140212_190548-191102.csv
# data type:  float64
# (6269, 10)
# Saved data for id  67 ,  20140212
# 31 :  N068_20140213.csv
#       >>  72 :  N068_20140213_080029-080250.csv
# data type:  float64
# (2822, 10)
#       >>  73 :  N068_20140213_083807-171908.csv
# data type:  float64
# (625211, 10)
# Saved data for id  68 ,  20140213
# 32 :  N068_20140219.csv
#       >>  74 :  N068_20140219_080856-081020.csv
# data type:  float64
# (1693, 10)
#       >>  75 :  N068_20140219_084048-123025.csv
# data type:  float64
# (275539, 10)
#       >>  76 :  N068_20140219_132250-175755.csv
# data type:  float64
# (330099, 10)
# Saved data for id  68 ,  20140219
# 33 :  N080_20140226.csv
# Saved data for id  80 ,  20140226
# 34 :  N097_20140227.csv
# Saved data for id  97 ,  20140227
# 35 :  N098_20140210.csv
#       >>  77 :  N098_20140210_081826-082203.csv
# data type:  float64
# (4349, 10)
#       >>  78 :  N098_20140210_090803-171210.csv
# data type:  float64
# (580933, 10)
#       >>  79 :  N098_20140210_202541-202835.csv
# data type:  float64
# (3472, 10)
# Saved data for id  98 ,  20140210
# 36 :  N098_20140217.csv
#       >>  80 :  N098_20140217_081008-081152.csv
# data type:  float64
# (2079, 10)
#       >>  81 :  N098_20140217_083635-083910.csv
# data type:  float64
# (3097, 10)
#       >>  82 :  N098_20140217_083918-171116.csv
# data type:  float64
# (614364, 10)
# Saved data for id  98 ,  20140217
# 37 :  N098_20140221.csv
# Saved data for id  98 ,  20140221
# 38 :  N099_20140214.csv
#       >>  83 :  N099_20140214_084122-165914.csv
# data type:  float64
# (597424, 10)
#       >>  84 :  N099_20140214_191608-192142.csv
# data type:  float64
# (6671, 10)
# Saved data for id  99 ,  20140214
# 39 :  N099_20140228.csv
#       >>  85 :  N099_20140228_084151-180720.csv

# %%
total = 0
for key, subject_data in data.items():    
    for key1, day_data in subject_data.items():
        print("ID: ", key, ", Date: ", key1, " Sensor File Count: ", len(day_data["sensors"]))
        sd = day_data["sensors"]
        for s in sd:
            s = s.astype(np.float32)
            size = s.nbytes
            print("    >> ",s.dtype, ", ", size)
            total+=size

# %%
print(total/1024)
