# %%
import numpy as np
import pickle
import os
import sys
import importlib
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
# Out:
# c:\asm\continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
util_path = 'C:/ASM/Dropbox/Developments/Jupyter/Eating/myutils' if 'C:' in os.getcwd() else './myutils'
sys.path.append(util_path)
import my_file_utils as mfileu
import my_classification_utils as mclfu
import my_steven_lab_utils as mslabu
import my_tensorflow_cnn_utils as mcnnu
import my_tensorflow_lstm_utils as mlstmu
import my_tensorflow_dense_utils as mdenseu
import generate_result_utils as gresu
#importlib.reload(biteu)

# %%
axis_count, label_shape_1 = 9, 1 
win_size, step_size, feature_count = 6*16, 2, 32
var_min, var_max, gx_th = 1, 25, -0.25
print("Win size:", win_size, ", Step size:", step_size, ", var min:", var_min, ", var max:", var_max, ', gx_th:', gx_th)
# Out:
# Win size: 96 , Step size: 2 , var min: 1 , var max: 25 , gx_th: -0.25

# %%
dlab = mfileu.read_file('data', 'lab_data_steven_smoothed.pkl')
dlab, _, dlab_annots = mslabu.separate_right_left_annots(dlab)
dfree = mfileu.read_file('data', 'free_data_steven_right_smoothed.pkl')
annots = mfileu.read_file('data', 'free_data_steven_annots.pkl')
fs = mfileu.read_file('features', 'free_features_steven_right.pkl')

# %%
all_proba_steven = gresu.get_all_proba(annots, 'baseline_test_proba_bite_steven', 'bite_free', sess_avail=True)
all_proba_our = gresu.get_all_proba(annots, 'our_test_proba_bite_6s', 'bite_free', sess_avail=True)

# %%
def get_mid_gx(ds, indices, win_size):
    count = len(indices)
    x = np.zeros((count, ))    
    for i in range(count):
        subj, sess, ix = indices[i, 0], indices[i, 1], indices[i, 2]+win_size//2
        x[i] = ds[subj][sess][ix, -3]                
    return x

# %%
def get_variance_accel(ds, indices, win_size):   
    count = len(indices)
    v = np.zeros((count, ))    
    for i in range(count):
        subj, sess, ix = indices[i, 0], indices[i, 1], indices[i, 2]
        v[i] = np.sum(np.var(ds[subj][sess][ix:ix+win_size, 1:4], axis=0))                
    return v

# %%
def get_labels_lab(indices, a, win_size):
    a = a[a[:, 3]!=2, :] # right hand only    
    wcount, acount = len(indices), len(a)  
    
    si = indices
    q1 = si + win_size//4
    mi = si + 2*win_size//4    
    q3 = si + 3*win_size//4    
    
    labels=np.zeros((wcount,))    
    for i in range(acount):         
        if a[i, 2]==1: #bite
            ix = a[i, 0]
            cond = (q1<=ix) & (ix<=q3)
            label = 1
        else:#sip
            ix1 = a[i, 0]
            ix2 = a[i, 1]
            cond = (mi>=ix1) & (mi<=ix2)
            label = 2
        
        labels[cond] = label
    return np.array(labels)

# %%
def get_labels_free(indices, a, win_size):    
    wcount, acount = len(indices), len(a)      
    mi = indices + win_size//2    
    
    labels=np.zeros((wcount,))    
    for i in range(acount):                 
        ix1 = a[i, 0]
        ix2 = a[i, 1]
        cond = (mi>=ix1) & (mi<=ix2)
        labels[cond] = a[i, 2]
        
    return labels.astype(int)

# %%
def get_all_indices_lab(exclude_subj=-1):
    all_indices = np.zeros((0, 4))
    for subj in range(len(dlab)):
        if subj==exclude_subj:
            continue
        for sess in range(len(dlab[subj])):
            d = dlab[subj][sess]
            a = dlab_annots[subj][sess]

            count = (len(d)-win_size)//step_size + 1
            indices = np.array(list(range(count)))*2
            labels = get_labels_lab(indices, a, win_size)
            labels[labels==2] = 0

            ix = np.zeros((count, 4))
            ix[:, 0] = subj
            ix[:, 1] = sess
            ix[:, 2] = indices
            ix[:, 3] = labels
            all_indices = np.concatenate((all_indices, ix))

    all_indices = all_indices.astype(int)
    assert np.sum(all_indices[:, -1]>1) == 0
    assert np.sum(all_indices[:, -1]<0) == 0
    #print("All indices shape, neg, bite:", len(all_indices), np.sum(all_indices[:, -1]==0), np.sum(all_indices[:, -1]==1))
    return all_indices

# %%
def get_subject_indices_free(subj):
    all_indices = np.zeros((0, 4))    
    for sess in range(len(dfree[subj])):
        d = dfree[subj][sess]
        a = annots[subj][sess]
        
        count = (len(d)-win_size)//step_size + 1
        indices = np.array(list(range(count)))*2
        labels = get_labels_free(indices, a, win_size)
        labels[labels==2] = 1
        labels[labels==3] = 0
        
        ix = np.zeros((count, 4))
        ix[:, 0] = subj
        ix[:, 1] = sess
        ix[:, 2] = indices
        ix[:, 3] = labels
        all_indices = np.concatenate((all_indices, ix))
        
    
    all_indices = all_indices.astype(int)
    assert np.sum(all_indices[:, -1]>1) == 0
    assert np.sum(all_indices[:, -1]<0) == 0
    #print("All indices shape, neg, pos:", len(all_indices), np.sum(all_indices[:, -1]==0), np.sum(all_indices[:, -1]==1))
    return all_indices

# %%
def get_all_indices_free(exclude_subj=-1):
    all_indices = np.zeros((0, 4))
    
    for subj in range(len(dfree)):
        if subj == exclude_subj:
            continue
        for sess in range(len(dfree[subj])):
            d = dfree[subj][sess]
            a = annots[subj][sess]

            count = (len(d)-win_size)//step_size + 1
            indices = np.array(list(range(count)))*2
            labels = get_labels_free(indices, a, win_size)
            labels[labels==2] = 1
            labels[labels==3] = 0

            ix = np.zeros((count, 4))
            ix[:, 0] = subj
            ix[:, 1] = sess
            ix[:, 2] = indices
            ix[:, 3] = labels
            all_indices = np.concatenate((all_indices, ix))
            
    all_indices = all_indices.astype(int)
    assert np.sum(all_indices[:, -1]>1) == 0
    assert np.sum(all_indices[:, -1]<0) == 0
    #print("All indices shape, neg, bite:", len(all_indices), np.sum(all_indices[:, -1]==0), np.sum(all_indices[:, -1]==1))
    return all_indices

# %%
for subj in range(len(fs)):
    subj_indices = get_subject_indices_free(subj)
    for sess in range(len(fs[subj])):        
        indices = subj_indices[subj_indices[:,1]==sess, :]
        print(subj, sess, " : ", indices.shape, all_proba_steven[subj][sess].shape, all_proba_our[subj][sess].shape)        
        print("Shapes indices, feature_count: ",indices.shape, fs[subj][sess].shape)        
        print("Shapes proba steven, our: ",all_proba_steven[subj][sess].shape, all_proba_our[subj][sess].shape)        
        
        gx = get_mid_gx(dfree, indices, win_size=win_size)
        indices = indices[gx<=gx_th]    
        print("Indices summary after gx filter total, neg, pos:", len(indices), np.sum(indices[:, -1]==0), np.sum(indices[:, -1]==1))

        v = get_variance_accel(dfree, indices, win_size=win_size)            
        indices = indices[(v>=var_min) & (v<=var_max)]   
        print("Indices summary after variance filter total, neg, pos:", len(indices), np.sum(indices[:, -1]==0), np.sum(indices[:, -1]==1))
# Out:
# 0 0  :  (323349, 4) (323357, 3) (33591, 2)
# Shapes indices, feature_count:  (323349, 4) (323357, 33)
# Shapes proba steven, our:  (323357, 3) (33591, 2)
# Indices summary after gx filter total, neg, pos: 137368 132172 5196
# Indices summary after variance filter total, neg, pos: 33591 29963 3628
# 0 1  :  (305438, 4) (305446, 3) (36244, 2)
# Shapes indices, feature_count:  (305438, 4) (305446, 33)
# Shapes proba steven, our:  (305446, 3) (36244, 2)
# Indices summary after gx filter total, neg, pos: 106170 100333 5837
# Indices summary after variance filter total, neg, pos: 36244 31379 4865
# 1 0  :  (292807, 4) (292815, 3) (42823, 2)
# Shapes indices, feature_count:  (292807, 4) (292815, 33)
# Shapes proba steven, our:  (292815, 3) (42823, 2)
# Indices summary after gx filter total, neg, pos: 76441 57129 19312
# Indices summary after variance filter total, neg, pos: 42823 30574 12249
# 1 1  :  (296339, 4) (296347, 3) (33511, 2)
# Shapes indices, feature_count:  (296339, 4) (296347, 33)
# Shapes proba steven, our:  (296347, 3) (33511, 2)
# Indices summary after gx filter total, neg, pos: 77310 61106 16204
# Indices summary after variance filter total, neg, pos: 33511 21262 12249
# 2 0  :  (345954, 4) (345962, 3) (37304, 2)
# Shapes indices, feature_count:  (345954, 4) (345962, 33)
# Shapes proba steven, our:  (345962, 3) (37304, 2)
# Indices summary after gx filter total, neg, pos: 79768 60881 18887
# Indices summary after variance filter total, neg, pos: 37304 24815 12489
# 2 1  :  (337081, 4) (337089, 3) (26129, 2)
# Shapes indices, feature_count:  (337081, 4) (337089, 33)
# Shapes proba steven, our:  (337089, 3) (26129, 2)
# Indices summary after gx filter total, neg, pos: 62095 48039 14056
# Indices summary after variance filter total, neg, pos: 26129 15059 11070
# 3 0  :  (201524, 4) (201532, 3) (15844, 2)
# Shapes indices, feature_count:  (201524, 4) (201532, 33)
# Shapes proba steven, our:  (201532, 3) (15844, 2)
# Indices summary after gx filter total, neg, pos: 30718 25367 5351
# Indices summary after variance filter total, neg, pos: 15844 11990 3854
# 3 1  :  (229719, 4) (229727, 3) (18196, 2)
# Shapes indices, feature_count:  (229719, 4) (229727, 33)
# Shapes proba steven, our:  (229727, 3) (18196, 2)
# Indices summary after gx filter total, neg, pos: 101792 98080 3712
# Indices summary after variance filter total, neg, pos: 18196 15504 2692
# 4 0  :  (245485, 4) (245493, 3) (16398, 2)
# Shapes indices, feature_count:  (245485, 4) (245493, 33)
# Shapes proba steven, our:  (245493, 3) (16398, 2)
# Indices summary after gx filter total, neg, pos: 64386 61993 2393
# Indices summary after variance filter total, neg, pos: 16398 14657 1741
# 4 1  :  (314276, 4) (314284, 3) (36449, 2)
# Shapes indices, feature_count:  (314276, 4) (314284, 33)
# Shapes proba steven, our:  (314284, 3) (36449, 2)
# Indices summary after gx filter total, neg, pos: 193497 171879 21618
# Indices summary after variance filter total, neg, pos: 36449 25512 10937
# 5 0  :  (124477, 4) (124485, 3) (24704, 2)
# Shapes indices, feature_count:  (124477, 4) (124485, 33)
# Shapes proba steven, our:  (124485, 3) (24704, 2)
# Indices summary after gx filter total, neg, pos: 44701 36194 8507
# Indices summary after variance filter total, neg, pos: 24704 19247 5457
# 5 1  :  (252951, 4) (252959, 3) (58679, 2)
# Shapes indices, feature_count:  (252951, 4) (252959, 33)
# Shapes proba steven, our:  (252959, 3) (58679, 2)
# Indices summary after gx filter total, neg, pos: 99134 66611 32523
# Indices summary after variance filter total, neg, pos: 58679 32616 26063
# 6 0  :  (296041, 4) (296049, 3) (35825, 2)
# Shapes indices, feature_count:  (296041, 4) (296049, 33)
# Shapes proba steven, our:  (296049, 3) (35825, 2)
# Indices summary after gx filter total, neg, pos: 74167 60727 13440
# Indices summary after variance filter total, neg, pos: 35825 26524 9301
# 6 1  :  (217624, 4) (217632, 3) (19477, 2)
# Shapes indices, feature_count:  (217624, 4) (217632, 33)
# Shapes proba steven, our:  (217632, 3) (19477, 2)
# Indices summary after gx filter total, neg, pos: 62646 57111 5535
# Indices summary after variance filter total, neg, pos: 19477 15108 4369
# 7 0  :  (164415, 4) (164423, 3) (18029, 2)
# Shapes indices, feature_count:  (164415, 4) (164423, 33)
# Shapes proba steven, our:  (164423, 3) (18029, 2)
# Indices summary after gx filter total, neg, pos: 93905 83975 9930
# Indices summary after variance filter total, neg, pos: 18029 15574 2455
# 7 1  :  (399418, 4) (399426, 3) (38256, 2)
# Shapes indices, feature_count:  (399418, 4) (399426, 33)
# Shapes proba steven, our:  (399426, 3) (38256, 2)
# Indices summary after gx filter total, neg, pos: 218381 212742 5639
# Indices summary after variance filter total, neg, pos: 38256 35163 3093
# 8 0  :  (306972, 4) (306980, 3) (32333, 2)
# Shapes indices, feature_count:  (306972, 4) (306980, 33)
# Shapes proba steven, our:  (306980, 3) (32333, 2)
# Indices summary after gx filter total, neg, pos: 48521 45088 3433
# Indices summary after variance filter total, neg, pos: 32333 29961 2372
# 8 1  :  (320803, 4) (320811, 3) (49124, 2)
# Shapes indices, feature_count:  (320803, 4) (320811, 33)
# Shapes proba steven, our:  (320811, 3) (49124, 2)
# Indices summary after gx filter total, neg, pos: 136113 123892 12221
# Indices summary after variance filter total, neg, pos: 49124 43753 5371
# 9 0  :  (265969, 4) (265977, 3) (44612, 2)
# Shapes indices, feature_count:  (265969, 4) (265977, 33)
# Shapes proba steven, our:  (265977, 3) (44612, 2)
# Indices summary after gx filter total, neg, pos: 94974 84123 10851
# Indices summary after variance filter total, neg, pos: 44612 36478 8134
# 9 1  :  (273523, 4) (273531, 3) (27177, 2)
# Shapes indices, feature_count:  (273523, 4) (273531, 33)
# Shapes proba steven, our:  (273531, 3) (27177, 2)
# Indices summary after gx filter total, neg, pos: 47254 40086 7168
# Indices summary after variance filter total, neg, pos: 27177 20848 6329
# 9 2  :  (273906, 4) (273914, 3) (21306, 2)
# Shapes indices, feature_count:  (273906, 4) (273914, 33)
# Shapes proba steven, our:  (273914, 3) (21306, 2)
# Indices summary after gx filter total, neg, pos: 63259 51963 11296
# Indices summary after variance filter total, neg, pos: 21306 14626 6680
# 9 3  :  (287328, 4) (287336, 3) (42946, 2)
# Shapes indices, feature_count:  (287328, 4) (287336, 33)
# Shapes proba steven, our:  (287336, 3) (42946, 2)
# Indices summary after gx filter total, neg, pos: 113642 105797 7845
# Indices summary after variance filter total, neg, pos: 42946 36594 6352
# 9 4  :  (202975, 4) (202983, 3) (32781, 2)
# Shapes indices, feature_count:  (202975, 4) (202983, 33)
# Shapes proba steven, our:  (202983, 3) (32781, 2)
# Indices summary after gx filter total, neg, pos: 68290 62677 5613
# Indices summary after variance filter total, neg, pos: 32781 27935 4846
# 10 0  :  (277717, 4) (277725, 3) (21285, 2)
# Shapes indices, feature_count:  (277717, 4) (277725, 33)
# Shapes proba steven, our:  (277725, 3) (21285, 2)
# Indices summary after gx filter total, neg, pos: 43758 39623 4135
# Indices summary after variance filter total, neg, pos: 21285 18241 3044
# 10 1  :  (334502, 4) (334510, 3) (21811, 2)
# Shapes indices, feature_count:  (334502, 4) (334510, 33)
# Shapes proba steven, our:  (334510, 3) (21811, 2)
# Indices summary after gx filter total, neg, pos: 47558 45065 2493
# Indices summary after variance filter total, neg, pos: 21811 19818 1993
