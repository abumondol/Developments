# %%
import numpy as np
import pickle
import os
import data_process_utils as dpu

# %%
def process_bite_label_steven(label):
    label = label.replace("P","1").replace("D","2").replace("I","3").replace("Q","4")
    label = label.replace("N","5").replace("C","6").replace("S","7").replace("M","8")
    label = label.replace("R","1").replace("L","2").replace("X","-1")
    return int(label)

def process_bite_annots_steven(annots):    
    a = np.zeros((len(annots), 2))
    for i in range(len(annots)):
        s = annots[i].split(",")
        t1 = float(s[0].rstrip())
        t2 = float(s[1].rstrip())
        label = process_bite_label_steven(s[2].rstrip())
        a[i, 0] = t1+t2/2
        a[i, 1] = label
    
    res = []
    hand = 0    
    last_was_bite = False
    for i in range(len(a)):
        #print(a[i, 0], ", ", a[i, 1])
        if a[i, 1]==21 or a[i,1] ==22:            
            if last_was_bite:    
                if a[i, 1]==21:
                    hand = 1
                else:
                    hand = 2
            else:
                if hand ==1 and a[i, 1]==21 or hand ==2 and a[i, 1]==22:
                    print( "************************ Similar hand found twice ****************")
                
                hand = 3
            
            last_was_bite = False
            
        elif a[i, 1]==3 or a[i, 1]==4:
            if hand==0:
                print("********** Hand is not found : " , annots[i] , ", line no: ", (i + 1))                
                continue
            
            r = [0, 0]
            r[0] = a[i, 0]
            if a[i, 1]==3:    #bite
                r[1] = 1
            else:            #drink
                r[1] = 2
            
            if hand ==1 or hand ==3: #add right hand data only
                res.append(r)
            
            if last_was_bite:
                print("************************ Bite repeated **************** ", i)
            last_was_bite = True        
    
    res = np.array(res)            
    return res

# %%
#read_data_steven_lab

path = 'C:/ASM/PublicData/eating_steventech/lab'
sampling_rate = 16 #Hz
data_all = []

for subject in range(7):
    dsubject = [];
    for sess in range(2):
        if (subject==0 and sess==0) or (subject==1 and sess==1):
            continue

        print("\nSubject, Sess ", subject, sess)
        
        filePathAccel = path + "/0" + str(subject) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv";
        filePathAnnots = path + "/0" + str(subject) + "/000" + str(sess) + "/annot_events.csv";

        data = np.genfromtxt(filePathAccel, delimiter=',')
        t = data[:, 0]/1e9
        t = t.reshape((-1, 1))
        accel_gyro = data[:, 1:7]
        quat = data[:, -3:]
        _ , _ , grav = dpu.quat2mat(quat)

        data = np.concatenate((t, grav, accel_gyro), axis=1)
        data = dpu.resample(data, sampling_rate)
        
        with open(filePathAnnots) as file:            
            annots = file.readlines()
        annots = process_bite_annots_steven(annots)        
        annots[:, 0] = dpu.time_to_index(data, annots[:, 0])
        annots = annots.astype(int)
        
        dsess = {}
        dsess['data'] = data
        dsess['annots'] = annots        
        dsubject.append(dsess)
        
    data_all.append(dsubject)
# Out:
# Subject, Sess  0 1
# Resampling... Rate: 16
# Old start, end: 0.0, 23392.876031962
# New start, end: 0.0, 23392.876031962
# Sample Count old, new: 384325, 374287
# Resampling Done
# ************************ Bite repeated ****************  2733
# ************************ Bite repeated ****************  2774
# ************************ Bite repeated ****************  2777
# ************************ Bite repeated ****************  2789
# Time to index ...
# Data start, end: 0.0, 23392.875
# TS start, end: 452.15999999999997, 23158.018
# Time to index Done.
#
# Subject, Sess  1 0
# Resampling... Rate: 16
# Old start, end: 0.0, 21589.856691755
# New start, end: 0.0, 21589.856691755
# Sample Count old, new: 311146, 345438
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 21589.8125
# TS start, end: 9463.2995, 20630.0495
# Time to index Done.
#
# Subject, Sess  2 0
# Resampling... Rate: 16
# Old start, end: 0.0, 22952.615783612
# New start, end: 0.0, 22952.615783612
# Sample Count old, new: 328534, 367242
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 22952.5625
# TS start, end: 569.2665, 21165.7925
# Time to index Done.
#
# Subject, Sess  2 1
# Resampling... Rate: 16
# Old start, end: 0.0, 21210.229435535
# New start, end: 0.0, 21210.229435535
# Sample Count old, new: 348846, 339364
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 21210.1875
# TS start, end: 311.3845, 20368.10825
# Time to index Done.
#
# Subject, Sess  3 0
# Resampling... Rate: 16
# Old start, end: 0.0, 21956.307458528
# New start, end: 0.0, 21956.307458528
# Sample Count old, new: 328777, 351301
# Resampling Done
# ************************ Bite repeated ****************  902
# ************************ Bite repeated ****************  1006
# ************************ Bite repeated ****************  1718
# Time to index ...
# Data start, end: 0.0, 21956.25
# TS start, end: 259.34225, 9783.4505
# Time to index Done.
#
# Subject, Sess  3 1
# Resampling... Rate: 16
# Old start, end: 0.0, 21660.930195068
# New start, end: 0.0, 21660.930195068
# Sample Count old, new: 340920, 346575
# Resampling Done
# ************************ Bite repeated ****************  151
# ************************ Bite repeated ****************  187
# ************************ Bite repeated ****************  198
# ************************ Bite repeated ****************  205
# ************************ Bite repeated ****************  242
# ************************ Bite repeated ****************  289
# ************************ Bite repeated ****************  304
# ************************ Bite repeated ****************  307
# ************************ Bite repeated ****************  308
# ************************ Bite repeated ****************  309
# ************************ Bite repeated ****************  432
# ************************ Bite repeated ****************  481
# ************************ Bite repeated ****************  593
# ************************ Bite repeated ****************  684
# ************************ Bite repeated ****************  698
# ************************ Bite repeated ****************  731
# ************************ Bite repeated ****************  765
# ************************ Bite repeated ****************  766
# ************************ Bite repeated ****************  780
# ************************ Bite repeated ****************  783
# ************************ Bite repeated ****************  786
# ************************ Bite repeated ****************  794
# Time to index ...
# Data start, end: 0.0, 21660.875
# TS start, end: 794.0165, 21480.734
# Time to index Done.
#
# Subject, Sess  4 0
# Resampling... Rate: 16
# Old start, end: 0.0, 21973.69046151
# New start, end: 0.0, 21973.69046151
# Sample Count old, new: 361588, 351580
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 21973.6875
# TS start, end: 225.743, 9690.949999999999
# Time to index Done.
#
# Subject, Sess  4 1
# Resampling... Rate: 16
# Old start, end: 0.0, 21648.58893313
# New start, end: 0.0, 21648.58893313
# Sample Count old, new: 316032, 346378
# Resampling Done
# ********** Hand is not found :  393.612390923,0.779609077313,Q
#  , line no:  1
# ************************ Bite repeated ****************  116
# ************************ Bite repeated ****************  262
# ************************ Bite repeated ****************  273
# ************************ Bite repeated ****************  390
# ************************ Bite repeated ****************  576
# ************************ Bite repeated ****************  727
# ************************ Bite repeated ****************  871
# ************************ Bite repeated ****************  875
# ************************ Bite repeated ****************  1001
# ************************ Bite repeated ****************  1142
# ************************ Bite repeated ****************  1261
# ************************ Bite repeated ****************  1351
# ************************ Bite repeated ****************  1367
# ************************ Bite repeated ****************  1378
# ************************ Bite repeated ****************  1382
# ************************ Bite repeated ****************  1387
# ************************ Bite repeated ****************  1510
# ************************ Bite repeated ****************  1811
# Time to index ...
# Data start, end: 0.0, 21648.5625
# TS start, end: 402.25, 20288.601
# Time to index Done.
#
# Subject, Sess  5 0
# Resampling... Rate: 16
# Old start, end: 0.0, 21246.994216869
# New start, end: 0.0, 21246.994216869
# Sample Count old, new: 332938, 339952
# Resampling Done
# ************************ Bite repeated ****************  2466
# Time to index ...
# Data start, end: 0.0, 21246.9375
# TS start, end: 497.0165, 13753.1165
# Time to index Done.
#
# Subject, Sess  5 1
# Resampling... Rate: 16
# Old start, end: 0.0, 22633.58737429
# New start, end: 0.0, 22633.58737429
# Sample Count old, new: 326227, 362138
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 22633.5625
# TS start, end: 1395.80025, 21850.25
# Time to index Done.
#
# Subject, Sess  6 0
# Resampling... Rate: 16
# Old start, end: 0.0, 21345.416743663
# New start, end: 0.0, 21345.416743663
# Sample Count old, new: 330052, 341527
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 21345.375
# TS start, end: 287.4665, 7448.867
# Time to index Done.
#
# Subject, Sess  6 1
# Resampling... Rate: 16
# Old start, end: 0.0, 21162.957109064
# New start, end: 0.0, 21162.957109064
# Sample Count old, new: 348741, 338608
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 21162.9375
# TS start, end: 272.6175, 13871.7835
# Time to index Done.

# %%
with open('C:/ASM/DevData/eating/data/steven_lab_data.pkl', 'wb') as file:
    pickle.dump(data_all, file)
