# %%
import numpy as np
import pickle
import sys
import data_process_utils as dpu

# %%
def get_meal_code(meal):    
    code = -1
    if meal == "meal" or meal=="lunch" or meal=="dinner":
        code = 1
    elif meal=="snack":
        code = 2    
    elif meal=="drink":
        code = 3
    elif meal=="eat":
        code = 4
    return code

def process_meal_annots_steven(annots, dr, dl, subject_code, session):
    meal_count = len(annots)    
    if subject_code == 5 and session == 0:
        meal_count = 9
    elif subject_code == 6 and session == 0:
        meal_count = 2
    elif subject_code == 102 and session == 1:
        meal_count = 1
    elif subject_code == 104 and session == 0:
        meal_count = 7
    
    j = 0
    a = np.zeros((meal_count, 5))
    for i in range(meal_count):        
        s = annots[i].split(",")
        a[i, 0] = float(s[1].rstrip())
        a[i, 1] = float(s[2].rstrip())
        
        
        if a[i,0]>dr[-1,0]:
            print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxx')            
            print('Right: Start time is greater than data end time', a[i,0], dr[-1,0])
            print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
            a[i, 2] = -1
            
        if a[i,0]>dl[-1,0]:
            print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxx')            
            print('Left: Start time is greater than data end time', a[i,0], dl[-1,0])
            print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
            a[i, 3] = -1
            
            
        if a[i,1]>dr[-1,0]:            
            print('.................................')            
            print('Right: Adjusted Meal end time is greater than data end time: ', dr[-1, 0], a[i,1])
            print('..................................')
            a[i, 2] = dr[-1,0]
        
        if a[i,1]>dl[-1,0]:            
            print('.................................')            
            print('Left: Adjusted Meal end time is greater than data end time: ', dl[-1, 0], a[i,1])
            print('..................................')
            a[i, 3] = dr[-1,0]
            
            #subject_code == 107 and session == 0 or subject_code == 107 and session == 2:            
         
        a[i, 4] = get_meal_code(s[3].rstrip().strip())        
        if a[i, 4]==-1:
            print(" \n\n******************* Meal code problem *************** code is -1\n\n")
            print(s[3])
            sys.exit(0)
            
    return a

# %%
path = 'C:/ASM/PublicData/eating_steventech/free'
sampling_rate = 16 #Hz
data_right = []
data_left = []
data_annots = []

subject_codes = [2, 3, 4, 5, 6, 101, 102, 103, 104, 107, 109]
for subject in range(len(subject_codes)):
    drs, dls, das = [], [], []
    sess_count = 2
    if subject_codes[subject] == 107:
        sess_count = 5

    for sess in range(sess_count):
        print('\nSubject, Sess, Code: ', subject, sess, subject_codes[subject])
        
        if subject_codes[subject] < 10:
            path_right = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv"
            path_left = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_left_000" + str(sess) + ".csv"
            path_annot = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/meal_events.csv"
        elif subject_codes[subject] == 109:
            path_right = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/watch_right_000" + str(sess+3) + ".csv"
            path_left = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/watch_left_000" + str(sess+3) + ".csv"
            path_annot = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/meal_events.csv"
        else:
            path_right = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv"
            path_left = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_left_000" + str(sess) + ".csv"
            path_annot = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/meal_events.csv"

        d = np.genfromtxt(path_right, delimiter=',')
        d[:, 0] = d[:, 0]/1e9        
        time_accel_gyro = d[:, :7]
        quat = d[:, -3:]
        _ , _ , grav = dpu.quat2mat(quat)
        d = np.concatenate((time_accel_gyro, grav), axis=1)
        dr = dpu.resample(d, sampling_rate)
        
        
        d = np.genfromtxt(path_left, delimiter=',')            
        d[:, 0] = d[:, 0]/1e9        
        time_accel_gyro = d[:, :7]
        quat = d[:, -3:]
        _ , _ , grav = dpu.quat2mat(quat)
        d = np.concatenate((time_accel_gyro, grav), axis=1)
        dl = dpu.resample(d, sampling_rate)        

        with open(path_annot) as file:            
            annots = file.readlines()
        da = process_meal_annots_steven(annots, dr, dl, subject_codes[subject], sess)        
        #annots[:, 0] = dpu.time_to_index(data, annots[:, 0])
        #annots[:, 1] = dpu.time_to_index(data, annots[:, 1])
        print("Right duration:", dr[0,0], dr[-1,0])
        print("Left duration:", dl[0,0], dl[-1,0])
        print(da)
        
        drs.append(dr)
        dls.append(dl)
        das.append(da)        

    data_right.append(drs)
    data_left.append(dls)
    data_annots.append(das)
# Out:
# Subject, Sess, Code:  0 0 2
# Resampling... Rate: 16
# Old start, end: 0.0, 40424.529486105
# New start, end: 0.0, 40424.529486105
# Sample Count old, new: 725551, 646793
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 37720.452365426
# New start, end: 0.0, 37720.452365426
# Sample Count old, new: 625128, 603528
# Resampling Done
# Right duration: 0.0 40424.5
# Left duration: 0.0 37720.4375
# [[8.0556000e+02 1.1769500e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [4.8269500e+03 4.8859500e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.8411603e+04 2.0145435e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  0 1 2
# Resampling... Rate: 16
# Old start, end: 0.0, 38185.645249663
# New start, end: 0.0, 38185.645249663
# Sample Count old, new: 550555, 610971
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 33380.66305363
# New start, end: 0.0, 33380.66305363
# Sample Count old, new: 559858, 534091
# Resampling Done
# Right duration: 0.0 38185.625
# Left duration: 0.0 33380.625
# [[2.0905890e+03 2.7736780e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [8.2873080e+03 8.3323380e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.9435941e+04 2.0122621e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.4973185e+04 2.5037560e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [2.9940763e+04 2.9993636e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]]
#
# Subject, Sess, Code:  1 0 3
# Resampling... Rate: 16
# Old start, end: 0.0, 36606.720713365
# New start, end: 0.0, 36606.720713365
# Sample Count old, new: 560364, 585708
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 36664.635614539
# New start, end: 0.0, 36664.635614539
# Sample Count old, new: 584168, 586635
# Resampling Done
# Right duration: 0.0 36606.6875
# Left duration: 0.0 36664.625
# [[3.8923600e+02 1.3213620e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.0003542e+04 1.1776710e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.4482381e+04 2.6590481e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.7823760e+04 2.7834329e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [3.2810731e+04 3.2903113e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]]
#
# Subject, Sess, Code:  1 1 3
# Resampling... Rate: 16
# Old start, end: 0.0, 37048.309772182
# New start, end: 0.0, 37048.309772182
# Sample Count old, new: 621551, 592773
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 37076.986728804
# New start, end: 0.0, 37076.986728804
# Sample Count old, new: 588543, 593232
# Resampling Done
# Right duration: 0.0 37048.25
# Left duration: 0.0 37076.9375
# [[1.0928900e+02 8.1856900e+02 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [6.5587880e+03 1.0127369e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.1641669e+04 1.2940058e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.9085558e+04 1.9491708e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.0428641e+04 2.0760714e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.2071027e+04 2.2121658e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.7138995e+04 2.8106677e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  2 0 4
# Resampling... Rate: 16
# Old start, end: 0.0, 43250.163293218
# New start, end: 0.0, 43250.163293218
# Sample Count old, new: 684553, 692003
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 38298.642482422
# New start, end: 0.0, 38298.642482422
# Sample Count old, new: 602478, 612779
# Resampling Done
# Right duration: 0.0 43250.125
# Left duration: 0.0 38298.625
# [[6.0846620e+03 6.1210570e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.1899681e+04 1.2484221e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.2767060e+04 1.3713598e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.6704428e+04 2.6740501e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [3.1828755e+04 3.3004925e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [3.3191482e+04 3.3582619e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]]
#
# Subject, Sess, Code:  2 1 4
# Resampling... Rate: 16
# Old start, end: 0.0, 42140.966948984
# New start, end: 0.0, 42140.966948984
# Sample Count old, new: 684200, 674256
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 39735.993622476
# New start, end: 0.0, 39735.993622476
# Sample Count old, new: 574563, 635776
# Resampling Done
# Right duration: 0.0 42140.9375
# Left duration: 0.0 39735.9375
# [[9.20704000e+02 2.04570100e+03 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [5.27588300e+03 5.44979300e+03 0.00000000e+00 0.00000000e+00
#   3.00000000e+00]
#  [1.41849500e+04 1.42251950e+04 0.00000000e+00 0.00000000e+00
#   3.00000000e+00]
#  [1.98992490e+04 2.13296520e+04 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [2.23771440e+04 2.26387450e+04 0.00000000e+00 0.00000000e+00
#   3.00000000e+00]
#  [2.60021500e+04 2.60127650e+04 0.00000000e+00 0.00000000e+00
#   3.00000000e+00]
#  [2.91167870e+04 2.91276660e+04 0.00000000e+00 0.00000000e+00
#   3.00000000e+00]
#  [3.79011859e+04 3.86675409e+04 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]]
#
# Subject, Sess, Code:  3 0 5
# Resampling... Rate: 16
# Old start, end: 0.0, 25196.418970225
# New start, end: 0.0, 25196.418970225
# Sample Count old, new: 390566, 403143
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 25196.497072002
# New start, end: 0.0, 25196.497072002
# Sample Count old, new: 389217, 403144
# Resampling Done
# Right duration: 0.0 25196.375
# Left duration: 0.0 25196.4375
# [[1.6807680e+03 2.9672470e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [4.8646790e+03 5.2885830e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [6.3159010e+03 6.3270600e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [6.3995770e+03 6.6858870e+03 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [1.5494790e+04 1.5511321e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [2.0175577e+04 2.0188401e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [2.2014033e+04 2.2272903e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.2362870e+04 2.2875396e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.2968625e+04 2.3124541e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  3 1 5
# Resampling... Rate: 16
# Old start, end: 0.0, 28720.781611331
# New start, end: 0.0, 28720.781611331
# Sample Count old, new: 479233, 459533
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 28719.676122151
# New start, end: 0.0, 28719.676122151
# Sample Count old, new: 477650, 459515
# Resampling Done
# Right duration: 0.0 28720.75
# Left duration: 0.0 28719.625
# [[2.6595250e+03 3.5474680e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [3.6630870e+03 3.8414600e+03 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [4.4193960e+03 4.4278910e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [9.1511500e+03 9.1648440e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.3725265e+04 1.3939686e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [1.4093323e+04 1.4384283e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]]
#
# Subject, Sess, Code:  4 0 6
# Resampling... Rate: 16
# Old start, end: 0.0, 30691.535907704
# New start, end: 0.0, 30691.535907704
# Sample Count old, new: 570537, 491065
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 30691.569866811
# New start, end: 0.0, 30691.569866811
# Sample Count old, new: 441933, 491066
# Resampling Done
# Right duration: 0.0 30691.5
# Left duration: 0.0 30691.5625
# [[1.2586267e+04 1.2914528e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.4414990e+04 1.4472905e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]]
#
# Subject, Sess, Code:  4 1 6
# Resampling... Rate: 16
# Old start, end: 0.0, 39290.324946087
# New start, end: 0.0, 39290.324946087
# Sample Count old, new: 682979, 628646
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 32498.197883501
# New start, end: 0.0, 32498.197883501
# Sample Count old, new: 570139, 519972
# Resampling Done
# .................................
# Left: Adjusted Meal end time is greater than data end time:  32498.1875 33222.6719592
# ..................................
# Right duration: 0.0 39290.3125
# Left duration: 0.0 32498.1875
# [[1.00676740e+04 1.06543390e+04 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [2.58190960e+04 2.66783230e+04 0.00000000e+00 0.00000000e+00
#   2.00000000e+00]
#  [2.68897010e+04 2.69484790e+04 0.00000000e+00 0.00000000e+00
#   2.00000000e+00]
#  [3.08349510e+04 3.32226720e+04 0.00000000e+00 3.92903125e+04
#   1.00000000e+00]]
#
# Subject, Sess, Code:  5 0 101
# Resampling... Rate: 16
# Old start, end: 0.0, 15565.4621878
# New start, end: 0.0, 15565.4621878
# Sample Count old, new: 222602, 249048
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 15565.488496824
# New start, end: 0.0, 15565.488496824
# Sample Count old, new: 222470, 249048
# Resampling Done
# Right duration: 0.0 15565.4375
# Left duration: 0.0 15565.4375
# [[5.9048700e+02 1.2240620e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.1504326e+04 1.2153079e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.4311638e+04 1.5453990e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  5 1 101
# Resampling... Rate: 16
# Old start, end: 0.0, 31624.754389144
# New start, end: 0.0, 31624.754389144
# Sample Count old, new: 452168, 505997
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 31624.660403154
# New start, end: 0.0, 31624.660403154
# Sample Count old, new: 452110, 505995
# Resampling Done
# Right duration: 0.0 31624.75
# Left duration: 0.0 31624.625
# [[3.94466600e+03 5.49435198e+03 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [1.51133190e+04 1.52196180e+04 0.00000000e+00 0.00000000e+00
#   2.00000000e+00]
#  [2.33067690e+04 2.65857500e+04 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [2.74025690e+04 2.83330130e+04 0.00000000e+00 0.00000000e+00
#   2.00000000e+00]]
#
# Subject, Sess, Code:  6 0 102
# Resampling... Rate: 16
# Old start, end: 0.0, 37010.948657578
# New start, end: 0.0, 37010.948657578
# Sample Count old, new: 529330, 592176
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 37011.603118364
# New start, end: 0.0, 37011.603118364
# Sample Count old, new: 529015, 592186
# Resampling Done
# Right duration: 0.0 37010.9375
# Left duration: 0.0 37011.5625
# [[7.0174270e+03 7.1747310e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [7.5200220e+03 8.5266450e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [3.0042986e+04 3.0186729e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [3.2695572e+04 3.3798702e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  6 1 102
# Resampling... Rate: 16
# Old start, end: 0.0, 27208.887866286
# New start, end: 0.0, 27208.887866286
# Sample Count old, new: 389150, 435343
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 27208.458532668
# New start, end: 0.0, 27208.458532668
# Sample Count old, new: 388924, 435336
# Resampling Done
# Right duration: 0.0 27208.875
# Left duration: 0.0 27208.4375
# [[5.781443e+03 6.802099e+03 0.000000e+00 0.000000e+00 1.000000e+00]]
#
# Subject, Sess, Code:  7 0 103
# Resampling... Rate: 16
# Old start, end: 0.0, 20557.79868422
# New start, end: 0.0, 20557.79868422
# Sample Count old, new: 293996, 328925
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 20557.992288946
# New start, end: 0.0, 20557.992288946
# Sample Count old, new: 293826, 328928
# Resampling Done
# Right duration: 0.0 20557.75
# Left duration: 0.0 20557.9375
# [[9.8581480e+03 1.1303672e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [1.7089920e+04 1.7204243e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]]
#
# Subject, Sess, Code:  7 1 103
# Resampling... Rate: 16
# Old start, end: 0.0, 49933.128138474
# New start, end: 0.0, 49933.128138474
# Sample Count old, new: 713817, 798931
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 49932.943507146
# New start, end: 0.0, 49932.943507146
# Sample Count old, new: 714213, 798928
# Resampling Done
# Right duration: 0.0 49933.125
# Left duration: 0.0 49932.9375
# [[2.45956160e+04 2.48991310e+04 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [3.97127219e+04 3.98224719e+04 0.00000000e+00 0.00000000e+00
#   2.00000000e+00]
#  [4.75683709e+04 4.84087579e+04 0.00000000e+00 0.00000000e+00
#   2.00000000e+00]]
#
# Subject, Sess, Code:  8 0 104
# Resampling... Rate: 16
# Old start, end: 0.0, 38377.338769308
# New start, end: 0.0, 38377.338769308
# Sample Count old, new: 548972, 614038
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 38377.00368985
# New start, end: 0.0, 38377.00368985
# Sample Count old, new: 548539, 614033
# Resampling Done
# Right duration: 0.0 38377.3125
# Left duration: 0.0 38377.0
# [[5.7530850e+03 5.9829250e+03 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [6.1938500e+03 8.6891750e+03 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.0419755e+04 1.4203466e+04 0.0000000e+00 0.0000000e+00 3.0000000e+00]
#  [1.4513638e+04 1.5766317e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.9553908e+04 1.9751290e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.5552586e+04 2.5844010e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.8070007e+04 2.8601532e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]]
#
# Subject, Sess, Code:  8 1 104
# Resampling... Rate: 16
# Old start, end: 0.0, 40106.189417588
# New start, end: 0.0, 40106.189417588
# Sample Count old, new: 573211, 641700
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 40106.596125512
# New start, end: 0.0, 40106.596125512
# Sample Count old, new: 572774, 641706
# Resampling Done
# Right duration: 0.0 40106.1875
# Left duration: 0.0 40106.5625
# [[9.1378770e+03 1.0209995e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.0948065e+04 1.1092302e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.5492337e+04 2.7098156e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [3.3923355e+04 3.4442862e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]]
#
# Subject, Sess, Code:  9 0 107
# Resampling... Rate: 16
# Old start, end: 0.0, 33252.021267668
# New start, end: 0.0, 33252.021267668
# Sample Count old, new: 475539, 532033
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 33252.10151928
# New start, end: 0.0, 33252.10151928
# Sample Count old, new: 475255, 532034
# Resampling Done
# .................................
# Right: Adjusted Meal end time is greater than data end time:  33252.0 34783.3769592
# ..................................
# .................................
# Left: Adjusted Meal end time is greater than data end time:  33252.0625 34783.3769592
# ..................................
# Right duration: 0.0 33252.0
# Left duration: 0.0 33252.0625
# [[1.2124327e+04 1.3300530e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.9606142e+04 1.9754326e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.4493636e+04 2.4799432e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [3.3050931e+04 3.4783377e+04 3.3252000e+04 3.3252000e+04 1.0000000e+00]]
#
# Subject, Sess, Code:  9 1 107
# Resampling... Rate: 16
# Old start, end: 0.0, 34196.310475865
# New start, end: 0.0, 34196.310475865
# Sample Count old, new: 488825, 547141
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 34196.505030395
# New start, end: 0.0, 34196.505030395
# Sample Count old, new: 489104, 547145
# Resampling Done
# Right duration: 0.0 34196.25
# Left duration: 0.0 34196.5
# [[9.6551490e+03 1.0054891e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.6770461e+04 1.7219482e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [3.2546079e+04 3.3632431e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  9 2 107
# Resampling... Rate: 16
# Old start, end: 0.0, 34244.07989093
# New start, end: 0.0, 34244.07989093
# Sample Count old, new: 489752, 547906
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 34244.222326972
# New start, end: 0.0, 34244.222326972
# Sample Count old, new: 489591, 547908
# Resampling Done
# .................................
# Right: Adjusted Meal end time is greater than data end time:  34244.0625 34317.1959592
# ..................................
# .................................
# Left: Adjusted Meal end time is greater than data end time:  34244.1875 34317.1959592
# ..................................
# Right duration: 0.0 34244.0625
# Left duration: 0.0 34244.1875
# [[2.10289330e+04 2.31062790e+04 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [2.85438680e+04 2.87291090e+04 0.00000000e+00 0.00000000e+00
#   2.00000000e+00]
#  [3.15235620e+04 3.17431140e+04 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [3.37563480e+04 3.43171960e+04 3.42440625e+04 3.42440625e+04
#   1.00000000e+00]]
#
# Subject, Sess, Code:  9 3 107
# Resampling... Rate: 16
# Old start, end: 0.0, 35921.861299408
# New start, end: 0.0, 35921.861299408
# Sample Count old, new: 513536, 574750
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 35921.80769877
# New start, end: 0.0, 35921.80769877
# Sample Count old, new: 513817, 574749
# Resampling Done
# Right duration: 0.0 35921.8125
# Left duration: 0.0 35921.75
# [[1.2130541e+04 1.3306548e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.5528844e+04 1.5875132e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.3388175e+04 2.4115559e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]]
#
# Subject, Sess, Code:  9 4 107
# Resampling... Rate: 16
# Old start, end: 0.0, 25377.810702188
# New start, end: 0.0, 25377.810702188
# Sample Count old, new: 363067, 406045
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 25377.73237111
# New start, end: 0.0, 25377.73237111
# Sample Count old, new: 362826, 406044
# Resampling Done
# Right duration: 0.0 25377.75
# Left duration: 0.0 25377.6875
# [[2.3857302e+04 2.4917263e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  10 0 109
# Resampling... Rate: 16
# Old start, end: 0.0, 34720.474778052
# New start, end: 0.0, 34720.474778052
# Sample Count old, new: 496343, 555528
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 34720.316487724
# New start, end: 0.0, 34720.316487724
# Sample Count old, new: 496629, 555526
# Resampling Done
# Right duration: 0.0 34720.4375
# Left duration: 0.0 34720.3125
# [[5.4442410e+03 6.1962600e+03 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [1.1552410e+04 1.1865398e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [2.3050319e+04 2.3737371e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [3.2774131e+04 3.4545210e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]]
#
# Subject, Sess, Code:  10 1 109
# Resampling... Rate: 16
# Old start, end: 0.0, 41818.580803762
# New start, end: 0.0, 41818.580803762
# Sample Count old, new: 597646, 669098
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 41819.246695548
# New start, end: 0.0, 41819.246695548
# Sample Count old, new: 597178, 669108
# Resampling Done
# Right duration: 0.0 41818.5625
# Left duration: 0.0 41819.1875
# [[1.0227114e+04 1.1213858e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]
#  [1.5795702e+04 1.6801503e+04 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [2.2154844e+04 2.3848830e+04 0.0000000e+00 0.0000000e+00 2.0000000e+00]]

# %%
with open('C:/ASM/DevData/eating_steven/data/free/steven_data_free_right.pkl', 'wb') as file:
    pickle.dump(data_right, file)
    
with open('C:/ASM/DevData/eating_steven/data/free/steven_data_free_left.pkl', 'wb') as file:
    pickle.dump(data_left, file)
    
with open('C:/ASM/DevData/eating_steven/data/free/steven_data_free_annots.pkl', 'wb') as file:
    pickle.dump(data_annots, file)
