# %%
import numpy as np
import pickle
import os
import sys
import data_process_utils as dpu

# %%
def process_annot_line(line):
    line = line.replace("DR","11").replace("DL","12")
    line = line.replace("PR","21").replace("PL","22")    
    line = line.replace("NR","31").replace("NL","32")
    line = line.replace("I","1").replace("Q","2")
    line = line.replace("C","-1").replace("S","-2").replace("M","-3").replace('X', '-100')    
    
    v = line.rstrip().split(',')    
    v = [float(x) for x in v]
    return v

# %%
def process_bite_annots_steven(filepath):
    a = open(filepath).readlines()
    a = [process_annot_line(line) for line in a]
    a = np.array(a)
    
    cond = (a[:, 2]>0) & (a[:, 2]<20)
    original_index = np.arange(len(a))[cond]  
    a = a[cond]
    
    
    acount = len(a)        
    for i in range(acount-1):
        if a[i, 2]==21 and a[i+1, 2]!=22 and a[i+1,2]!=1 and a[i+1,2]!=2:
            print("@@@@@@@@@@@@@@@@@@ Right Sequence Problem at ", i, oi[i])
            
        elif a[i, 2]==22 and a[i+1, 2]!=21 and a[i+1,2]!=1 and a[i+1,2]!=2:    
            print("@@@@@@@@@@@@@@@@@@@@@ Left Sequence Problem at ", i, oi[i])                
    
    i = 0        
    last_was_bite = True
    last_bite_time = 0
    hand = 0
    repeat_count = 0
    
    annots = []        
    for i in range(len(a)):
        if a[i, 2]==11 or a[i, 2]==12:
            if last_was_bite:
                hand = a[i, 2]-10
            else:                
                hand =3                
                if a[i, 0]-a[i-1,0]>1:
                    print("$$$$$$$$$$$$$$$$$$$$$$ Both hand synchronization problem $$$$$$$$$$$$$$$$$$$$$")
                    print("Both hands at index:", original_index[i], ", Time difference: ", a[i, 0]-a[i-1,0])

            last_was_bite = False
            repeat_count = 0

        elif a[i, 2]==1 or a[i, 2]==2:
            r = [a[i,0], a[i,1], a[i,2], hand, 0]
            
            if last_was_bite:
                if hand==0:
                    print("%%%%%%%%%%%%%%%%%%% No hand found**************", i, )
                    r[-1] = -1
                else:
                    repeat_count +=1
                    r[-1] = repeat_count
                    print("*** Repeated at ix:{}, Time:{}, Bite/Sip:{}, hand:{}, interval:{}, repeat_count:{}".format(original_index[i], int(a[i,0]), a[i, 2], hand, int(a[i,0]-last_bite_time),  r[-1]))                    
                
            annots.append(r)                
            last_was_bite = True
            last_bite_time = a[i, 0]
                      
        else:
            print("##### Condition Problem ###########")
            sys.exit(0)
           
    annots = np.array(annots)        
    annots[:,1]= (annots[:,0]+annots[:,1])*16
    annots[:,0]= annots[:,0]*16
    
    return annots.astype(int)

# %%
def process_data_steven(filepath, sampling_rate = 16, time_problem_index=-1):
    d = np.genfromtxt(filepath, delimiter=',')
    d[:, 0] = d[:, 0]/1e9
    
    if time_problem_index>0:
        ix = time_problem_index
        d[ix:, 0] = d[ix-1, 0] + (d[ix:, 0] - d[ix, 0]) + (d[ix-1, 0]-d[ix-2, 0])        
    
    for i in range(1, len(d)):
        if d[i, 0] - d[i-1, 0]>2:
            print("TTTTTTTTTTTTTTT data time distance is very high, at index:{}, distance:{}".format(i, d[i, 0] - d[i-1, 0]))
    
    time_accel_gyro = d[:, :7]
    quat = d[:, -3:]
    _ , _ , grav = dpu.quat2mat(quat)

    d = np.concatenate((time_accel_gyro, grav), axis=1)
    d = dpu.resample(d, sampling_rate)
    
    return d

# %%
#read_data_steven_lab

path = 'C:/ASM/PublicData/eating_steventech/lab'
sampling_rate = 16 #Hz
data = []

for subj in range(7):
    dsubject=[]
    for sess in range(2):
        if subj==1 and sess==1:
            continue

        print("\n\nSubject, Sess ", subj, sess)
        print("-------------------")
        
        print("====== Right Hand =====")
        filepath = path + "/0" + str(subj) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv"
        if subj==0 and sess==0:
            dr = process_data_steven(filepath, time_problem_index=14827)
        else:
            dr = process_data_steven(filepath)
            
        print("====== Left Hand =====")
        filepath = path + "/0" + str(subj) + "/000" + str(sess) + "/watch_left_000" + str(sess) + ".csv"
        dl = process_data_steven(filepath)
                
        print("====== Annotations =====")
        filepath= path + "/0" + str(subj) + "/000" + str(sess) + "/annot_events.csv";
        a = process_bite_annots_steven(filepath)
        
        dsubject.append({"data_right":dr, "data_left":dl, "annots":a})
        
        print("Data Right Range: {} - {}, sample count, rate: {}, {}".format(dr[0,0], dr[-1,0], len(dr), len(dr)/dr[-1,0]))
        print("Data Left Range : {} - {}, sample count, rate: {}, {}".format(dl[0,0], dl[-1,0], len(dl), len(dl)/dl[-1,0]))        
        print("Annot Range     : {} - {}, Annot count: {}, ".format(a[0,0]/16, a[-1,0]/16, len(a)))
        
        if dr[-1, 0]<a[-1,0]/16:
            print("XXXXXXXXXXXX Annot out of data range right hand")
        #if dl[0,0]>a[0,0] or dl[-1, 0]<a[-1,0]:
        #   print("XXXXXXXXXXXX Annot out of data range left hand")        
        
    data.append(dsubject)
    
with open('C:/ASM/DevData/eating_steven/data/lab_data_steven.pkl', 'wb') as file:
    pickle.dump(data, file)
# Out:
# Subject, Sess  0 0
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 22749.07175797757
# New start, end: 0.0, 22749.07175797757
# Sample Count old, new: 376378, 363986
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 22748.846600419
# New start, end: 0.0, 22748.846600419
# Sample Count old, new: 363105, 363982
# Resampling Done
# ====== Annotations =====
# Data Right Range: 0.0 - 22749.0625, sample count, rate: 363986, 16.000043957855407
# Data Left Range : 0.0 - 22748.8125, sample count, rate: 363982, 16.000043958338484
# Annot Range     : 560.375 - 21148.0625, Annot count: 155,
#
#
# Subject, Sess  0 1
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 23392.876031962
# New start, end: 0.0, 23392.876031962
# Sample Count old, new: 384325, 374287
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 23391.161307121
# New start, end: 0.0, 23391.161307121
# Sample Count old, new: 342764, 374259
# Resampling Done
# ====== Annotations =====
# *** Repeated at ix:2733, Time:12324, Bite/Sip:2.0, hand:1.0, interval:200, repeat_count:1
# *** Repeated at ix:2774, Time:12867, Bite/Sip:2.0, hand:3, interval:7, repeat_count:1
# *** Repeated at ix:2777, Time:12888, Bite/Sip:2.0, hand:3, interval:20, repeat_count:2
# *** Repeated at ix:2789, Time:12988, Bite/Sip:2.0, hand:1.0, interval:9, repeat_count:1
# Data Right Range: 0.0 - 23392.875, sample count, rate: 374287, 16.00004274805897
# Data Left Range : 0.0 - 23391.125, sample count, rate: 374259, 16.000042751257155
# Annot Range     : 451.4375 - 23158.0, Annot count: 395,
#
#
# Subject, Sess  1 0
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21589.856691755
# New start, end: 0.0, 21589.856691755
# Sample Count old, new: 311146, 345438
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21589.896660272
# New start, end: 0.0, 21589.896660272
# Sample Count old, new: 336179, 345439
# Resampling Done
# ====== Annotations =====
# Data Right Range: 0.0 - 21589.8125, sample count, rate: 345438, 16.000046318141948
# Data Left Range : 0.0 - 21589.875, sample count, rate: 345439, 16.00004631800786
# Annot Range     : 9463.25 - 20629.0, Annot count: 42,
#
#
# Subject, Sess  2 0
# -------------------
# ====== Right Hand =====
# TTTTTTTTTTTTTTT data time distance is very high, at index:132984, distance:191.65884885500054
# Resampling... Rate: 16
# Old start, end: 0.0, 22952.615783612
# New start, end: 0.0, 22952.615783612
# Sample Count old, new: 328534, 367242
# Resampling Done
# ====== Left Hand =====
# TTTTTTTTTTTTTTT data time distance is very high, at index:71971, distance:3610.4552900120007
# Resampling... Rate: 16
# Old start, end: 0.0, 22952.781790098
# New start, end: 0.0, 22952.781790098
# Sample Count old, new: 290942, 367245
# Resampling Done
# ====== Annotations =====
# Data Right Range: 0.0 - 22952.5625, sample count, rate: 367242, 16.000043568120116
# Data Left Range : 0.0 - 22952.75, sample count, rate: 367245, 16.000043567764212
# Annot Range     : 569.25 - 21164.3125, Annot count: 153,
#
#
# Subject, Sess  2 1
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21210.229435535
# New start, end: 0.0, 21210.229435535
# Sample Count old, new: 348846, 339364
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21210.375999317
# New start, end: 0.0, 21210.375999317
# Sample Count old, new: 324340, 339367
# Resampling Done
# ====== Annotations =====
# Data Right Range: 0.0 - 21210.1875, sample count, rate: 339364, 16.00004714715511
# Data Left Range : 0.0 - 21210.375, sample count, rate: 339367, 16.00004714673833
# Annot Range     : 311.375 - 20366.625, Annot count: 144,
#
#
# Subject, Sess  3 0
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21956.307458528
# New start, end: 0.0, 21956.307458528
# Sample Count old, new: 328777, 351301
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21956.371983704
# New start, end: 0.0, 21956.371983704
# Sample Count old, new: 316908, 351302
# Resampling Done
# ====== Annotations =====
# *** Repeated at ix:902, Time:8795, Bite/Sip:1.0, hand:1.0, interval:11, repeat_count:1
# *** Repeated at ix:1006, Time:8924, Bite/Sip:1.0, hand:3, interval:1, repeat_count:1
# $$$$$$$$$$$$$$$$$$$$$$ Both hand synchronization problem $$$$$$$$$$$$$$$$$$$$$
# Both hands at index: 1503 , Time difference:  1.1711442899995745
# *** Repeated at ix:1718, Time:9772, Bite/Sip:1.0, hand:1.0, interval:1, repeat_count:1
# Data Right Range: 0.0 - 21956.25, sample count, rate: 351301, 16.000045545118134
# Data Left Range : 0.0 - 21956.3125, sample count, rate: 351302, 16.000045544988485
# Annot Range     : 258.3125 - 13295.375, Annot count: 167,
#
#
# Subject, Sess  3 1
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21660.930195068
# New start, end: 0.0, 21660.930195068
# Sample Count old, new: 340920, 346575
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21661.010377525
# New start, end: 0.0, 21661.010377525
# Sample Count old, new: 311746, 346577
# Resampling Done
# ====== Annotations =====
# *** Repeated at ix:151, Time:1055, Bite/Sip:1.0, hand:1.0, interval:13, repeat_count:1
# *** Repeated at ix:187, Time:1105, Bite/Sip:1.0, hand:1.0, interval:22, repeat_count:1
# *** Repeated at ix:198, Time:1119, Bite/Sip:1.0, hand:1.0, interval:13, repeat_count:2
# *** Repeated at ix:205, Time:1131, Bite/Sip:1.0, hand:1.0, interval:12, repeat_count:3
# *** Repeated at ix:242, Time:1193, Bite/Sip:1.0, hand:1.0, interval:8, repeat_count:1
# *** Repeated at ix:289, Time:1313, Bite/Sip:2.0, hand:1.0, interval:20, repeat_count:1
# *** Repeated at ix:304, Time:2680, Bite/Sip:2.0, hand:1.0, interval:1321, repeat_count:1
# *** Repeated at ix:307, Time:4462, Bite/Sip:2.0, hand:1.0, interval:1781, repeat_count:2
# *** Repeated at ix:308, Time:7871, Bite/Sip:2.0, hand:1.0, interval:3409, repeat_count:3
# *** Repeated at ix:309, Time:7885, Bite/Sip:1.0, hand:1.0, interval:13, repeat_count:4
# *** Repeated at ix:432, Time:8028, Bite/Sip:1.0, hand:3, interval:16, repeat_count:1
# *** Repeated at ix:481, Time:8116, Bite/Sip:2.0, hand:3, interval:27, repeat_count:1
# *** Repeated at ix:593, Time:8278, Bite/Sip:2.0, hand:3, interval:23, repeat_count:1
# *** Repeated at ix:684, Time:8416, Bite/Sip:1.0, hand:1.0, interval:10, repeat_count:1
# *** Repeated at ix:698, Time:8431, Bite/Sip:1.0, hand:1.0, interval:5, repeat_count:1
# *** Repeated at ix:731, Time:8458, Bite/Sip:2.0, hand:1.0, interval:5, repeat_count:1
# *** Repeated at ix:765, Time:21015, Bite/Sip:1.0, hand:1.0, interval:8, repeat_count:1
# *** Repeated at ix:766, Time:21028, Bite/Sip:1.0, hand:1.0, interval:13, repeat_count:2
# *** Repeated at ix:780, Time:21075, Bite/Sip:1.0, hand:1.0, interval:6, repeat_count:1
# *** Repeated at ix:783, Time:21102, Bite/Sip:1.0, hand:1.0, interval:13, repeat_count:1
# *** Repeated at ix:786, Time:21126, Bite/Sip:1.0, hand:1.0, interval:13, repeat_count:1
# *** Repeated at ix:794, Time:21162, Bite/Sip:1.0, hand:1.0, interval:7, repeat_count:1
# Data Right Range: 0.0 - 21660.875, sample count, rate: 346575, 16.00004616618673
# Data Left Range : 0.0 - 21661.0, sample count, rate: 346577, 16.000046165920317
# Annot Range     : 794.0 - 21480.6875, Annot count: 120,
#
#
# Subject, Sess  4 0
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21973.69046151
# New start, end: 0.0, 21973.69046151
# Sample Count old, new: 361588, 351580
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21973.674972448
# New start, end: 0.0, 21973.674972448
# Sample Count old, new: 333863, 351579
# Resampling Done
# ====== Annotations =====
# Data Right Range: 0.0 - 21973.6875, sample count, rate: 351580, 16.000045508975223
# Data Left Range : 0.0 - 21973.625, sample count, rate: 351579, 16.000045509104666
# Annot Range     : 225.6875 - 9689.75, Annot count: 188,
#
#
# Subject, Sess  4 1
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21648.58893313
# New start, end: 0.0, 21648.58893313
# Sample Count old, new: 316032, 346378
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21648.642594219
# New start, end: 0.0, 21648.642594219
# Sample Count old, new: 311726, 346379
# Resampling Done
# ====== Annotations =====
# %%%%%%%%%%%%%%%%%%% No hand found************** 0
# *** Repeated at ix:116, Time:490, Bite/Sip:2.0, hand:3, interval:18, repeat_count:1
# *** Repeated at ix:262, Time:612, Bite/Sip:2.0, hand:3, interval:29, repeat_count:1
# *** Repeated at ix:273, Time:623, Bite/Sip:2.0, hand:3, interval:10, repeat_count:2
# *** Repeated at ix:390, Time:713, Bite/Sip:2.0, hand:3, interval:24, repeat_count:1
# *** Repeated at ix:576, Time:862, Bite/Sip:2.0, hand:3, interval:19, repeat_count:1
# *** Repeated at ix:727, Time:999, Bite/Sip:2.0, hand:3, interval:17, repeat_count:1
# *** Repeated at ix:871, Time:1118, Bite/Sip:2.0, hand:3, interval:18, repeat_count:1
# *** Repeated at ix:875, Time:1122, Bite/Sip:2.0, hand:3, interval:4, repeat_count:2
# *** Repeated at ix:1001, Time:1217, Bite/Sip:2.0, hand:3, interval:24, repeat_count:1
# *** Repeated at ix:1142, Time:1327, Bite/Sip:2.0, hand:3, interval:15, repeat_count:1
# *** Repeated at ix:1261, Time:1406, Bite/Sip:2.0, hand:3, interval:30, repeat_count:1
# *** Repeated at ix:1351, Time:1472, Bite/Sip:2.0, hand:1.0, interval:47, repeat_count:1
# *** Repeated at ix:1367, Time:1485, Bite/Sip:2.0, hand:1.0, interval:13, repeat_count:2
# *** Repeated at ix:1378, Time:1536, Bite/Sip:2.0, hand:1.0, interval:51, repeat_count:3
# *** Repeated at ix:1382, Time:1544, Bite/Sip:2.0, hand:1.0, interval:7, repeat_count:4
# *** Repeated at ix:1387, Time:1556, Bite/Sip:2.0, hand:1.0, interval:12, repeat_count:5
# *** Repeated at ix:1510, Time:19689, Bite/Sip:2.0, hand:1.0, interval:39, repeat_count:1
# *** Repeated at ix:1811, Time:19950, Bite/Sip:2.0, hand:1.0, interval:10, repeat_count:1
# Data Right Range: 0.0 - 21648.5625, sample count, rate: 346378, 16.000046192443495
# Data Left Range : 0.0 - 21648.625, sample count, rate: 346379, 16.000046192310137
# Annot Range     : 393.5625 - 20287.1875, Annot count: 92,
#
#
# Subject, Sess  5 0
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21246.994216869
# New start, end: 0.0, 21246.994216869
# Sample Count old, new: 332938, 339952
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21247.032277113
# New start, end: 0.0, 21247.032277113
# Sample Count old, new: 336878, 339953
# Resampling Done
# ====== Annotations =====
# *** Repeated at ix:2466, Time:13751, Bite/Sip:2.0, hand:1.0, interval:32, repeat_count:1
# Data Right Range: 0.0 - 21246.9375, sample count, rate: 339952, 16.000047065606513
# Data Left Range : 0.0 - 21247.0, sample count, rate: 339953, 16.000047065468067
# Annot Range     : 497.0 - 13751.875, Annot count: 121,
#
#
# Subject, Sess  5 1
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 22633.58737429
# New start, end: 0.0, 22633.58737429
# Sample Count old, new: 326227, 362138
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 22632.073054421
# New start, end: 0.0, 22632.073054421
# Sample Count old, new: 367228, 362114
# Resampling Done
# ====== Annotations =====
# $$$$$$$$$$$$$$$$$$$$$$ Both hand synchronization problem $$$$$$$$$$$$$$$$$$$$$
# Both hands at index: 1677 , Time difference:  1.532999999999447
# Data Right Range: 0.0 - 22633.5625, sample count, rate: 362138, 16.00004418217415
# Data Left Range : 0.0 - 22632.0625, sample count, rate: 362114, 16.00004418510244
# Annot Range     : 1394.0 - 21849.0, Annot count: 107,
#
#
# Subject, Sess  6 0
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21345.416743663
# New start, end: 0.0, 21345.416743663
# Sample Count old, new: 330052, 341527
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21345.560609729
# New start, end: 0.0, 21345.560609729
# Sample Count old, new: 329767, 341529
# Resampling Done
# ====== Annotations =====
# $$$$$$$$$$$$$$$$$$$$$$ Both hand synchronization problem $$$$$$$$$$$$$$$$$$$$$
# Both hands at index: 285 , Time difference:  1.25
# $$$$$$$$$$$$$$$$$$$$$$ Both hand synchronization problem $$$$$$$$$$$$$$$$$$$$$
# Both hands at index: 341 , Time difference:  1.7578867000001992
# Data Right Range: 0.0 - 21345.375, sample count, rate: 341527, 16.000046848556185
# Data Left Range : 0.0 - 21345.5, sample count, rate: 341529, 16.00004684828184
# Annot Range     : 287.4375 - 21076.5, Annot count: 48,
#
#
# Subject, Sess  6 1
# -------------------
# ====== Right Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21162.957109064
# New start, end: 0.0, 21162.957109064
# Sample Count old, new: 348741, 338608
# Resampling Done
# ====== Left Hand =====
# Resampling... Rate: 16
# Old start, end: 0.0, 21163.018382863
# New start, end: 0.0, 21163.018382863
# Sample Count old, new: 327863, 338609
# Resampling Done
# ====== Annotations =====
# Data Right Range: 0.0 - 21162.9375, sample count, rate: 338608, 16.00004725241947
# Data Left Range : 0.0 - 21163.0, sample count, rate: 338609, 16.000047252279924
# Annot Range     : 272.5625 - 13869.875, Annot count: 89,
