# %%
import numpy as np
import pickle
import os
import sys

# %%
util_path = 'C:/ASM/Dropbox/Developments/Jupyter/Eating/myutils' if 'C:' in os.getcwd() else './myutils'
sys.path.append(util_path)
import my_file_utils as mfu
import my_data_process_utils as mdpu

# %%
def get_meal_code(meal):    
    code = -1
    if meal == "meal" or meal=="lunch" or meal=="dinner":
        code = 1
    elif meal=="snack":
        code = 2    
    elif meal=="drink":
        code = 3
    elif meal=="eat":
        code = 4
    return code

def process_meal_annots(annots, subject_code, session, sampling_rate):
    meal_count = len(annots)
    '''
    if subject_code == 5 and session == 0:
        meal_count = 9
    elif subject_code == 6 and session == 0:
        meal_count = 2
    elif subject_code == 102 and session == 1:
        meal_count = 1
    elif subject_code == 104 and session == 0:
        meal_count = 7
    '''
    
    j = 0
    a = np.zeros((meal_count, 3))
    for i in range(meal_count):        
        s = annots[i].split(",")
        a[i, 0] = float(s[1].rstrip())*sampling_rate
        a[i, 1] = float(s[2].rstrip())*sampling_rate       
        a[i, 2] = get_meal_code(s[3].rstrip().strip())        
        assert a[i, 2]!=-1
        a = a.astype(int)
        
    return a

# %%
path = 'C:/ASM/PublicData/eating_steventech/free'
sampling_rate = 16 #Hz
data_right = []
data_left = []
data_annots = []

subject_codes = [2, 3, 4, 5, 6, 101, 102, 103, 104, 107, 109]
for subject in range(len(subject_codes)):
    drs, dls, das = [], [], []
    sess_count = 2
    if subject_codes[subject] == 107:
        sess_count = 5

    for sess in range(sess_count):
        print('\nSubject, Sess, Code: ', subject, sess, subject_codes[subject])
        
        if subject_codes[subject] < 10:
            path_right = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv"
            path_left = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_left_000" + str(sess) + ".csv"
            path_annot = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/meal_events.csv"
        elif subject_codes[subject] == 109:
            path_right = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/watch_right_000" + str(sess+3) + ".csv"
            path_left = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/watch_left_000" + str(sess+3) + ".csv"
            path_annot = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/meal_events.csv"
        else:
            path_right = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv"
            path_left = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_left_000" + str(sess) + ".csv"
            path_annot = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/meal_events.csv"

        d = np.genfromtxt(path_right, delimiter=',')
        d[:, 0] = d[:, 0]/1e9        
        time_accel_gyro = d[:, :7]
        quat = d[:, -3:]
        _ , _ , grav = mdpu.quat2mat(quat)
        linaccel = time_accel_gyro[:, 1:4] - (grav*9.81)
        
        d = np.concatenate((time_accel_gyro, linaccel, grav), axis=1)
        dr = mdpu.resample(d, sampling_rate)
        
        
        d = np.genfromtxt(path_left, delimiter=',')            
        d[:, 0] = d[:, 0]/1e9        
        time_accel_gyro = d[:, :7]
        quat = d[:, -3:]
        _ , _ , grav = mdpu.quat2mat(quat)
        linaccel = time_accel_gyro[:, 1:4] - (grav*9.81)
        
        d = np.concatenate((time_accel_gyro, linaccel, grav), axis=1)
        dl = mdpu.resample(d, sampling_rate)        

        with open(path_annot) as file:            
            annots = file.readlines()
        da = process_meal_annots(annots,subject_codes[subject], sess, sampling_rate)        
        
        print("Right duration:", dr[0,0], dr[-1,0])
        print("Left duration:", dl[0,0], dl[-1,0])
        print(da)
        
        drs.append(dr)
        dls.append(dl)
        das.append(da)        

    data_right.append(drs)
    data_left.append(dls)
    data_annots.append(das)
# Out:
# Subject, Sess, Code:  0 0 2
# Resampling... Rate: 16
# Old start, end: 0.0, 40424.529486105
# New start, end: 0.0, 40424.529486105
# Sample Count old, new: 725551, 646793
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 37720.452365426
# New start, end: 0.0, 37720.452365426
# Sample Count old, new: 625128, 603528
# Resampling Done
# Right duration: 0.0 40424.5
# Left duration: 0.0 37720.4375
# [[ 12888  18831      1]
#  [ 77231  78175      3]
#  [294585 322326      1]]
#
# Subject, Sess, Code:  0 1 2
# Resampling... Rate: 16
# Old start, end: 0.0, 38185.645249663
# New start, end: 0.0, 38185.645249663
# Sample Count old, new: 550555, 610971
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 33380.66305363
# New start, end: 0.0, 33380.66305363
# Sample Count old, new: 559858, 534091
# Resampling Done
# Right duration: 0.0 38185.625
# Left duration: 0.0 33380.625
# [[ 33449  44378      1]
#  [132596 133317      3]
#  [310975 321961      1]
#  [399570 400600      3]
#  [479052 479898      3]]
#
# Subject, Sess, Code:  1 0 3
# Resampling... Rate: 16
# Old start, end: 0.0, 36606.720713365
# New start, end: 0.0, 36606.720713365
# Sample Count old, new: 560364, 585708
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 36664.635614539
# New start, end: 0.0, 36664.635614539
# Sample Count old, new: 584168, 586635
# Resampling Done
# Right duration: 0.0 36606.6875
# Left duration: 0.0 36664.625
# [[  6227  21141      1]
#  [160056 188427      1]
#  [391718 425447      1]
#  [445180 445349      2]
#  [524971 526449      2]]
#
# Subject, Sess, Code:  1 1 3
# Resampling... Rate: 16
# Old start, end: 0.0, 37048.309772182
# New start, end: 0.0, 37048.309772182
# Sample Count old, new: 621551, 592773
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 37076.986728804
# New start, end: 0.0, 37076.986728804
# Sample Count old, new: 588543, 593232
# Resampling Done
# Right duration: 0.0 37048.25
# Left duration: 0.0 37076.9375
# [[  1748  13097      1]
#  [104940 162037      3]
#  [186266 207040      1]
#  [305368 311867      2]
#  [326858 332171      2]
#  [353136 353946      2]
#  [434223 449706      1]]
#
# Subject, Sess, Code:  2 0 4
# Resampling... Rate: 16
# Old start, end: 0.0, 43250.163293218
# New start, end: 0.0, 43250.163293218
# Sample Count old, new: 684553, 692003
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 38298.642482422
# New start, end: 0.0, 38298.642482422
# Sample Count old, new: 602478, 612779
# Resampling Done
# Right duration: 0.0 43250.125
# Left duration: 0.0 38298.625
# [[ 97354  97936      3]
#  [190394 199747      1]
#  [204272 219417      1]
#  [427270 427848      3]
#  [509260 528078      1]
#  [531063 537321      2]]
#
# Subject, Sess, Code:  2 1 4
# Resampling... Rate: 16
# Old start, end: 0.0, 42140.966948984
# New start, end: 0.0, 42140.966948984
# Sample Count old, new: 684200, 674256
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 39735.993622476
# New start, end: 0.0, 39735.993622476
# Sample Count old, new: 574563, 635776
# Resampling Done
# Right duration: 0.0 42140.9375
# Left duration: 0.0 39735.9375
# [[ 14731  32731      1]
#  [ 84414  87196      3]
#  [226959 227603      3]
#  [318387 341274      1]
#  [358034 362219      3]
#  [416034 416204      3]
#  [465868 466042      3]
#  [606418 618680      1]]
#
# Subject, Sess, Code:  3 0 5
# Resampling... Rate: 16
# Old start, end: 0.0, 25196.418970225
# New start, end: 0.0, 25196.418970225
# Sample Count old, new: 390566, 403143
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 25196.497072002
# New start, end: 0.0, 25196.497072002
# Sample Count old, new: 389217, 403144
# Resampling Done
# Right duration: 0.0 25196.375
# Left duration: 0.0 25196.4375
# [[ 26892  47475      1]
#  [ 77834  84617      3]
#  [101054 101232      3]
#  [102393 106974      2]
#  [247916 248181      3]
#  [322809 323014      3]
#  [352224 356366      1]
#  [357805 366006      1]
#  [367497 369992      1]
#  [441640 441881      3]
#  [444196 452173      4]]
#
# Subject, Sess, Code:  3 1 5
# Resampling... Rate: 16
# Old start, end: 0.0, 28720.781611331
# New start, end: 0.0, 28720.781611331
# Sample Count old, new: 479233, 459533
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 28719.676122151
# New start, end: 0.0, 28719.676122151
# Sample Count old, new: 477650, 459515
# Resampling Done
# Right duration: 0.0 28720.75
# Left duration: 0.0 28719.625
# [[ 42552  56759      1]
#  [ 58609  61463      2]
#  [ 70710  70846      3]
#  [146418 146637      3]
#  [219604 223034      2]
#  [225493 230148      2]]
#
# Subject, Sess, Code:  4 0 6
# Resampling... Rate: 16
# Old start, end: 0.0, 30691.535907704
# New start, end: 0.0, 30691.535907704
# Sample Count old, new: 570537, 491065
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 30691.569866811
# New start, end: 0.0, 30691.569866811
# Sample Count old, new: 441933, 491066
# Resampling Done
# Right duration: 0.0 30691.5
# Left duration: 0.0 30691.5625
# [[201380 206632      1]
#  [230639 231566      3]
#  [499854 518801      1]]
#
# Subject, Sess, Code:  4 1 6
# Resampling... Rate: 16
# Old start, end: 0.0, 39290.324946087
# New start, end: 0.0, 39290.324946087
# Sample Count old, new: 682979, 628646
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 32498.197883501
# New start, end: 0.0, 32498.197883501
# Sample Count old, new: 570139, 519972
# Resampling Done
# Right duration: 0.0 39290.3125
# Left duration: 0.0 32498.1875
# [[161082 170469      1]
#  [413105 426853      2]
#  [430235 431175      2]
#  [493359 531562      1]]
#
# Subject, Sess, Code:  5 0 101
# Resampling... Rate: 16
# Old start, end: 0.0, 15565.4621878
# New start, end: 0.0, 15565.4621878
# Sample Count old, new: 222602, 249048
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 15565.488496824
# New start, end: 0.0, 15565.488496824
# Sample Count old, new: 222470, 249048
# Resampling Done
# Right duration: 0.0 15565.4375
# Left duration: 0.0 15565.4375
# [[  9447  19584      3]
#  [184069 194449      1]
#  [228986 247263      1]]
#
# Subject, Sess, Code:  5 1 101
# Resampling... Rate: 16
# Old start, end: 0.0, 31624.754389144
# New start, end: 0.0, 31624.754389144
# Sample Count old, new: 452168, 505997
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 31624.660403154
# New start, end: 0.0, 31624.660403154
# Sample Count old, new: 452110, 505995
# Resampling Done
# Right duration: 0.0 31624.75
# Left duration: 0.0 31624.625
# [[ 63114  87909      1]
#  [241813 243513      2]
#  [372908 425371      1]
#  [438441 453328      2]]
#
# Subject, Sess, Code:  6 0 102
# Resampling... Rate: 16
# Old start, end: 0.0, 37010.948657578
# New start, end: 0.0, 37010.948657578
# Sample Count old, new: 529330, 592176
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 37011.603118364
# New start, end: 0.0, 37011.603118364
# Sample Count old, new: 529015, 592186
# Resampling Done
# Right duration: 0.0 37010.9375
# Left duration: 0.0 37011.5625
# [[112278 114795      1]
#  [120320 136426      1]
#  [480687 482987      1]
#  [523129 540779      1]]
#
# Subject, Sess, Code:  6 1 102
# Resampling... Rate: 16
# Old start, end: 0.0, 27208.887866286
# New start, end: 0.0, 27208.887866286
# Sample Count old, new: 389150, 435343
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 27208.458532668
# New start, end: 0.0, 27208.458532668
# Sample Count old, new: 388924, 435336
# Resampling Done
# Right duration: 0.0 27208.875
# Left duration: 0.0 27208.4375
# [[ 92503 108833      1]
#  [436677 447030      1]]
#
# Subject, Sess, Code:  7 0 103
# Resampling... Rate: 16
# Old start, end: 0.0, 20557.79868422
# New start, end: 0.0, 20557.79868422
# Sample Count old, new: 293996, 328925
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 20557.992288946
# New start, end: 0.0, 20557.992288946
# Sample Count old, new: 293826, 328928
# Resampling Done
# Right duration: 0.0 20557.75
# Left duration: 0.0 20557.9375
# [[157730 180858      2]
#  [273438 275267      3]]
#
# Subject, Sess, Code:  7 1 103
# Resampling... Rate: 16
# Old start, end: 0.0, 49933.128138474
# New start, end: 0.0, 49933.128138474
# Sample Count old, new: 713817, 798931
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 49932.943507146
# New start, end: 0.0, 49932.943507146
# Sample Count old, new: 714213, 798928
# Resampling Done
# Right duration: 0.0 49933.125
# Left duration: 0.0 49932.9375
# [[393529 398386      1]
#  [635403 637159      2]
#  [761093 774540      2]]
#
# Subject, Sess, Code:  8 0 104
# Resampling... Rate: 16
# Old start, end: 0.0, 38377.338769308
# New start, end: 0.0, 38377.338769308
# Sample Count old, new: 548972, 614038
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 38377.00368985
# New start, end: 0.0, 38377.00368985
# Sample Count old, new: 548539, 614033
# Resampling Done
# Right duration: 0.0 38377.3125
# Left duration: 0.0 38377.0
# [[ 92049  95726      2]
#  [ 99101 139026      3]
#  [166716 227255      3]
#  [232218 252261      1]
#  [312862 316020      2]
#  [408841 413504      2]
#  [449120 457624      2]
#  [623869 666799      1]]
#
# Subject, Sess, Code:  8 1 104
# Resampling... Rate: 16
# Old start, end: 0.0, 40106.189417588
# New start, end: 0.0, 40106.189417588
# Sample Count old, new: 573211, 641700
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 40106.596125512
# New start, end: 0.0, 40106.596125512
# Sample Count old, new: 572774, 641706
# Resampling Done
# Right duration: 0.0 40106.1875
# Left duration: 0.0 40106.5625
# [[146206 163359      1]
#  [175169 177476      2]
#  [407877 433570      1]
#  [542773 551085      2]]
#
# Subject, Sess, Code:  9 0 107
# Resampling... Rate: 16
# Old start, end: 0.0, 33252.021267668
# New start, end: 0.0, 33252.021267668
# Sample Count old, new: 475539, 532033
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 33252.10151928
# New start, end: 0.0, 33252.10151928
# Sample Count old, new: 475255, 532034
# Resampling Done
# Right duration: 0.0 33252.0
# Left duration: 0.0 33252.0625
# [[193989 212808      1]
#  [313698 316069      2]
#  [391898 396790      2]
#  [528814 556534      1]]
#
# Subject, Sess, Code:  9 1 107
# Resampling... Rate: 16
# Old start, end: 0.0, 34196.310475865
# New start, end: 0.0, 34196.310475865
# Sample Count old, new: 488825, 547141
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 34196.505030395
# New start, end: 0.0, 34196.505030395
# Sample Count old, new: 489104, 547145
# Resampling Done
# Right duration: 0.0 34196.25
# Left duration: 0.0 34196.5
# [[154482 160878      1]
#  [268327 275511      2]
#  [520737 538118      1]]
#
# Subject, Sess, Code:  9 2 107
# Resampling... Rate: 16
# Old start, end: 0.0, 34244.07989093
# New start, end: 0.0, 34244.07989093
# Sample Count old, new: 489752, 547906
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 34244.222326972
# New start, end: 0.0, 34244.222326972
# Sample Count old, new: 489591, 547908
# Resampling Done
# Right duration: 0.0 34244.0625
# Left duration: 0.0 34244.1875
# [[336462 369700      1]
#  [456701 459665      2]
#  [504376 507889      1]
#  [540101 549075      1]]
#
# Subject, Sess, Code:  9 3 107
# Resampling... Rate: 16
# Old start, end: 0.0, 35921.861299408
# New start, end: 0.0, 35921.861299408
# Sample Count old, new: 513536, 574750
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 35921.80769877
# New start, end: 0.0, 35921.80769877
# Sample Count old, new: 513817, 574749
# Resampling Done
# Right duration: 0.0 35921.8125
# Left duration: 0.0 35921.75
# [[194088 212904      1]
#  [248461 254002      2]
#  [374210 385848      2]]
#
# Subject, Sess, Code:  9 4 107
# Resampling... Rate: 16
# Old start, end: 0.0, 25377.810702188
# New start, end: 0.0, 25377.810702188
# Sample Count old, new: 363067, 406045
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 25377.73237111
# New start, end: 0.0, 25377.73237111
# Sample Count old, new: 362826, 406044
# Resampling Done
# Right duration: 0.0 25377.75
# Left duration: 0.0 25377.6875
# [[381716 398676      1]]
#
# Subject, Sess, Code:  10 0 109
# Resampling... Rate: 16
# Old start, end: 0.0, 34720.474778052
# New start, end: 0.0, 34720.474778052
# Sample Count old, new: 496343, 555528
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 34720.316487724
# New start, end: 0.0, 34720.316487724
# Sample Count old, new: 496629, 555526
# Resampling Done
# Right duration: 0.0 34720.4375
# Left duration: 0.0 34720.3125
# [[ 87107  99140      1]
#  [184838 189846      2]
#  [368805 379797      2]
#  [524386 552723      1]]
#
# Subject, Sess, Code:  10 1 109
# Resampling... Rate: 16
# Old start, end: 0.0, 41818.580803762
# New start, end: 0.0, 41818.580803762
# Sample Count old, new: 597646, 669098
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 41819.246695548
# New start, end: 0.0, 41819.246695548
# Sample Count old, new: 597178, 669108
# Resampling Done
# Right duration: 0.0 41818.5625
# Left duration: 0.0 41819.1875
# [[163633 179421      2]
#  [252731 268824      1]
#  [354477 381581      2]]

# %%
mfu.write_file('data', 'free_data_steven_right.pkl', data_right)
mfu.write_file('data', 'free_data_steven_left.pkl', data_left)
mfu.write_file('data', 'free_data_steven_annots.pkl', data_annots)

# %%
print(data_right[0][0].shape)
# Out:
# (646793, 13)
