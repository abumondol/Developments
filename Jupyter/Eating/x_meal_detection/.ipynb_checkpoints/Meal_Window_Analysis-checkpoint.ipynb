# %%
import numpy as np
import pickle
import os
import sys
import importlib

# %%
util_path = 'C:/ASM/Dropbox/Developments/Jupyter/Eating/myutils' if 'C:' in os.getcwd() else './myutils'
sys.path.append(util_path)
import my_file_utils as mfileu
import Meal_Window_Generation_Utils as mwgenu
import my_data_process_utils as mdpu
import my_feature_utils as mfeatu
importlib.reload(mwgenu)
# Out:
# <module 'Meal_Window_Generation_Utils' from 'C:\\ASM\\Dropbox\\Developments\\Jupyter\\Eating\\meal_detection\\Meal_Window_Generation_Utils.py'>

# %%
hand = 'right'
ds = mfileu.read_file('data', 'free_data_steven_'+hand+'.pkl')
annots = mfileu.read_file('data', 'free_data_steven_annots.pkl')

# %%
win_size, step_size = 10*16, 8
params={'win_size':win_size, 'step_size':step_size}

# %%
ixs = mwgenu.get_train_window_indices_all(ds, annots, win_size=win_size, step_size=step_size, blockPrint=False)
# Out:
# Generating train window indices...
#
# Subject, Session:  0 0
# Meal count: 3, Times data, last meal end: 40424, 20145
# [[ 12888  18831      1]
#  [ 77231  78175      3]
#  [294585 322326      1]]
#   Meal 1: 805 - 1176, 1
#   Meal 2: 4826 - 4885, 3
#   Meal 3: 18411 - 20145, 1
# total, onborders: 80830 80713
# Session Shapes window, labels:  (80830, 8) 76502 4210 0 118
# ---------------------------------------------
#
# Subject, Session:  0 1
# Meal count: 5, Times data, last meal end: 38185, 29993
# [[ 33449  44378      1]
#  [132596 133317      3]
#  [310975 321961      1]
#  [399570 400600      3]
#  [479052 479898      3]]
#   Meal 1: 2090 - 2773, 1
#   Meal 2: 8287 - 8332, 3
#   Meal 3: 19435 - 20122, 1
#   Meal 4: 24973 - 25037, 3
#   Meal 5: 29940 - 29993, 3
# total, onborders: 76352 76152
# Session Shapes window, labels:  (76352, 8) 73287 2740 0 325
# ---------------------------------------------
#
# Subject, Session:  1 0
# Meal count: 5, Times data, last meal end: 36606, 32903
# [[  6227  21141      1]
#  [160056 188427      1]
#  [391718 425447      1]
#  [445180 445349      2]
#  [524971 526449      2]]
#   Meal 1: 389 - 1321, 1
#   Meal 2: 10003 - 11776, 1
#   Meal 3: 24482 - 26590, 1
#   Meal 4: 27823 - 27834, 2
#   Meal 5: 32810 - 32903, 2
# total, onborders: 73194 72996
# Session Shapes window, labels:  (73194, 8) 63361 9627 206 0
# ---------------------------------------------
#
# Subject, Session:  1 1
# Meal count: 7, Times data, last meal end: 37048, 28106
# [[  1748  13097      1]
#  [104940 162037      3]
#  [186266 207040      1]
#  [305368 311867      2]
#  [326858 332171      2]
#  [353136 353946      2]
#  [434223 449706      1]]
#   Meal 1: 109 - 818, 1
#   Meal 2: 6558 - 10127, 3
#   Meal 3: 11641 - 12940, 1
#   Meal 4: 19085 - 19491, 2
#   Meal 5: 20428 - 20760, 2
#   Meal 6: 22071 - 22121, 2
#   Meal 7: 27138 - 28106, 1
# total, onborders: 74077 73799
# Session Shapes window, labels:  (74077, 8) 59409 5952 1579 7137
# ---------------------------------------------
#
# Subject, Session:  2 0
# Meal count: 6, Times data, last meal end: 43250, 33582
# [[ 97354  97936      3]
#  [190394 199747      1]
#  [204272 219417      1]
#  [427270 427848      3]
#  [509260 528078      1]
#  [531063 537321      2]]
#   Meal 1: 6084 - 6121, 3
#   Meal 2: 11899 - 12484, 1
#   Meal 3: 12767 - 13713, 1
#   Meal 4: 26704 - 26740, 3
#   Meal 5: 31828 - 33004, 1
#   Meal 6: 33191 - 33582, 2
# total, onborders: 86481 86242
# Session Shapes window, labels:  (86481, 8) 80137 5415 783 146
# ---------------------------------------------
#
# Subject, Session:  2 1
# Meal count: 8, Times data, last meal end: 42141, 38667
# [[ 14731  32731      1]
#  [ 84414  87196      3]
#  [226959 227603      3]
#  [318387 341274      1]
#  [358034 362219      3]
#  [416034 416204      3]
#  [465868 466042      3]
#  [606418 618680      1]]
#   Meal 1: 920 - 2045, 1
#   Meal 2: 5275 - 5449, 3
#   Meal 3: 14184 - 14225, 3
#   Meal 4: 19899 - 21329, 1
#   Meal 5: 22377 - 22638, 3
#   Meal 6: 26002 - 26012, 3
#   Meal 7: 29116 - 29127, 3
#   Meal 8: 37901 - 38667, 1
# total, onborders: 84262 83942
# Session Shapes window, labels:  (84262, 8) 76623 6644 0 995
# ---------------------------------------------
#
# Subject, Session:  3 0
# Annots cut at meal: 10/11, Times data, start: 25196, 27602
# Meal count: 9, Times data, last meal end: 25196, 23124
# [[ 26892  47475      1]
#  [ 77834  84617      3]
#  [101054 101232      3]
#  [102393 106974      2]
#  [247916 248181      3]
#  [322809 323014      3]
#  [352224 356366      1]
#  [357805 366006      1]
#  [367497 369992      1]]
#   Meal 1: 1680 - 2967, 1
#   Meal 2: 4864 - 5288, 3
#   Meal 3: 6315 - 6327, 3
#   Meal 4: 6399 - 6685, 2
#   Meal 5: 15494 - 15511, 3
#   Meal 6: 20175 - 20188, 3
#   Meal 7: 22014 - 22272, 1
#   Meal 8: 22362 - 22875, 1
#   Meal 9: 22968 - 23124, 1
# total, onborders: 50373 50014
# Session Shapes window, labels:  (50373, 8) 44444 4428 572 929
# ---------------------------------------------
#
# Subject, Session:  3 1
# Meal count: 6, Times data, last meal end: 28720, 14384
# [[ 42552  56759      1]
#  [ 58609  61463      2]
#  [ 70710  70846      3]
#  [146418 146637      3]
#  [219604 223034      2]
#  [225493 230148      2]]
#   Meal 1: 2659 - 3547, 1
#   Meal 2: 3663 - 3841, 2
#   Meal 3: 4419 - 4427, 3
#   Meal 4: 9151 - 9164, 3
#   Meal 5: 13725 - 13939, 2
#   Meal 6: 14093 - 14384, 2
# total, onborders: 57422 57188
# Session Shapes window, labels:  (57422, 8) 54235 1776 1367 44
# ---------------------------------------------
#
# Subject, Session:  4 0
# Annots cut at meal: 3/3, Times data, start: 30691, 31240
# Meal count: 2, Times data, last meal end: 30691, 14472
# [[201380 206632      1]
#  [230639 231566      3]]
#   Meal 1: 12586 - 12914, 1
#   Meal 2: 14414 - 14472, 3
# total, onborders: 61364 61284
# Session Shapes window, labels:  (61364, 8) 60591 657 0 116
# ---------------------------------------------
#
# Subject, Session:  4 1
# Meal count: 4, Times data, last meal end: 39290, 33222
# [[161082 170469      1]
#  [413105 426853      2]
#  [430235 431175      2]
#  [493359 531562      1]]
#   Meal 1: 10067 - 10654, 1
#   Meal 2: 25819 - 26678, 2
#   Meal 3: 26889 - 26948, 2
#   Meal 4: 30834 - 33222, 1
# total, onborders: 78561 78402
# Session Shapes window, labels:  (78561, 8) 70777 5949 1835 0
# ---------------------------------------------
#
# Subject, Session:  5 0
# Meal count: 3, Times data, last meal end: 15565, 15453
# [[  9447  19584      3]
#  [184069 194449      1]
#  [228986 247263      1]]
#   Meal 1: 590 - 1224, 3
#   Meal 2: 11504 - 12153, 1
#   Meal 3: 14311 - 15453, 1
# total, onborders: 31111 30992
# Session Shapes window, labels:  (31111, 8) 26261 3582 0 1268
# ---------------------------------------------
#
# Subject, Session:  5 1
# Meal count: 4, Times data, last meal end: 31624, 28333
# [[ 63114  87909      1]
#  [241813 243513      2]
#  [372908 425371      1]
#  [438441 453328      2]]
#   Meal 1: 3944 - 5494, 1
#   Meal 2: 15113 - 15219, 2
#   Meal 3: 23306 - 26585, 1
#   Meal 4: 27402 - 28333, 2
# total, onborders: 63230 63070
# Session Shapes window, labels:  (63230, 8) 51499 9657 2074 0
# ---------------------------------------------
#
# Subject, Session:  6 0
# Meal count: 4, Times data, last meal end: 37011, 33798
# [[112278 114795      1]
#  [120320 136426      1]
#  [480687 482987      1]
#  [523129 540779      1]]
#   Meal 1: 7017 - 7174, 1
#   Meal 2: 7520 - 8526, 1
#   Meal 3: 30042 - 30186, 1
#   Meal 4: 32695 - 33798, 1
# total, onborders: 74002 73843
# Session Shapes window, labels:  (74002, 8) 69179 4823 0 0
# ---------------------------------------------
#
# Subject, Session:  6 1
# Annots cut at meal: 2/2, Times data, start: 27208, 27292
# Meal count: 1, Times data, last meal end: 27208, 6802
# [[ 92503 108833      1]]
#   Meal 1: 5781 - 6802, 1
# total, onborders: 54398 54358
# Session Shapes window, labels:  (54398, 8) 52356 2042 0 0
# ---------------------------------------------
#
# Subject, Session:  7 0
# Meal count: 2, Times data, last meal end: 20557, 17204
# [[157730 180858      2]
#  [273438 275267      3]]
#   Meal 1: 9858 - 11303, 2
#   Meal 2: 17089 - 17204, 3
# total, onborders: 41096 41016
# Session Shapes window, labels:  (41096, 8) 37976 0 2891 229
# ---------------------------------------------
#
# Subject, Session:  7 1
# Meal count: 3, Times data, last meal end: 49933, 48408
# [[393529 398386      1]
#  [635403 637159      2]
#  [761093 774540      2]]
#   Meal 1: 24595 - 24899, 1
#   Meal 2: 39712 - 39822, 2
#   Meal 3: 47568 - 48408, 2
# total, onborders: 99847 99728
# Session Shapes window, labels:  (99847, 8) 97340 607 1900 0
# ---------------------------------------------
#
# Subject, Session:  8 0
# Annots cut at meal: 8/8, Times data, start: 38377, 38991
# Meal count: 7, Times data, last meal end: 38377, 28601
# [[ 92049  95726      2]
#  [ 99101 139026      3]
#  [166716 227255      3]
#  [232218 252261      1]
#  [312862 316020      2]
#  [408841 413504      2]
#  [449120 457624      2]]
#   Meal 1: 5753 - 5982, 2
#   Meal 2: 6193 - 8689, 3
#   Meal 3: 10419 - 14203, 3
#   Meal 4: 14513 - 15766, 1
#   Meal 5: 19553 - 19751, 2
#   Meal 6: 25552 - 25844, 2
#   Meal 7: 28070 - 28601, 2
# total, onborders: 76735 76457
# Session Shapes window, labels:  (76735, 8) 59171 2505 2501 12558
# ---------------------------------------------
#
# Subject, Session:  8 1
# Meal count: 4, Times data, last meal end: 40106, 34442
# [[146206 163359      1]
#  [175169 177476      2]
#  [407877 433570      1]
#  [542773 551085      2]]
#   Meal 1: 9137 - 10209, 1
#   Meal 2: 10948 - 11092, 2
#   Meal 3: 25492 - 27098, 1
#   Meal 4: 33923 - 34442, 2
# total, onborders: 80193 80034
# Session Shapes window, labels:  (80193, 8) 73510 5356 1327 0
# ---------------------------------------------
#
# Subject, Session:  9 0
# Meal count: 4, Times data, last meal end: 33252, 33252
# [[193989 212808      1]
#  [313698 316069      2]
#  [391898 396790      2]
#  [528814 532032      1]]
#   Meal 1: 12124 - 13300, 1
#   Meal 2: 19606 - 19754, 2
#   Meal 3: 24493 - 24799, 2
#   Meal 4: 33050 - 33252, 1
# total, onborders: 66485 66345
# Session Shapes window, labels:  (66485, 8) 62832 2746 907 0
# ---------------------------------------------
#
# Subject, Session:  9 1
# Meal count: 3, Times data, last meal end: 34196, 33632
# [[154482 160878      1]
#  [268327 275511      2]
#  [520737 538118      1]]
#   Meal 1: 9655 - 10054, 1
#   Meal 2: 16770 - 17219, 2
#   Meal 3: 32546 - 33632, 1
# total, onborders: 68373 68254
# Session Shapes window, labels:  (68373, 8) 64504 2971 898 0
# ---------------------------------------------
#
# Subject, Session:  9 2
# Meal count: 4, Times data, last meal end: 34244, 34244
# [[336462 369700      1]
#  [456701 459665      2]
#  [504376 507889      1]
#  [540101 547905      1]]
#   Meal 1: 21028 - 23106, 1
#   Meal 2: 28543 - 28729, 2
#   Meal 3: 31523 - 31743, 1
#   Meal 4: 33756 - 34244, 1
# total, onborders: 68469 68330
# Session Shapes window, labels:  (68469, 8) 62537 5561 371 0
# ---------------------------------------------
#
# Subject, Session:  9 3
# Meal count: 3, Times data, last meal end: 35921, 24115
# [[194088 212904      1]
#  [248461 254002      2]
#  [374210 385848      2]]
#   Meal 1: 12130 - 13306, 1
#   Meal 2: 15528 - 15875, 2
#   Meal 3: 23388 - 24115, 2
# total, onborders: 71824 71705
# Session Shapes window, labels:  (71824, 8) 67323 2353 2148 0
# ---------------------------------------------
#
# Subject, Session:  9 4
# Meal count: 1, Times data, last meal end: 25377, 24917
# [[381716 398676      1]]
#   Meal 1: 23857 - 24917, 1
# total, onborders: 50736 50696
# Session Shapes window, labels:  (50736, 8) 48616 2120 0 0
# ---------------------------------------------
#
# Subject, Session:  10 0
# Meal count: 4, Times data, last meal end: 34720, 34545
# [[ 87107  99140      1]
#  [184838 189846      2]
#  [368805 379797      2]
#  [524386 552723      1]]
#   Meal 1: 5444 - 6196, 1
#   Meal 2: 11552 - 11865, 2
#   Meal 3: 23050 - 23737, 2
#   Meal 4: 32774 - 34545, 1
# total, onborders: 69421 69261
# Session Shapes window, labels:  (69421, 8) 62375 5046 2000 0
# ---------------------------------------------
#
# Subject, Session:  10 1
# Meal count: 3, Times data, last meal end: 41818, 23848
# [[163633 179421      2]
#  [252731 268824      1]
#  [354477 381581      2]]
#   Meal 1: 10227 - 11213, 2
#   Meal 2: 15795 - 16801, 1
#   Meal 3: 22154 - 23848, 2
# total, onborders: 83618 83498
# Session Shapes window, labels:  (83618, 8) 76245 2012 5361 0
# ---------------------------------------------

# %%
print(ixs.shape)
for i in range(0, 4):
    print(i, np.sum(ixs[:, -1]==i))

print()
ixs2 = ixs[ixs[:, -2]>=0, :]
print(ixs2.shape)
for i in range(0, 4):
    print(i, np.sum(ixs2[:, -1]==i))
# Out:
# (1722454, 8)
# 0 1571090
# 1 98779
# 2 28720
# 3 23865
#
# (1718319, 8)
# 0 1569021
# 1 97824
# 2 28064
# 3 23410

# %%
ixf = ixs[(ixs[:, -1]<=1), :]
print("All Shapes window, labels: ", ixf.shape, np.sum(ixf[:,-1]==0), np.sum(ixf[:,-1]==1), np.sum(ixf[:,-1]==2), np.sum(ixf[:,-1]==3))
# Out:
# All Shapes window, labels:  (1669869, 8) 1571090 98779 0 0

# %%
#windows = mwgenu.get_window_data(ds, ixf, win_size=win_size)
#print(windows.shape)

# %%
v = mfeatu.get_variance_accel(ds, ixf, win_size=win_size)
gx = mfeatu.get_grav_x(ds, ixf, index_offset=win_size//2)

# %%
for vth in np.arange(0,2, 0.5):
    vv = v[ixf[:, -1]==0]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

vth = 1

vn = v[ixf[:, -1]==0]
vp = v[ixf[:, -1]>0]
print(vn.shape, vp.shape)

gxn =gx[ixf[:, -1]==0] 
gxp = gx[ixf[:, -1]>0]
vn = vn[(gxn<=-0)]
vp = vp[(gxp<=-0)]
print(vn.shape, vp.shape)

vn = vn[(vn>=vth) & (vn<=30)]
vp = vp[(vp>=vth) & (vp<=30)]
print(vn.shape, vp.shape)

plt.hist(vn, bins=50)
plt.xlim([0, 50])
plt.show()
plt.hist(vp, bins=50)
plt.xlim([0, 50])
plt.show()
# Out:
# (1571090,) (98779,)
# (899471,) (78283,)
# (335907,) (53411,)
