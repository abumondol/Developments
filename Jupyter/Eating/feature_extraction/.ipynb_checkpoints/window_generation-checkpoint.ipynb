# %%
import numpy as np
import pickle
import os
import sys
import importlib

# %%
util_path = 'C:/ASM/Dropbox/Developments/Jupyter/Eating/myutils' if 'C:' in os.getcwd() else './myutils'
sys.path.append(util_path)
import my_file_utils as mfileu
import my_data_process_utils as mdpu

# %%
ds = mfileu.read_file("data", "free_data_steven_right.pkl")
annots = mfileu.read_file("data", "free_data_steven_annots.pkl")

# %%
def get_windows_segments(d, si, ei, win_size, step_size):
    #print("\tdcount, si, ei:", len(d), si, ei, si//16, ei//16)
    indices = list(range(si, ei-win_size, step_size))
    count = len(indices)
    w = np.zeros((count, win_size, d.shape[1]))
    j = 0
    for i in indices:
        w [j, :, :] = d[i:i+win_size, :]
        j += 1
    
    assert j == count
    return w
    
    
def get_windows(d, a, win_size=16, neg_step=8, pos_step=1):
    windows = np.empty((0, win_size, d.shape[1]))
    labels = np.empty((0, 1), dtype=np.int32)
    dcount = len(d)
    acount = len(a)
    
    for i in range(acount):
        if a[i, 0]>=dcount:
            print("Annots cut at meal: {}/{}, Times data, start: {}, {}".format(i+1, acount, dcount//16, a[i,0]//16))
            a = a[:i, :]            
            break
            
        if a[i, 1]>=dcount:
            print("Annots end adjusted at meal: {}/{}, Times data, end: {}, {}".format(i+1, acount, dcount//16, a[i,0]//16))
            a[i, 1]=dcount-1
            a = a[:i+1, :]            
            break
            
            
    acount = len(a)    
    print("Meal count: {}, Times data, last meal end: {}, {}".format(acount, dcount//16, a[-1,1]//16))    
    assert a[-1, 1]<=dcount-1
     
    
    si, ei = 0, a[0,0]
    w = get_windows_segments(d, si, ei, win_size, neg_step)
    l = np.zeros((len(w), 1), dtype=np.int32)
    windows = np.concatenate((windows, w), axis=0)    
    labels = np.concatenate((labels, l), axis=0)
    
    for i in range(acount):
        si = a[i, 0]
        ei = a[i, 1]
        mt = a[i, 2]        
        print('  Meal {}: {} - {}, {}'.format(i+1, si//16, ei//16, mt))
                
        #Positive Windows        
        print("    Positives: ")                
        
        if mt>2 or (mt==1 and ei-si>=30*60*16) or (mt==2 and ei-si>=20*60*16):
            print("\tExcluded => Meal Index:{}, Meal type:{}, Duration:{}".format(i, mt, (ei-si)/16))
        else:            
            w = get_windows_segments(d, si, ei, win_size, pos_step)
            l = np.zeros((len(w), 1), dtype=np.int32) + 1            
            windows = np.concatenate((windows, w), axis=0)            
            labels = np.concatenate((labels, l), axis=0)
            print("\tShapes window, label: ", w.shape, l.shape)
            
        # Negative windows
        if ei == dcount-1:
            break
            
        print("    Negatives: ")
        si = ei+1
        ei = dcount-1 if i==acount-1 else a[i+1, 0]-1
        
        print("\tTimes: ", si//16, " - " ,ei//16)
        
        w = get_windows_segments(d, si, ei, win_size, neg_step)
        l = np.zeros((len(w), 1), dtype=np.int32)
        windows = np.concatenate((windows, w), axis=0)        
        labels = np.concatenate((labels, l), axis=0)
        
        print("\tShapes window, label: ", w.shape, l.shape)        
        
    assert len(windows) == len(labels)
    return windows, labels

# %%
win_size=16
for subj in range(len(ds)):
    windows = np.empty((0, win_size, 9))
    labels = np.empty((0, 1), dtype=np.int32)
    
    for sess in range(len(ds[subj])):
        print("\n\nSubject, Session: ", subj, sess)
        d = ds[subj][sess]
        d = d[:, 4:]
        
        d[:, :3] = mdpu.smooth_data(d[:, :3], 0.9)
        d[:, 3:6] = mdpu.smooth_data(d[:, 3:6], 0.9)
        
        a = annots[subj][sess]
        
        w, l = get_windows(d, a)        
        windows = np.concatenate((windows, w), axis=0)        
        labels = np.concatenate((labels, l), axis=0)        
        print("Session Shapes window, label: ", w.shape, l.shape)
        
    subj_data={"windows":windows, 'labels':labels}
    print("Subject Shapes window, label: ", windows.shape, labels.shape, np.sum(labels))    
    mfileu.write_file('windows_free_cnn', 'subj_'+str(subj)+".pkl", subj_data)
    print("---------------------------------------------")
# Out:
# Subject, Session:  0 0
# Meal count: 3, Times data, last meal end: 40424, 20145
#   Meal 1: 805 - 1176, 1
#     Positives:
# 	Shapes window, label:  (5927, 16, 9) (5927, 1)
#     Negatives:
# 	Times:  1177  -  4826
# 	Shapes window, label:  (7298, 16, 9) (7298, 1)
#   Meal 2: 4826 - 4885, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:59.0
#     Negatives:
# 	Times:  4886  -  18411
# 	Shapes window, label:  (27049, 16, 9) (27049, 1)
#   Meal 3: 18411 - 20145, 1
#     Positives:
# 	Shapes window, label:  (27725, 16, 9) (27725, 1)
#     Negatives:
# 	Times:  20145  -  40424
# 	Shapes window, label:  (40557, 16, 9) (40557, 1)
# Session Shapes window, label:  (110165, 16, 9) (110165, 1)
#
#
# Subject, Session:  0 1
# Meal count: 5, Times data, last meal end: 38185, 29993
#   Meal 1: 2090 - 2773, 1
#     Positives:
# 	Shapes window, label:  (10913, 16, 9) (10913, 1)
#     Negatives:
# 	Times:  2773  -  8287
# 	Shapes window, label:  (11025, 16, 9) (11025, 1)
#   Meal 2: 8287 - 8332, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:45.0625
#     Negatives:
# 	Times:  8332  -  19435
# 	Shapes window, label:  (22205, 16, 9) (22205, 1)
#   Meal 3: 19435 - 20122, 1
#     Positives:
# 	Shapes window, label:  (10970, 16, 9) (10970, 1)
#     Negatives:
# 	Times:  20122  -  24973
# 	Shapes window, label:  (9699, 16, 9) (9699, 1)
#   Meal 4: 24973 - 25037, 3
#     Positives:
# 	Excluded => Meal Index:3, Meal type:3, Duration:64.375
#     Negatives:
# 	Times:  25037  -  29940
# 	Shapes window, label:  (9805, 16, 9) (9805, 1)
#   Meal 5: 29940 - 29993, 3
#     Positives:
# 	Excluded => Meal Index:4, Meal type:3, Duration:52.875
#     Negatives:
# 	Times:  29993  -  38185
# 	Shapes window, label:  (16382, 16, 9) (16382, 1)
# Session Shapes window, label:  (95179, 16, 9) (95179, 1)
# Subject Shapes window, label:  (205344, 16, 9) (205344, 1) 55535
# ---------------------------------------------
#
#
# Subject, Session:  1 0
# Meal count: 5, Times data, last meal end: 36606, 32903
#   Meal 1: 389 - 1321, 1
#     Positives:
# 	Shapes window, label:  (14898, 16, 9) (14898, 1)
#     Negatives:
# 	Times:  1321  -  10003
# 	Shapes window, label:  (17363, 16, 9) (17363, 1)
#   Meal 2: 10003 - 11776, 1
#     Positives:
# 	Shapes window, label:  (28355, 16, 9) (28355, 1)
#     Negatives:
# 	Times:  11776  -  24482
# 	Shapes window, label:  (25410, 16, 9) (25410, 1)
#   Meal 3: 24482 - 26590, 1
#     Positives:
# 	Excluded => Meal Index:2, Meal type:1, Duration:2108.0625
#     Negatives:
# 	Times:  26590  -  27823
# 	Shapes window, label:  (2465, 16, 9) (2465, 1)
#   Meal 4: 27823 - 27834, 2
#     Positives:
# 	Shapes window, label:  (153, 16, 9) (153, 1)
#     Negatives:
# 	Times:  27834  -  32810
# 	Shapes window, label:  (9951, 16, 9) (9951, 1)
#   Meal 5: 32810 - 32903, 2
#     Positives:
# 	Shapes window, label:  (1462, 16, 9) (1462, 1)
#     Negatives:
# 	Times:  32903  -  36606
# 	Shapes window, label:  (7406, 16, 9) (7406, 1)
# Session Shapes window, label:  (108240, 16, 9) (108240, 1)
#
#
# Subject, Session:  1 1
# Meal count: 7, Times data, last meal end: 37048, 28106
#   Meal 1: 109 - 818, 1
#     Positives:
# 	Shapes window, label:  (11333, 16, 9) (11333, 1)
#     Negatives:
# 	Times:  818  -  6558
# 	Shapes window, label:  (11479, 16, 9) (11479, 1)
#   Meal 2: 6558 - 10127, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:3568.5625
#     Negatives:
# 	Times:  10127  -  11641
# 	Shapes window, label:  (3027, 16, 9) (3027, 1)
#   Meal 3: 11641 - 12940, 1
#     Positives:
# 	Shapes window, label:  (20758, 16, 9) (20758, 1)
#     Negatives:
# 	Times:  12940  -  19085
# 	Shapes window, label:  (12289, 16, 9) (12289, 1)
#   Meal 4: 19085 - 19491, 2
#     Positives:
# 	Shapes window, label:  (6483, 16, 9) (6483, 1)
#     Negatives:
# 	Times:  19491  -  20428
# 	Shapes window, label:  (1872, 16, 9) (1872, 1)
#   Meal 5: 20428 - 20760, 2
#     Positives:
# 	Shapes window, label:  (5297, 16, 9) (5297, 1)
#     Negatives:
# 	Times:  20760  -  22070
# 	Shapes window, label:  (2619, 16, 9) (2619, 1)
#   Meal 6: 22071 - 22121, 2
#     Positives:
# 	Shapes window, label:  (794, 16, 9) (794, 1)
#     Negatives:
# 	Times:  22121  -  27138
# 	Shapes window, label:  (10033, 16, 9) (10033, 1)
#   Meal 7: 27138 - 28106, 1
#     Positives:
# 	Shapes window, label:  (15467, 16, 9) (15467, 1)
#     Negatives:
# 	Times:  28106  -  37048
# 	Shapes window, label:  (17882, 16, 9) (17882, 1)
# Session Shapes window, label:  (119550, 16, 9) (119550, 1)
# Subject Shapes window, label:  (227790, 16, 9) (227790, 1) 105000
# ---------------------------------------------
#
#
# Subject, Session:  2 0
# Meal count: 6, Times data, last meal end: 43250, 33582
#   Meal 1: 6084 - 6121, 3
#     Positives:
# 	Excluded => Meal Index:0, Meal type:3, Duration:36.375
#     Negatives:
# 	Times:  6121  -  11899
# 	Shapes window, label:  (11555, 16, 9) (11555, 1)
#   Meal 2: 11899 - 12484, 1
#     Positives:
# 	Shapes window, label:  (9337, 16, 9) (9337, 1)
#     Negatives:
# 	Times:  12484  -  12766
# 	Shapes window, label:  (564, 16, 9) (564, 1)
#   Meal 3: 12767 - 13713, 1
#     Positives:
# 	Shapes window, label:  (15129, 16, 9) (15129, 1)
#     Negatives:
# 	Times:  13713  -  26704
# 	Shapes window, label:  (25980, 16, 9) (25980, 1)
#   Meal 4: 26704 - 26740, 3
#     Positives:
# 	Excluded => Meal Index:3, Meal type:3, Duration:36.125
#     Negatives:
# 	Times:  26740  -  31828
# 	Shapes window, label:  (10175, 16, 9) (10175, 1)
#   Meal 5: 31828 - 33004, 1
#     Positives:
# 	Shapes window, label:  (18802, 16, 9) (18802, 1)
#     Negatives:
# 	Times:  33004  -  33191
# 	Shapes window, label:  (371, 16, 9) (371, 1)
#   Meal 6: 33191 - 33582, 2
#     Positives:
# 	Shapes window, label:  (6242, 16, 9) (6242, 1)
#     Negatives:
# 	Times:  33582  -  43250
# 	Shapes window, label:  (19333, 16, 9) (19333, 1)
# Session Shapes window, label:  (129656, 16, 9) (129656, 1)
#
#
# Subject, Session:  2 1
# Meal count: 8, Times data, last meal end: 42141, 38667
#   Meal 1: 920 - 2045, 1
#     Positives:
# 	Shapes window, label:  (17984, 16, 9) (17984, 1)
#     Negatives:
# 	Times:  2045  -  5275
# 	Shapes window, label:  (6459, 16, 9) (6459, 1)
#   Meal 2: 5275 - 5449, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:173.875
#     Negatives:
# 	Times:  5449  -  14184
# 	Shapes window, label:  (17469, 16, 9) (17469, 1)
#   Meal 3: 14184 - 14225, 3
#     Positives:
# 	Excluded => Meal Index:2, Meal type:3, Duration:40.25
#     Negatives:
# 	Times:  14225  -  19899
# 	Shapes window, label:  (11346, 16, 9) (11346, 1)
#   Meal 4: 19899 - 21329, 1
#     Positives:
# 	Shapes window, label:  (22871, 16, 9) (22871, 1)
#     Negatives:
# 	Times:  21329  -  22377
# 	Shapes window, label:  (2093, 16, 9) (2093, 1)
#   Meal 5: 22377 - 22638, 3
#     Positives:
# 	Excluded => Meal Index:4, Meal type:3, Duration:261.5625
#     Negatives:
# 	Times:  22638  -  26002
# 	Shapes window, label:  (6725, 16, 9) (6725, 1)
#   Meal 6: 26002 - 26012, 3
#     Positives:
# 	Excluded => Meal Index:5, Meal type:3, Duration:10.625
#     Negatives:
# 	Times:  26012  -  29116
# 	Shapes window, label:  (6206, 16, 9) (6206, 1)
#   Meal 7: 29116 - 29127, 3
#     Positives:
# 	Excluded => Meal Index:6, Meal type:3, Duration:10.875
#     Negatives:
# 	Times:  29127  -  37901
# 	Shapes window, label:  (17545, 16, 9) (17545, 1)
#   Meal 8: 37901 - 38667, 1
#     Positives:
# 	Shapes window, label:  (12246, 16, 9) (12246, 1)
#     Negatives:
# 	Times:  38667  -  42140
# 	Shapes window, label:  (6945, 16, 9) (6945, 1)
# Session Shapes window, label:  (129729, 16, 9) (129729, 1)
# Subject Shapes window, label:  (259385, 16, 9) (259385, 1) 102611
# ---------------------------------------------
#
#
# Subject, Session:  3 0
# Annots cut at meal: 10/11, Times data, start: 25196, 27602
# Meal count: 9, Times data, last meal end: 25196, 23124
#   Meal 1: 1680 - 2967, 1
#     Positives:
# 	Shapes window, label:  (20567, 16, 9) (20567, 1)
#     Negatives:
# 	Times:  2967  -  4864
# 	Shapes window, label:  (3793, 16, 9) (3793, 1)
#   Meal 2: 4864 - 5288, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:423.9375
#     Negatives:
# 	Times:  5288  -  6315
# 	Shapes window, label:  (2053, 16, 9) (2053, 1)
#   Meal 3: 6315 - 6327, 3
#     Positives:
# 	Excluded => Meal Index:2, Meal type:3, Duration:11.125
#     Negatives:
# 	Times:  6327  -  6399
# 	Shapes window, label:  (143, 16, 9) (143, 1)
#   Meal 4: 6399 - 6685, 2
#     Positives:
# 	Shapes window, label:  (4565, 16, 9) (4565, 1)
#     Negatives:
# 	Times:  6685  -  15494
# 	Shapes window, label:  (17616, 16, 9) (17616, 1)
#   Meal 5: 15494 - 15511, 3
#     Positives:
# 	Excluded => Meal Index:4, Meal type:3, Duration:16.5625
#     Negatives:
# 	Times:  15511  -  20175
# 	Shapes window, label:  (9327, 16, 9) (9327, 1)
#   Meal 6: 20175 - 20188, 3
#     Positives:
# 	Excluded => Meal Index:5, Meal type:3, Duration:12.8125
#     Negatives:
# 	Times:  20188  -  22013
# 	Shapes window, label:  (3649, 16, 9) (3649, 1)
#   Meal 7: 22014 - 22272, 1
#     Positives:
# 	Shapes window, label:  (4126, 16, 9) (4126, 1)
#     Negatives:
# 	Times:  22272  -  22362
# 	Shapes window, label:  (178, 16, 9) (178, 1)
#   Meal 8: 22362 - 22875, 1
#     Positives:
# 	Shapes window, label:  (8185, 16, 9) (8185, 1)
#     Negatives:
# 	Times:  22875  -  22968
# 	Shapes window, label:  (185, 16, 9) (185, 1)
#   Meal 9: 22968 - 23124, 1
#     Positives:
# 	Shapes window, label:  (2479, 16, 9) (2479, 1)
#     Negatives:
# 	Times:  23124  -  25196
# 	Shapes window, label:  (4142, 16, 9) (4142, 1)
# Session Shapes window, label:  (84368, 16, 9) (84368, 1)
#
#
# Subject, Session:  3 1
# Meal count: 6, Times data, last meal end: 28720, 14384
#   Meal 1: 2659 - 3547, 1
#     Positives:
# 	Shapes window, label:  (14191, 16, 9) (14191, 1)
#     Negatives:
# 	Times:  3547  -  3663
# 	Shapes window, label:  (229, 16, 9) (229, 1)
#   Meal 2: 3663 - 3841, 2
#     Positives:
# 	Shapes window, label:  (2838, 16, 9) (2838, 1)
#     Negatives:
# 	Times:  3841  -  4419
# 	Shapes window, label:  (1154, 16, 9) (1154, 1)
#   Meal 3: 4419 - 4427, 3
#     Positives:
# 	Excluded => Meal Index:2, Meal type:3, Duration:8.5
#     Negatives:
# 	Times:  4427  -  9151
# 	Shapes window, label:  (9445, 16, 9) (9445, 1)
#   Meal 4: 9151 - 9164, 3
#     Positives:
# 	Excluded => Meal Index:3, Meal type:3, Duration:13.6875
#     Negatives:
# 	Times:  9164  -  13725
# 	Shapes window, label:  (9119, 16, 9) (9119, 1)
#   Meal 5: 13725 - 13939, 2
#     Positives:
# 	Shapes window, label:  (3414, 16, 9) (3414, 1)
#     Negatives:
# 	Times:  13939  -  14093
# 	Shapes window, label:  (306, 16, 9) (306, 1)
#   Meal 6: 14093 - 14384, 2
#     Positives:
# 	Shapes window, label:  (4639, 16, 9) (4639, 1)
#     Negatives:
# 	Times:  14384  -  28720
# 	Shapes window, label:  (28671, 16, 9) (28671, 1)
# Session Shapes window, label:  (79323, 16, 9) (79323, 1)
# Subject Shapes window, label:  (163691, 16, 9) (163691, 1) 65004
# ---------------------------------------------
#
#
# Subject, Session:  4 0
# Annots cut at meal: 3/3, Times data, start: 30691, 31240
# Meal count: 2, Times data, last meal end: 30691, 14472
#   Meal 1: 12586 - 12914, 1
#     Positives:
# 	Shapes window, label:  (5236, 16, 9) (5236, 1)
#     Negatives:
# 	Times:  12914  -  14414
# 	Shapes window, label:  (2999, 16, 9) (2999, 1)
#   Meal 2: 14414 - 14472, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:57.9375
#     Negatives:
# 	Times:  14472  -  30691
# 	Shapes window, label:  (32436, 16, 9) (32436, 1)
# Session Shapes window, label:  (65842, 16, 9) (65842, 1)
#
#
# Subject, Session:  4 1
# Meal count: 4, Times data, last meal end: 39290, 33222
#   Meal 1: 10067 - 10654, 1
#     Positives:
# 	Shapes window, label:  (9371, 16, 9) (9371, 1)
#     Negatives:
# 	Times:  10654  -  25819
# 	Shapes window, label:  (30328, 16, 9) (30328, 1)
#   Meal 2: 25819 - 26678, 2
#     Positives:
# 	Shapes window, label:  (13732, 16, 9) (13732, 1)
#     Negatives:
# 	Times:  26678  -  26889
# 	Shapes window, label:  (421, 16, 9) (421, 1)
#   Meal 3: 26889 - 26948, 2
#     Positives:
# 	Shapes window, label:  (924, 16, 9) (924, 1)
#     Negatives:
# 	Times:  26948  -  30834
# 	Shapes window, label:  (7771, 16, 9) (7771, 1)
#   Meal 4: 30834 - 33222, 1
#     Positives:
# 	Excluded => Meal Index:3, Meal type:1, Duration:2387.6875
#     Negatives:
# 	Times:  33222  -  39290
# 	Shapes window, label:  (12134, 16, 9) (12134, 1)
# Session Shapes window, label:  (94815, 16, 9) (94815, 1)
# Subject Shapes window, label:  (160657, 16, 9) (160657, 1) 29263
# ---------------------------------------------
#
#
# Subject, Session:  5 0
# Meal count: 3, Times data, last meal end: 15565, 15453
#   Meal 1: 590 - 1224, 3
#     Positives:
# 	Excluded => Meal Index:0, Meal type:3, Duration:633.5625
#     Negatives:
# 	Times:  1224  -  11504
# 	Shapes window, label:  (20559, 16, 9) (20559, 1)
#   Meal 2: 11504 - 12153, 1
#     Positives:
# 	Shapes window, label:  (10364, 16, 9) (10364, 1)
#     Negatives:
# 	Times:  12153  -  14311
# 	Shapes window, label:  (4315, 16, 9) (4315, 1)
#   Meal 3: 14311 - 15453, 1
#     Positives:
# 	Shapes window, label:  (18261, 16, 9) (18261, 1)
#     Negatives:
# 	Times:  15454  -  15565
# 	Shapes window, label:  (221, 16, 9) (221, 1)
# Session Shapes window, label:  (54899, 16, 9) (54899, 1)
#
#
# Subject, Session:  5 1
# Meal count: 4, Times data, last meal end: 31624, 28333
#   Meal 1: 3944 - 5494, 1
#     Positives:
# 	Shapes window, label:  (24779, 16, 9) (24779, 1)
#     Negatives:
# 	Times:  5494  -  15113
# 	Shapes window, label:  (19236, 16, 9) (19236, 1)
#   Meal 2: 15113 - 15219, 2
#     Positives:
# 	Shapes window, label:  (1684, 16, 9) (1684, 1)
#     Negatives:
# 	Times:  15219  -  23306
# 	Shapes window, label:  (16173, 16, 9) (16173, 1)
#   Meal 3: 23306 - 26585, 1
#     Positives:
# 	Excluded => Meal Index:2, Meal type:1, Duration:3278.9375
#     Negatives:
# 	Times:  26585  -  27402
# 	Shapes window, label:  (1632, 16, 9) (1632, 1)
#   Meal 4: 27402 - 28333, 2
#     Positives:
# 	Shapes window, label:  (14871, 16, 9) (14871, 1)
#     Negatives:
# 	Times:  28333  -  31624
# 	Shapes window, label:  (6582, 16, 9) (6582, 1)
# Session Shapes window, label:  (92845, 16, 9) (92845, 1)
# Subject Shapes window, label:  (147744, 16, 9) (147744, 1) 69959
# ---------------------------------------------
#
#
# Subject, Session:  6 0
# Meal count: 4, Times data, last meal end: 37011, 33798
#   Meal 1: 7017 - 7174, 1
#     Positives:
# 	Shapes window, label:  (2501, 16, 9) (2501, 1)
#     Negatives:
# 	Times:  7174  -  7519
# 	Shapes window, label:  (689, 16, 9) (689, 1)
#   Meal 2: 7520 - 8526, 1
#     Positives:
# 	Shapes window, label:  (16090, 16, 9) (16090, 1)
#     Negatives:
# 	Times:  8526  -  30042
# 	Shapes window, label:  (43031, 16, 9) (43031, 1)
#   Meal 3: 30042 - 30186, 1
#     Positives:
# 	Shapes window, label:  (2284, 16, 9) (2284, 1)
#     Negatives:
# 	Times:  30186  -  32695
# 	Shapes window, label:  (5016, 16, 9) (5016, 1)
#   Meal 4: 32695 - 33798, 1
#     Positives:
# 	Shapes window, label:  (17634, 16, 9) (17634, 1)
#     Negatives:
# 	Times:  33798  -  37010
# 	Shapes window, label:  (6423, 16, 9) (6423, 1)
# Session Shapes window, label:  (107701, 16, 9) (107701, 1)
#
#
# Subject, Session:  6 1
# Annots cut at meal: 2/2, Times data, start: 27208, 27292
# Meal count: 1, Times data, last meal end: 27208, 6802
#   Meal 1: 5781 - 6802, 1
#     Positives:
# 	Shapes window, label:  (16314, 16, 9) (16314, 1)
#     Negatives:
# 	Times:  6802  -  27208
# 	Shapes window, label:  (40812, 16, 9) (40812, 1)
# Session Shapes window, label:  (68687, 16, 9) (68687, 1)
# Subject Shapes window, label:  (176388, 16, 9) (176388, 1) 54823
# ---------------------------------------------
#
#
# Subject, Session:  7 0
# Meal count: 2, Times data, last meal end: 20557, 17204
#   Meal 1: 9858 - 11303, 2
#     Positives:
# 	Excluded => Meal Index:0, Meal type:2, Duration:1445.5
#     Negatives:
# 	Times:  11303  -  17089
# 	Shapes window, label:  (11571, 16, 9) (11571, 1)
#   Meal 2: 17089 - 17204, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:114.3125
#     Negatives:
# 	Times:  17204  -  20557
# 	Shapes window, label:  (6705, 16, 9) (6705, 1)
# Session Shapes window, label:  (37991, 16, 9) (37991, 1)
#
#
# Subject, Session:  7 1
# Meal count: 3, Times data, last meal end: 49933, 48408
#   Meal 1: 24595 - 24899, 1
#     Positives:
# 	Shapes window, label:  (4841, 16, 9) (4841, 1)
#     Negatives:
# 	Times:  24899  -  39712
# 	Shapes window, label:  (29625, 16, 9) (29625, 1)
#   Meal 2: 39712 - 39822, 2
#     Positives:
# 	Shapes window, label:  (1740, 16, 9) (1740, 1)
#     Negatives:
# 	Times:  39822  -  47568
# 	Shapes window, label:  (15490, 16, 9) (15490, 1)
#   Meal 3: 47568 - 48408, 2
#     Positives:
# 	Shapes window, label:  (13431, 16, 9) (13431, 1)
#     Negatives:
# 	Times:  48408  -  49933
# 	Shapes window, label:  (3047, 16, 9) (3047, 1)
# Session Shapes window, label:  (117364, 16, 9) (117364, 1)
# Subject Shapes window, label:  (155355, 16, 9) (155355, 1) 20012
# ---------------------------------------------
#
#
# Subject, Session:  8 0
# Annots cut at meal: 8/8, Times data, start: 38377, 38991
# Meal count: 7, Times data, last meal end: 38377, 28601
#   Meal 1: 5753 - 5982, 2
#     Positives:
# 	Shapes window, label:  (3661, 16, 9) (3661, 1)
#     Negatives:
# 	Times:  5982  -  6193
# 	Shapes window, label:  (420, 16, 9) (420, 1)
#   Meal 2: 6193 - 8689, 3
#     Positives:
# 	Excluded => Meal Index:1, Meal type:3, Duration:2495.3125
#     Negatives:
# 	Times:  8689  -  10419
# 	Shapes window, label:  (3459, 16, 9) (3459, 1)
#   Meal 3: 10419 - 14203, 3
#     Positives:
# 	Excluded => Meal Index:2, Meal type:3, Duration:3783.6875
#     Negatives:
# 	Times:  14203  -  14513
# 	Shapes window, label:  (619, 16, 9) (619, 1)
#   Meal 4: 14513 - 15766, 1
#     Positives:
# 	Shapes window, label:  (20027, 16, 9) (20027, 1)
#     Negatives:
# 	Times:  15766  -  19553
# 	Shapes window, label:  (7573, 16, 9) (7573, 1)
#   Meal 5: 19553 - 19751, 2
#     Positives:
# 	Shapes window, label:  (3142, 16, 9) (3142, 1)
#     Negatives:
# 	Times:  19751  -  25552
# 	Shapes window, label:  (11601, 16, 9) (11601, 1)
#   Meal 6: 25552 - 25844, 2
#     Positives:
# 	Shapes window, label:  (4647, 16, 9) (4647, 1)
#     Negatives:
# 	Times:  25844  -  28069
# 	Shapes window, label:  (4450, 16, 9) (4450, 1)
#   Meal 7: 28070 - 28601, 2
#     Positives:
# 	Shapes window, label:  (8488, 16, 9) (8488, 1)
#     Negatives:
# 	Times:  28601  -  38377
# 	Shapes window, label:  (19550, 16, 9) (19550, 1)
# Session Shapes window, label:  (99142, 16, 9) (99142, 1)
#
#
# Subject, Session:  8 1
# Meal count: 4, Times data, last meal end: 40106, 34442
#   Meal 1: 9137 - 10209, 1
#     Positives:
# 	Shapes window, label:  (17137, 16, 9) (17137, 1)
#     Negatives:
# 	Times:  10210  -  10948
# 	Shapes window, label:  (1474, 16, 9) (1474, 1)
#   Meal 2: 10948 - 11092, 2
#     Positives:
# 	Shapes window, label:  (2291, 16, 9) (2291, 1)
#     Negatives:
# 	Times:  11092  -  25492
# 	Shapes window, label:  (28798, 16, 9) (28798, 1)
#   Meal 3: 25492 - 27098, 1
#     Positives:
# 	Shapes window, label:  (25677, 16, 9) (25677, 1)
#     Negatives:
# 	Times:  27098  -  33923
# 	Shapes window, label:  (13649, 16, 9) (13649, 1)
#   Meal 4: 33923 - 34442, 2
#     Positives:
# 	Shapes window, label:  (8296, 16, 9) (8296, 1)
#     Negatives:
# 	Times:  34442  -  40106
# 	Shapes window, label:  (11325, 16, 9) (11325, 1)
# Session Shapes window, label:  (126921, 16, 9) (126921, 1)
# Subject Shapes window, label:  (226063, 16, 9) (226063, 1) 93366
# ---------------------------------------------
#
#
# Subject, Session:  9 0
# Annots end adjusted at meal: 4/4, Times data, end: 33252, 33050
# Meal count: 4, Times data, last meal end: 33252, 33252
#   Meal 1: 12124 - 13300, 1
#     Positives:
# 	Shapes window, label:  (18803, 16, 9) (18803, 1)
#     Negatives:
# 	Times:  13300  -  19606
# 	Shapes window, label:  (12609, 16, 9) (12609, 1)
#   Meal 2: 19606 - 19754, 2
#     Positives:
# 	Shapes window, label:  (2355, 16, 9) (2355, 1)
#     Negatives:
# 	Times:  19754  -  24493
# 	Shapes window, label:  (9477, 16, 9) (9477, 1)
#   Meal 3: 24493 - 24799, 2
#     Positives:
# 	Shapes window, label:  (4876, 16, 9) (4876, 1)
#     Negatives:
# 	Times:  24799  -  33050
# 	Shapes window, label:  (16501, 16, 9) (16501, 1)
#   Meal 4: 33050 - 33252, 1
#     Positives:
# 	Shapes window, label:  (3202, 16, 9) (3202, 1)
# Session Shapes window, label:  (92070, 16, 9) (92070, 1)
#
#
# Subject, Session:  9 1
# Meal count: 3, Times data, last meal end: 34196, 33632
#   Meal 1: 9655 - 10054, 1
#     Positives:
# 	Shapes window, label:  (6380, 16, 9) (6380, 1)
#     Negatives:
# 	Times:  10054  -  16770
# 	Shapes window, label:  (13429, 16, 9) (13429, 1)
#   Meal 2: 16770 - 17219, 2
#     Positives:
# 	Shapes window, label:  (7168, 16, 9) (7168, 1)
#     Negatives:
# 	Times:  17219  -  32546
# 	Shapes window, label:  (30651, 16, 9) (30651, 1)
#   Meal 3: 32546 - 33632, 1
#     Positives:
# 	Shapes window, label:  (17365, 16, 9) (17365, 1)
#     Negatives:
# 	Times:  33632  -  34196
# 	Shapes window, label:  (1126, 16, 9) (1126, 1)
# Session Shapes window, label:  (95428, 16, 9) (95428, 1)
#
#
# Subject, Session:  9 2
# Annots end adjusted at meal: 4/4, Times data, end: 34244, 33756
# Meal count: 4, Times data, last meal end: 34244, 34244
#   Meal 1: 21028 - 23106, 1
#     Positives:
# 	Excluded => Meal Index:0, Meal type:1, Duration:2077.375
#     Negatives:
# 	Times:  23106  -  28543
# 	Shapes window, label:  (10873, 16, 9) (10873, 1)
#   Meal 2: 28543 - 28729, 2
#     Positives:
# 	Shapes window, label:  (2948, 16, 9) (2948, 1)
#     Negatives:
# 	Times:  28729  -  31523
# 	Shapes window, label:  (5587, 16, 9) (5587, 1)
#   Meal 3: 31523 - 31743, 1
#     Positives:
# 	Shapes window, label:  (3497, 16, 9) (3497, 1)
#     Negatives:
# 	Times:  31743  -  33756
# 	Shapes window, label:  (4025, 16, 9) (4025, 1)
#   Meal 4: 33756 - 34244, 1
#     Positives:
# 	Shapes window, label:  (7788, 16, 9) (7788, 1)
# Session Shapes window, label:  (76774, 16, 9) (76774, 1)
#
#
# Subject, Session:  9 3
# Meal count: 3, Times data, last meal end: 35921, 24115
#   Meal 1: 12130 - 13306, 1
#     Positives:
# 	Shapes window, label:  (18800, 16, 9) (18800, 1)
#     Negatives:
# 	Times:  13306  -  15528
# 	Shapes window, label:  (4443, 16, 9) (4443, 1)
#   Meal 2: 15528 - 15875, 2
#     Positives:
# 	Shapes window, label:  (5525, 16, 9) (5525, 1)
#     Negatives:
# 	Times:  15875  -  23388
# 	Shapes window, label:  (15024, 16, 9) (15024, 1)
#   Meal 3: 23388 - 24115, 2
#     Positives:
# 	Shapes window, label:  (11622, 16, 9) (11622, 1)
#     Negatives:
# 	Times:  24115  -  35921
# 	Shapes window, label:  (23611, 16, 9) (23611, 1)
# Session Shapes window, label:  (103284, 16, 9) (103284, 1)
#
#
# Subject, Session:  9 4
# Meal count: 1, Times data, last meal end: 25377, 24917
#   Meal 1: 23857 - 24917, 1
#     Positives:
# 	Shapes window, label:  (16944, 16, 9) (16944, 1)
#     Negatives:
# 	Times:  24917  -  25377
# 	Shapes window, label:  (919, 16, 9) (919, 1)
# Session Shapes window, label:  (65576, 16, 9) (65576, 1)
# Subject Shapes window, label:  (433132, 16, 9) (433132, 1) 127273
# ---------------------------------------------
#
#
# Subject, Session:  10 0
# Meal count: 4, Times data, last meal end: 34720, 34545
#   Meal 1: 5444 - 6196, 1
#     Positives:
# 	Shapes window, label:  (12017, 16, 9) (12017, 1)
#     Negatives:
# 	Times:  6196  -  11552
# 	Shapes window, label:  (10710, 16, 9) (10710, 1)
#   Meal 2: 11552 - 11865, 2
#     Positives:
# 	Shapes window, label:  (4992, 16, 9) (4992, 1)
#     Negatives:
# 	Times:  11865  -  23050
# 	Shapes window, label:  (22368, 16, 9) (22368, 1)
#   Meal 3: 23050 - 23737, 2
#     Positives:
# 	Shapes window, label:  (10976, 16, 9) (10976, 1)
#     Negatives:
# 	Times:  23737  -  32774
# 	Shapes window, label:  (18072, 16, 9) (18072, 1)
#   Meal 4: 32774 - 34545, 1
#     Positives:
# 	Shapes window, label:  (28321, 16, 9) (28321, 1)
#     Negatives:
# 	Times:  34545  -  34720
# 	Shapes window, label:  (349, 16, 9) (349, 1)
# Session Shapes window, label:  (118692, 16, 9) (118692, 1)
#
#
# Subject, Session:  10 1
# Meal count: 3, Times data, last meal end: 41818, 23848
#   Meal 1: 10227 - 11213, 2
#     Positives:
# 	Shapes window, label:  (15772, 16, 9) (15772, 1)
#     Negatives:
# 	Times:  11213  -  15795
# 	Shapes window, label:  (9162, 16, 9) (9162, 1)
#   Meal 2: 15795 - 16801, 1
#     Positives:
# 	Shapes window, label:  (16077, 16, 9) (16077, 1)
#     Negatives:
# 	Times:  16801  -  22154
# 	Shapes window, label:  (10705, 16, 9) (10705, 1)
#   Meal 3: 22154 - 23848, 2
#     Positives:
# 	Excluded => Meal Index:2, Meal type:2, Duration:1694.0
#     Negatives:
# 	Times:  23848  -  41818
# 	Shapes window, label:  (35938, 16, 9) (35938, 1)
# Session Shapes window, label:  (108107, 16, 9) (108107, 1)
# Subject Shapes window, label:  (226799, 16, 9) (226799, 1) 88155
# ---------------------------------------------
