# %%
import numpy as np
import pickle
import sys
import data_process_utils as dpu

# %%
def get_meal_code(meal):    
    code = -1
    if meal == "meal" or meal=="lunch" or meal=="dinner":
        code = 1
    elif meal=="snack":
        code = 2    
    elif meal=="drink":
        code = 3
    return code;

def process_meal_annots_steven(annots, data, subject_code, session):
    meal_count = len(annots)
    sample_count = len(data)
    if subject_code == 5 and session == 0:
        meal_count = 9
    elif subject_code == 6 and session == 0:
        meal_count = 2
    elif subject_code == 102 and session == 1:
        meal_count = 1
    elif subject_code == 104 and session == 0:
        meal_count = 7
    
    j = 0
    a = np.zeros((meal_count, 3))
    for i in range(meal_count):        
        s = annots[i].split(",")
        t1 = float(s[1].rstrip())
        t2 = float(s[2].rstrip())
        
        if t1>data[-1,0]:
            print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxx')            
            print('Error Meal start time is greater than data end time')
            print('xxxxxxxxxxxxxxxxxxxxxxxxxxxxx')
            sys.exit(0)
            
        if t2>data[-1,0]:            
            print('.................................')            
            print('Adjusted Meal end time is greater than data end time: ', data[-1, 0], t2)
            print('..................................')
            t2 = data[-1,0]
            
            #subject_code == 107 and session == 0 or subject_code == 107 and session == 2:
            
        a[i, 0] = t1
        a[i, 1] = t2
        a[i, 2] = get_meal_code(s[3].rstrip().strip())        
        if a[i, 2]==-1:
            print(" \n\n******************* Meal code problem *************** code is -1\n\n")
            
    return a

# %%
path = 'C:/ASM/PublicData/eating_steventech/free'
sampling_rate = 16 #Hz
data_all = []

subject_codes = [2, 3, 4, 5, 6, 101, 102, 103, 104, 107, 109]
for subject in range(len(subject_codes)):
    dsubject = [];
    sess_count = 2
    if subject_codes[subject] == 107:
        sess_count = 5

    for sess in range(sess_count):
        print('\nSubject, code, Sess: ', subject, subject_codes[subject], sess)
        
        if subject_codes[subject] < 10:
            filePathAccel = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv";
            filePathAnnots = path + "/0" + str(subject_codes[subject]) + "/000" + str(sess) + "/meal_events.csv";
        elif subject_codes[subject] == 109:
            filePathAccel = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/watch_right_000" + str(sess+3) + ".csv";
            filePathAnnots = path + "/" + str(subject_codes[subject]) + "/000" + str(sess+3) + "/meal_events.csv";
        else:
            filePathAccel = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/watch_right_000" + str(sess) + ".csv";
            filePathAnnots = path + "/" + str(subject_codes[subject]) + "/000" + str(sess) + "/meal_events.csv";

        data = np.genfromtxt(filePathAccel, delimiter=',')
        t = data[:, 0]/1e9
        t = t.reshape((-1, 1))
        accel_gyro = data[:, 1:7]
        quat = data[:, -3:]
        _ , _ , grav = dpu.quat2mat(quat)

        data = np.concatenate((t, grav, accel_gyro), axis=1)
        data = dpu.resample(data, sampling_rate)

        with open(filePathAnnots) as file:            
            annots = file.readlines()
        annots = process_meal_annots_steven(annots, data, subject_codes[subject], sess)        
        annots[:, 0] = dpu.time_to_index(data, annots[:, 0])
        annots[:, 1] = dpu.time_to_index(data, annots[:, 1])
        
        dsess = {}
        dsess['data'] = data
        dsess['annots'] = annots.astype(int)
        dsess['subject_code'] = subject_codes[subject]
        dsubject.append(dsess)        

    data_all.append(dsubject)
# Out:
# Subject, code, Sess:  0 2 0
# Resampling... Rate: 16
# Old start, end: 0.0, 40424.529486105
# New start, end: 0.0, 40424.529486105
# Sample Count old, new: 725551, 646793
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 40424.5
# TS start, end: 805.56, 18411.6029796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 40424.5
# TS start, end: 1176.95, 20145.4349796
# Time to index Done.
#
# Subject, code, Sess:  0 2 1
# Resampling... Rate: 16
# Old start, end: 0.0, 38185.645249663
# New start, end: 0.0, 38185.645249663
# Sample Count old, new: 550555, 610971
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 38185.625
# TS start, end: 2090.589, 29940.7629592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 38185.625
# TS start, end: 2773.678, 29993.6359592
# Time to index Done.
#
# Subject, code, Sess:  1 3 0
# Resampling... Rate: 16
# Old start, end: 0.0, 36606.720713365
# New start, end: 0.0, 36606.720713365
# Sample Count old, new: 560364, 585708
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 36606.6875
# TS start, end: 389.236, 32810.7309592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 36606.6875
# TS start, end: 1321.362, 32903.1129592
# Time to index Done.
#
# Subject, code, Sess:  1 3 1
# Resampling... Rate: 16
# Old start, end: 0.0, 37048.309772182
# New start, end: 0.0, 37048.309772182
# Sample Count old, new: 621551, 592773
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 37048.25
# TS start, end: 109.289, 27138.9949592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 37048.25
# TS start, end: 818.569, 28106.6769592
# Time to index Done.
#
# Subject, code, Sess:  2 4 0
# Resampling... Rate: 16
# Old start, end: 0.0, 43250.163293218
# New start, end: 0.0, 43250.163293218
# Sample Count old, new: 684553, 692003
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 43250.125
# TS start, end: 6084.662, 33191.4819592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 43250.125
# TS start, end: 6121.057, 33582.6189592
# Time to index Done.
#
# Subject, code, Sess:  2 4 1
# Resampling... Rate: 16
# Old start, end: 0.0, 42140.966948984
# New start, end: 0.0, 42140.966948984
# Sample Count old, new: 684200, 674256
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 42140.9375
# TS start, end: 920.704, 37901.1859388
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 42140.9375
# TS start, end: 2045.701, 38667.5409388
# Time to index Done.
#
# Subject, code, Sess:  3 5 0
# Resampling... Rate: 16
# Old start, end: 0.0, 25196.418970225
# New start, end: 0.0, 25196.418970225
# Sample Count old, new: 390566, 403143
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 25196.375
# TS start, end: 1680.768, 22968.6249796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 25196.375
# TS start, end: 2967.247, 23124.5409796
# Time to index Done.
#
# Subject, code, Sess:  3 5 1
# Resampling... Rate: 16
# Old start, end: 0.0, 28720.781611331
# New start, end: 0.0, 28720.781611331
# Sample Count old, new: 479233, 459533
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 28720.75
# TS start, end: 2659.525, 14093.3229796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 28720.75
# TS start, end: 3547.468, 14384.2829796
# Time to index Done.
#
# Subject, code, Sess:  4 6 0
# Resampling... Rate: 16
# Old start, end: 0.0, 30691.535907704
# New start, end: 0.0, 30691.535907704
# Sample Count old, new: 570537, 491065
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 30691.5
# TS start, end: 12586.2669796, 14414.9899796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 30691.5
# TS start, end: 12914.5279796, 14472.9049796
# Time to index Done.
#
# Subject, code, Sess:  4 6 1
# Resampling... Rate: 16
# Old start, end: 0.0, 39290.324946087
# New start, end: 0.0, 39290.324946087
# Sample Count old, new: 682979, 628646
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 39290.3125
# TS start, end: 10067.674, 30834.9509592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 39290.3125
# TS start, end: 10654.339, 33222.6719592
# Time to index Done.
#
# Subject, code, Sess:  5 101 0
# Resampling... Rate: 16
# Old start, end: 0.0, 15565.4621878
# New start, end: 0.0, 15565.4621878
# Sample Count old, new: 222602, 249048
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 15565.4375
# TS start, end: 590.487, 14311.6379796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 15565.4375
# TS start, end: 1224.062, 15453.9899796
# Time to index Done.
#
# Subject, code, Sess:  5 101 1
# Resampling... Rate: 16
# Old start, end: 0.0, 31624.754389144
# New start, end: 0.0, 31624.754389144
# Sample Count old, new: 452168, 505997
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 31624.75
# TS start, end: 3944.666, 27402.5689592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 31624.75
# TS start, end: 5494.35197959, 28333.0129592
# Time to index Done.
#
# Subject, code, Sess:  6 102 0
# Resampling... Rate: 16
# Old start, end: 0.0, 37010.948657578
# New start, end: 0.0, 37010.948657578
# Sample Count old, new: 529330, 592176
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 37010.9375
# TS start, end: 7017.427, 32695.5719592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 37010.9375
# TS start, end: 7174.731, 33798.7019592
# Time to index Done.
#
# Subject, code, Sess:  6 102 1
# Resampling... Rate: 16
# Old start, end: 0.0, 27208.887866286
# New start, end: 0.0, 27208.887866286
# Sample Count old, new: 389150, 435343
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 27208.875
# TS start, end: 5781.443, 5781.443
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 27208.875
# TS start, end: 6802.099, 6802.099
# Time to index Done.
#
# Subject, code, Sess:  7 103 0
# Resampling... Rate: 16
# Old start, end: 0.0, 20557.79868422
# New start, end: 0.0, 20557.79868422
# Sample Count old, new: 293996, 328925
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 20557.75
# TS start, end: 9858.148, 17089.9199796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 20557.75
# TS start, end: 11303.672, 17204.2429796
# Time to index Done.
#
# Subject, code, Sess:  7 103 1
# Resampling... Rate: 16
# Old start, end: 0.0, 49933.128138474
# New start, end: 0.0, 49933.128138474
# Sample Count old, new: 713817, 798931
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 49933.125
# TS start, end: 24595.6159592, 47568.3709388
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 49933.125
# TS start, end: 24899.1309592, 48408.7579184
# Time to index Done.
#
# Subject, code, Sess:  8 104 0
# Resampling... Rate: 16
# Old start, end: 0.0, 38377.338769308
# New start, end: 0.0, 38377.338769308
# Sample Count old, new: 548972, 614038
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 38377.3125
# TS start, end: 5753.085, 28070.0069592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 38377.3125
# TS start, end: 5982.925, 28601.5319592
# Time to index Done.
#
# Subject, code, Sess:  8 104 1
# Resampling... Rate: 16
# Old start, end: 0.0, 40106.189417588
# New start, end: 0.0, 40106.189417588
# Sample Count old, new: 573211, 641700
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 40106.1875
# TS start, end: 9137.877, 33923.3549592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 40106.1875
# TS start, end: 10209.995, 34442.8619592
# Time to index Done.
#
# Subject, code, Sess:  9 107 0
# Resampling... Rate: 16
# Old start, end: 0.0, 33252.021267668
# New start, end: 0.0, 33252.021267668
# Sample Count old, new: 475539, 532033
# Resampling Done
# .................................
# Adjusted Meal end time is greater than data end time:  33252.0 34783.3769592
# ..................................
# Time to index ...
# Data start, end: 0.0, 33252.0
# TS start, end: 12124.3269796, 33050.9309592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 33252.0
# TS start, end: 13300.5299796, 33252.0
# Time to index Done.
#
# Subject, code, Sess:  9 107 1
# Resampling... Rate: 16
# Old start, end: 0.0, 34196.310475865
# New start, end: 0.0, 34196.310475865
# Sample Count old, new: 488825, 547141
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 34196.25
# TS start, end: 9655.149, 32546.0789592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 34196.25
# TS start, end: 10054.891, 33632.4309592
# Time to index Done.
#
# Subject, code, Sess:  9 107 2
# Resampling... Rate: 16
# Old start, end: 0.0, 34244.07989093
# New start, end: 0.0, 34244.07989093
# Sample Count old, new: 489752, 547906
# Resampling Done
# .................................
# Adjusted Meal end time is greater than data end time:  34244.0625 34317.1959592
# ..................................
# Time to index ...
# Data start, end: 0.0, 34244.0625
# TS start, end: 21028.9329796, 33756.3479592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 34244.0625
# TS start, end: 23106.2789796, 34244.0625
# Time to index Done.
#
# Subject, code, Sess:  9 107 3
# Resampling... Rate: 16
# Old start, end: 0.0, 35921.861299408
# New start, end: 0.0, 35921.861299408
# Sample Count old, new: 513536, 574750
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 35921.8125
# TS start, end: 12130.5409796, 23388.1749796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 35921.8125
# TS start, end: 13306.5479796, 24115.5589796
# Time to index Done.
#
# Subject, code, Sess:  9 107 4
# Resampling... Rate: 16
# Old start, end: 0.0, 25377.810702188
# New start, end: 0.0, 25377.810702188
# Sample Count old, new: 363067, 406045
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 25377.75
# TS start, end: 23857.3019796, 23857.3019796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 25377.75
# TS start, end: 24917.2629592, 24917.2629592
# Time to index Done.
#
# Subject, code, Sess:  10 109 0
# Resampling... Rate: 16
# Old start, end: 0.0, 34720.474778052
# New start, end: 0.0, 34720.474778052
# Sample Count old, new: 496343, 555528
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 34720.4375
# TS start, end: 5444.241, 32774.1309592
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 34720.4375
# TS start, end: 6196.26, 34545.2099592
# Time to index Done.
#
# Subject, code, Sess:  10 109 1
# Resampling... Rate: 16
# Old start, end: 0.0, 41818.580803762
# New start, end: 0.0, 41818.580803762
# Sample Count old, new: 597646, 669098
# Resampling Done
# Time to index ...
# Data start, end: 0.0, 41818.5625
# TS start, end: 10227.114, 22154.8439796
# Time to index Done.
# Time to index ...
# Data start, end: 0.0, 41818.5625
# TS start, end: 11213.858, 23848.8299796
# Time to index Done.

# %%
with open('C:/ASM/DevData/eating/data/steven_free_data.pkl', 'wb') as file:
    pickle.dump(data_all, file)
