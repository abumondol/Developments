# %%
import numpy as np
import pickle
import os
import sys
import importlib

# %%
util_path = 'C:/ASM/Dropbox/Developments/Jupyter/Eating/myutils' if 'C:' in os.getcwd() else './myutils'
sys.path.append(util_path)
import my_file_utils as mfileu
import my_data_process_utils as mdpu

# %%
ds = mfileu.read_file("data", "free_data_steven_right.pkl")
annots = mfileu.read_file("data", "free_data_steven_annots.pkl")

# %%
print(annots[0][0].shape)
# Out:
# (3, 3)

# %%
meal_type_count =[0, 0, 0, 0, 0]
whole_out =[0, 0, 0, 0, 0]
partial_out =[0, 0, 0, 0, 0]
durations = [0, 0, 0, 0, 0]
total_data_duration = 0

for subj in range(len(ds)):
    for sess in range(len(ds[subj])):
        print("\nSubj, sess: ", subj, sess)
        d = ds[subj][sess]
        a = annots[subj][sess]
        print("Shapes: ", d.shape, a.shape)
        
        dt = int(len(d)/16)
        total_data_duration+=dt
        print("Data Length: ", dt)
        print("Meals (Start time, End time, Type): total ",len(a))
        
        for i in range(len(a)):
            st, et, meal_type = int(a[i,0]/16), int(a[i,1]/16), int(a[i, 2])
            meal_type_count[meal_type] += 1
            print("  ", st, et, meal_type, " : ", et-st+1)
            
            if st>dt:
                print("       ********* Whole out xxxxxxxxxxxx")
                whole_out[meal_type]+=1
            elif et>dt:
                print("       xxxxxxxxxxxx Partial out xxxxxxxxx")
                partial_out[meal_type]+=1
                durations[meal_type]+=(dt-st+1)
            else:
                durations[meal_type]+=(et-st+1)
# Out:
# Subj, sess:  0 0
# Shapes:  (646793, 13) (3, 3)
# Data Length:  40424
# Meals (Start time, End time, Type): total  3
#    805 1176 1  :  372
#    4826 4885 3  :  60
#    18411 20145 1  :  1735
#
# Subj, sess:  0 1
# Shapes:  (610971, 13) (5, 3)
# Data Length:  38185
# Meals (Start time, End time, Type): total  5
#    2090 2773 1  :  684
#    8287 8332 3  :  46
#    19435 20122 1  :  688
#    24973 25037 3  :  65
#    29940 29993 3  :  54
#
# Subj, sess:  1 0
# Shapes:  (585708, 13) (5, 3)
# Data Length:  36606
# Meals (Start time, End time, Type): total  5
#    389 1321 1  :  933
#    10003 11776 1  :  1774
#    24482 26590 1  :  2109
#    27823 27834 2  :  12
#    32810 32903 2  :  94
#
# Subj, sess:  1 1
# Shapes:  (592773, 13) (7, 3)
# Data Length:  37048
# Meals (Start time, End time, Type): total  7
#    109 818 1  :  710
#    6558 10127 3  :  3570
#    11641 12940 1  :  1300
#    19085 19491 2  :  407
#    20428 20760 2  :  333
#    22071 22121 2  :  51
#    27138 28106 1  :  969
#
# Subj, sess:  2 0
# Shapes:  (692003, 13) (6, 3)
# Data Length:  43250
# Meals (Start time, End time, Type): total  6
#    6084 6121 3  :  38
#    11899 12484 1  :  586
#    12767 13713 1  :  947
#    26704 26740 3  :  37
#    31828 33004 1  :  1177
#    33191 33582 2  :  392
#
# Subj, sess:  2 1
# Shapes:  (674256, 13) (8, 3)
# Data Length:  42141
# Meals (Start time, End time, Type): total  8
#    920 2045 1  :  1126
#    5275 5449 3  :  175
#    14184 14225 3  :  42
#    19899 21329 1  :  1431
#    22377 22638 3  :  262
#    26002 26012 3  :  11
#    29116 29127 3  :  12
#    37901 38667 1  :  767
#
# Subj, sess:  3 0
# Shapes:  (403143, 13) (11, 3)
# Data Length:  25196
# Meals (Start time, End time, Type): total  11
#    1680 2967 1  :  1288
#    4864 5288 3  :  425
#    6315 6327 3  :  13
#    6399 6685 2  :  287
#    15494 15511 3  :  18
#    20175 20188 3  :  14
#    22014 22272 1  :  259
#    22362 22875 1  :  514
#    22968 23124 1  :  157
#    27602 27617 3  :  16
#        ********* Whole out xxxxxxxxxxxx
#    27762 28260 4  :  499
#        ********* Whole out xxxxxxxxxxxx
#
# Subj, sess:  3 1
# Shapes:  (459533, 13) (6, 3)
# Data Length:  28720
# Meals (Start time, End time, Type): total  6
#    2659 3547 1  :  889
#    3663 3841 2  :  179
#    4419 4427 3  :  9
#    9151 9164 3  :  14
#    13725 13939 2  :  215
#    14093 14384 2  :  292
#
# Subj, sess:  4 0
# Shapes:  (491065, 13) (3, 3)
# Data Length:  30691
# Meals (Start time, End time, Type): total  3
#    12586 12914 1  :  329
#    14414 14472 3  :  59
#    31240 32425 1  :  1186
#        ********* Whole out xxxxxxxxxxxx
#
# Subj, sess:  4 1
# Shapes:  (628646, 13) (4, 3)
# Data Length:  39290
# Meals (Start time, End time, Type): total  4
#    10067 10654 1  :  588
#    25819 26678 2  :  860
#    26889 26948 2  :  60
#    30834 33222 1  :  2389
#
# Subj, sess:  5 0
# Shapes:  (249048, 13) (3, 3)
# Data Length:  15565
# Meals (Start time, End time, Type): total  3
#    590 1224 3  :  635
#    11504 12153 1  :  650
#    14311 15453 1  :  1143
#
# Subj, sess:  5 1
# Shapes:  (505997, 13) (4, 3)
# Data Length:  31624
# Meals (Start time, End time, Type): total  4
#    3944 5494 1  :  1551
#    15113 15219 2  :  107
#    23306 26585 1  :  3280
#    27402 28333 2  :  932
#
# Subj, sess:  6 0
# Shapes:  (592176, 13) (4, 3)
# Data Length:  37011
# Meals (Start time, End time, Type): total  4
#    7017 7174 1  :  158
#    7520 8526 1  :  1007
#    30042 30186 1  :  145
#    32695 33798 1  :  1104
#
# Subj, sess:  6 1
# Shapes:  (435343, 13) (2, 3)
# Data Length:  27208
# Meals (Start time, End time, Type): total  2
#    5781 6802 1  :  1022
#    27292 27939 1  :  648
#        ********* Whole out xxxxxxxxxxxx
#
# Subj, sess:  7 0
# Shapes:  (328925, 13) (2, 3)
# Data Length:  20557
# Meals (Start time, End time, Type): total  2
#    9858 11303 2  :  1446
#    17089 17204 3  :  116
#
# Subj, sess:  7 1
# Shapes:  (798931, 13) (3, 3)
# Data Length:  49933
# Meals (Start time, End time, Type): total  3
#    24595 24899 1  :  305
#    39712 39822 2  :  111
#    47568 48408 2  :  841
#
# Subj, sess:  8 0
# Shapes:  (614038, 13) (8, 3)
# Data Length:  38377
# Meals (Start time, End time, Type): total  8
#    5753 5982 2  :  230
#    6193 8689 3  :  2497
#    10419 14203 3  :  3785
#    14513 15766 1  :  1254
#    19553 19751 2  :  199
#    25552 25844 2  :  293
#    28070 28601 2  :  532
#    38991 41674 1  :  2684
#        ********* Whole out xxxxxxxxxxxx
#
# Subj, sess:  8 1
# Shapes:  (641700, 13) (4, 3)
# Data Length:  40106
# Meals (Start time, End time, Type): total  4
#    9137 10209 1  :  1073
#    10948 11092 2  :  145
#    25492 27098 1  :  1607
#    33923 34442 2  :  520
#
# Subj, sess:  9 0
# Shapes:  (532033, 13) (4, 3)
# Data Length:  33252
# Meals (Start time, End time, Type): total  4
#    12124 13300 1  :  1177
#    19606 19754 2  :  149
#    24493 24799 2  :  307
#    33050 34783 1  :  1734
#        xxxxxxxxxxxx Partial out xxxxxxxxx
#
# Subj, sess:  9 1
# Shapes:  (547141, 13) (3, 3)
# Data Length:  34196
# Meals (Start time, End time, Type): total  3
#    9655 10054 1  :  400
#    16770 17219 2  :  450
#    32546 33632 1  :  1087
#
# Subj, sess:  9 2
# Shapes:  (547906, 13) (4, 3)
# Data Length:  34244
# Meals (Start time, End time, Type): total  4
#    21028 23106 1  :  2079
#    28543 28729 2  :  187
#    31523 31743 1  :  221
#    33756 34317 1  :  562
#        xxxxxxxxxxxx Partial out xxxxxxxxx
#
# Subj, sess:  9 3
# Shapes:  (574750, 13) (3, 3)
# Data Length:  35921
# Meals (Start time, End time, Type): total  3
#    12130 13306 1  :  1177
#    15528 15875 2  :  348
#    23388 24115 2  :  728
#
# Subj, sess:  9 4
# Shapes:  (406045, 13) (1, 3)
# Data Length:  25377
# Meals (Start time, End time, Type): total  1
#    23857 24917 1  :  1061
#
# Subj, sess:  10 0
# Shapes:  (555528, 13) (4, 3)
# Data Length:  34720
# Meals (Start time, End time, Type): total  4
#    5444 6196 1  :  753
#    11552 11865 2  :  314
#    23050 23737 2  :  688
#    32774 34545 1  :  1772
#
# Subj, sess:  10 1
# Shapes:  (669098, 13) (3, 3)
# Data Length:  41818
# Meals (Start time, End time, Type): total  3
#    10227 11213 2  :  987
#    15795 16801 1  :  1007
#    22154 23848 2  :  1695

# %%
print(meal_type_count, " : ", sum(meal_type_count))
print(whole_out, " : ", sum(whole_out))
print(partial_out, " : ", sum(partial_out))
print(total_data_duration, total_data_duration-)
print(durations, " : ", durations[0]+durations[1])
# Out:
# [0, 52, 33, 24, 1]  :  110
# [0, 3, 0, 1, 1]  :  5
# [0, 2, 0, 0, 0]  :  2
# 861460
# [0, 49446, 14391, 11957, 0]  :  49446
