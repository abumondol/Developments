# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import data_process_utils as dpu
# %matplotlib inline

# %%
def process_annots(annots, min_bite_distance):    
    count = len(annots)
    
    for i in range(count):
        if 1 <= annots[i, 1] < 400:
            annots[i, 1] = 1
        elif 400 <= annots[i, 1] < 1000:
            annots[i, 1] = 2
        else:
            annots[i, 1] = 0
    
    annots = annots[annots[:, 1]>0, :]
    count = len(annots)
    flags = np.ones((count, ))
    
    for i in range(1, count):
        if annots[i, 0] - annots[i-1, 0]<=min_bite_distance:
            flags[i-1] = 0
            
    annots = annots[flags==1, :]    
    return annots

# %%
with open('C:/ASM/DevData/eating/datasets/our_lab_dataset.pkl', 'rb') as file:
    data = pickle.load(file)
print("Total subjects: ", len(data))

sampling_rate = 16
min_bite_distance = 1
for subject in range(len(data)):
    for sess in range(len(data[subject])):
        print('\nSubject, Sess >> ', subject, sess)
        d = data[subject][sess]['data']
        a = data[subject][sess]['annots']
        a = process_annots(a, min_bite_distance)
        
        accel = d[d[:, 1]==1, :]
        gyro = d[d[:, 1]==4, :]
        grav = d[d[:, 1]==9, :]        
        
        start_time = max([accel[0,0], gyro[0,0], grav[0,0]])
        end_time = min([accel[-1,0], gyro[-1,0], grav[-1,0]])
        
        accel = dpu.resample(accel, sampling_rate, [start_time, end_time])
        gyro = dpu.resample(gyro, sampling_rate, [start_time, end_time])
        grav = dpu.resample(grav, sampling_rate, [start_time, end_time])
        grav = grav[:, 2:]        
        mag = np.sqrt(np.sum(grav*grav, axis=1, keepdims=True))
        mag = np.concatenate((mag, mag, mag), axis=1)        
        grav = grav/mag
        
        
        t = accel[:, 0].reshape((-1, 1))
        offset = t[0, 0]        
        t = t-offset  # starting from time 0
        print('Offset: ', offset)
        
        d = np.concatenate((t, grav, accel[:, 2:], gyro[:, 2:]), axis =1)
        
        a[:, 0] = a[:, 0] - offset  #offset the annots also
        
        if a[0,0]<=0:
            a = a[a[:,0]>0, :]
            print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
            print("First bite negative ", a[0,0])
            print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
        
        if a[0,0]<10:
            print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
            print("First bite with in 10 second ", a[0,0])
            print("xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
        
        a[:, 0] = dpu.time_to_index(d, a[:, 0])        
        
        data[subject][sess]['data'] = d
        data[subject][sess]['annots'] = a.astype(int)
# Out:
# Total subjects:  21
#
# Subject, Sess >>  0 0
# Resampling... Rate: 16
# Old start, end: -0.032239871, 2519.98513794
# New start, end: 0.309830401, 2519.98513794
# Sample Count old, new: 151896, 40315
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2519.995880127
# New start, end: 0.309830401, 2519.98513794
# Sample Count old, new: 494359, 40315
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.309830401, 2519.98513794
# New start, end: 0.309830401, 2519.98513794
# Sample Count old, new: 151875, 40315
# Resampling Done
# Offset:  0.309830401
# Time to index ...
# Data start, end: 0.0, 2519.625
# TS start, end: 102.89016959900002, 2070.690169599
# Time to index Done.
#
# Subject, Sess >>  1 0
# Resampling... Rate: 16
# Old start, end: 0.0, 2107.514415376
# New start, end: 0.379174912, 2107.514415376
# Sample Count old, new: 127874, 33715
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.067088716, 2107.524638765
# New start, end: 0.379174912, 2107.514415376
# Sample Count old, new: 406856, 33715
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.379174912, 2107.514415376
# New start, end: 0.379174912, 2107.514415376
# Sample Count old, new: 127851, 33715
# Resampling Done
# Offset:  0.379174912
# Time to index ...
# Data start, end: 0.0, 2107.125
# TS start, end: 131.320825088, 2053.220825088
# Time to index Done.
#
# Subject, Sess >>  2 0
# Resampling... Rate: 16
# Old start, end: 0.0, 2190.183753272
# New start, end: 0.434813952, 2190.183753272
# Sample Count old, new: 136694, 35036
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.065650245, 2190.199347755
# New start, end: 0.434813952, 2190.183753272
# Sample Count old, new: 409535, 35036
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.434813952, 2190.199347755
# New start, end: 0.434813952, 2190.183753272
# Sample Count old, new: 136667, 35036
# Resampling Done
# Offset:  0.434813952
# Time to index ...
# Data start, end: 0.0, 2189.6875
# TS start, end: 135.26518604799998, 2055.965186048
# Time to index Done.
#
# Subject, Sess >>  3 0
# Resampling... Rate: 16
# Old start, end: 0.0475595, 2111.377838135
# New start, end: 0.369168204, 2111.377838135
# Sample Count old, new: 129059, 33777
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2111.377838135
# New start, end: 0.369168204, 2111.377838135
# Sample Count old, new: 415319, 33777
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.369168204, 2111.377838135
# New start, end: 0.369168204, 2111.377838135
# Sample Count old, new: 129038, 33777
# Resampling Done
# Offset:  0.369168204
# Time to index ...
# Data start, end: 0.0, 2111.0
# TS start, end: 57.330831796, 1836.030831796
# Time to index Done.
#
# Subject, Sess >>  4 0
# Resampling... Rate: 16
# Old start, end: 0.0, 2002.710298587
# New start, end: 0.362267648, 2002.710298587
# Sample Count old, new: 122886, 32038
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.075838138, 2002.719850589
# New start, end: 0.362267648, 2002.710298587
# Sample Count old, new: 387879, 32038
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.362267648, 2002.710298587
# New start, end: 0.362267648, 2002.710298587
# Sample Count old, new: 122863, 32038
# Resampling Done
# Offset:  0.362267648
# Time to index ...
# Data start, end: 0.0, 2002.3125
# TS start, end: 79.137732352, 1919.137732352
# Time to index Done.
#
# Subject, Sess >>  5 0
# Resampling... Rate: 16
# Old start, end: 0.0, 2024.745606994
# New start, end: 0.36531712, 2024.745606994
# Sample Count old, new: 124080, 32391
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.051820372, 2024.750337218
# New start, end: 0.36531712, 2024.745606994
# Sample Count old, new: 393976, 32391
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.36531712, 2024.745606994
# New start, end: 0.36531712, 2024.745606994
# Sample Count old, new: 124057, 32391
# Resampling Done
# Offset:  0.36531712
# Time to index ...
# Data start, end: 0.0, 2024.375
# TS start, end: 52.434682880000004, 1784.03468288
# Time to index Done.
#
# Subject, Sess >>  6 0
# Resampling... Rate: 16
# Old start, end: -0.07478902, 2342.775207519
# New start, end: 0.281851748, 2342.775207519
# Sample Count old, new: 145624, 37480
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2342.775207519
# New start, end: 0.281851748, 2342.775207519
# Sample Count old, new: 432869, 37480
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.281851748, 2342.775207519
# New start, end: 0.281851748, 2342.775207519
# Sample Count old, new: 145602, 37480
# Resampling Done
# Offset:  0.281851748
# Time to index ...
# Data start, end: 0.0, 2342.4375
# TS start, end: 144.91814825199998, 1740.418148252
# Time to index Done.
#
# Subject, Sess >>  7 0
# Resampling... Rate: 16
# Old start, end: -0.00888878, 2124.77230835
# New start, end: 0.3296917, 2124.77230835
# Sample Count old, new: 130862, 33992
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2124.782348633
# New start, end: 0.3296917, 2124.77230835
# Sample Count old, new: 407835, 33992
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.3296917, 2124.77230835
# New start, end: 0.3296917, 2124.77230835
# Sample Count old, new: 130841, 33992
# Resampling Done
# Offset:  0.3296917
# Time to index ...
# Data start, end: 0.0, 2124.4375
# TS start, end: 133.27030829999998, 1393.5703082999999
# Time to index Done.
#
# Subject, Sess >>  8 0
# Resampling... Rate: 16
# Old start, end: 0.040360027, 2039.087280274
# New start, end: 0.372237403, 2039.087280274
# Sample Count old, new: 126316, 32620
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2039.096679688
# New start, end: 0.372237403, 2039.087280274
# Sample Count old, new: 398197, 32620
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.372237403, 2039.087280274
# New start, end: 0.372237403, 2039.087280274
# Sample Count old, new: 126295, 32620
# Resampling Done
# Offset:  0.372237403
# Time to index ...
# Data start, end: 0.0, 2038.6875
# TS start, end: 73.627762597, 1992.627762597
# Time to index Done.
#
# Subject, Sess >>  9 0
# Resampling... Rate: 16
# Old start, end: 0.044637921, 2268.501373291
# New start, end: 3.919942385, 2268.501373291
# Sample Count old, new: 138318, 36234
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2268.501373291
# New start, end: 3.919942385, 2268.501373291
# Sample Count old, new: 439823, 36234
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 3.919942385, 2268.501373291
# New start, end: 3.919942385, 2268.501373291
# Sample Count old, new: 138075, 36234
# Resampling Done
# Offset:  3.919942385
# Time to index ...
# Data start, end: 0.0, 2264.5625
# TS start, end: 141.580057615, 2063.2800576150003
# Time to index Done.
#
# Subject, Sess >>  10 0
# Resampling... Rate: 16
# Old start, end: 0.0, 1974.623026859
# New start, end: 0.393684263, 1974.623026859
# Sample Count old, new: 121466, 31588
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.084269535, 1974.636851322
# New start, end: 0.393684263, 1974.623026859
# Sample Count old, new: 372340, 31588
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.393684263, 1974.623026859
# New start, end: 0.393684263, 1974.623026859
# Sample Count old, new: 121442, 31588
# Resampling Done
# Offset:  0.393684263
# Time to index ...
# Data start, end: 0.0, 1974.1875
# TS start, end: 56.80631573699999, 1094.9063157369999
# Time to index Done.
#
# Subject, Sess >>  11 0
# Resampling... Rate: 16
# Old start, end: 0.040770208, 2093.202209473
# New start, end: 0.284760736, 2093.202209473
# Sample Count old, new: 127114, 33487
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2093.206970215
# New start, end: 0.284760736, 2093.202209473
# Sample Count old, new: 402718, 33487
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.284760736, 2093.202209473
# New start, end: 0.284760736, 2093.202209473
# Sample Count old, new: 127099, 33487
# Resampling Done
# Offset:  0.284760736
# Time to index ...
# Data start, end: 0.0, 2092.875
# TS start, end: 209.91523926399998, 1994.915239264
# Time to index Done.
#
# Subject, Sess >>  12 0
# Resampling... Rate: 16
# Old start, end: 0.0, 2080.66710848
# New start, end: 0.453706752, 2080.66710848
# Sample Count old, new: 127772, 33284
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.082208578, 2080.677240316
# New start, end: 0.453706752, 2080.66710848
# Sample Count old, new: 405366, 33284
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.453706752, 2080.66710848
# New start, end: 0.453706752, 2080.66710848
# Sample Count old, new: 127744, 33284
# Resampling Done
# Offset:  0.453706752
# Time to index ...
# Data start, end: 0.0, 2080.1875
# TS start, end: 190.44629324800002, 1979.7462932480003
# Time to index Done.
#
# Subject, Sess >>  13 0
# Resampling... Rate: 16
# Old start, end: 0.045838637, 2143.732788086
# New start, end: 0.364720429, 2143.732788086
# Sample Count old, new: 132867, 34294
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2143.742767334
# New start, end: 0.364720429, 2143.732788086
# Sample Count old, new: 401804, 34294
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.364720429, 2143.732788086
# New start, end: 0.364720429, 2143.732788086
# Sample Count old, new: 132847, 34294
# Resampling Done
# Offset:  0.364720429
# Time to index ...
# Data start, end: 0.0, 2143.3125
# TS start, end: 226.93527957100002, 1978.9352795710001
# Time to index Done.
#
# Subject, Sess >>  14 0
# Resampling... Rate: 16
# Old start, end: 0.0, 986.705444336
# New start, end: 0.69897461, 986.705444336
# Sample Count old, new: 62924, 15777
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.008178711, 986.707763672
# New start, end: 0.69897461, 986.705444336
# Sample Count old, new: 98705, 15777
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.69897461, 986.705444336
# New start, end: 0.69897461, 986.705444336
# Sample Count old, new: 62880, 15777
# Resampling Done
# Offset:  0.69897461
# Time to index ...
# Data start, end: 0.0, 986.0
# TS start, end: 17.301025390000003, 910.7010253899999
# Time to index Done.
#
# Subject, Sess >>  14 1
# Resampling... Rate: 16
# Old start, end: 0.0, 494.644958496
# New start, end: 0.405517578, 494.644958496
# Sample Count old, new: 30977, 7908
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 494.66015625
# New start, end: 0.405517578, 494.644958496
# Sample Count old, new: 98647, 7908
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.405517578, 494.644958496
# New start, end: 0.405517578, 494.644958496
# Sample Count old, new: 30955, 7908
# Resampling Done
# Offset:  0.405517578
# Time to index ...
# Data start, end: 0.0, 494.1875
# TS start, end: 28.294482421999998, 402.794482422
# Time to index Done.
#
# Subject, Sess >>  15 0
# Resampling... Rate: 16
# Old start, end: 0.0, 1159.746276855
# New start, end: 0.703704834, 1159.746276855
# Sample Count old, new: 74027, 18545
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0050354, 1159.749084473
# New start, end: 0.703704834, 1159.746276855
# Sample Count old, new: 116005, 18545
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.703704834, 1159.746276855
# New start, end: 0.703704834, 1159.746276855
# Sample Count old, new: 73983, 18545
# Resampling Done
# Offset:  0.703704834
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# First bite with in 10 second  7.296295166
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Time to index ...
# Data start, end: 0.0, 1159.0
# TS start, end: 7.296295166, 753.3962951660001
# Time to index Done.
#
# Subject, Sess >>  15 1
# Resampling... Rate: 16
# Old start, end: 0.0, 750.451782227
# New start, end: 0.351257325, 750.451782227
# Sample Count old, new: 46850, 12002
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.027282715, 750.464630127
# New start, end: 0.351257325, 750.451782227
# Sample Count old, new: 149251, 12002
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.351257325, 750.451782227
# New start, end: 0.351257325, 750.451782227
# Sample Count old, new: 46828, 12002
# Resampling Done
# Offset:  0.351257325
# Time to index ...
# Data start, end: 0.0, 750.0625
# TS start, end: 28.248742675, 674.5487426750001
# Time to index Done.
#
# Subject, Sess >>  15 2
# Resampling... Rate: 16
# Old start, end: 0.0, 1093.573235446
# New start, end: 45.601186436, 1093.573235446
# Sample Count old, new: 65805, 16768
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.068047457, 1093.573235446
# New start, end: 45.601186436, 1093.573235446
# Sample Count old, new: 210773, 16768
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 45.601186436, 1093.573235446
# New start, end: 45.601186436, 1093.573235446
# Sample Count old, new: 62991, 16768
# Resampling Done
# Offset:  45.601186436
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# First bite negative  2.898813564000001
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# First bite with in 10 second  2.898813564000001
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Time to index ...
# Data start, end: 0.0, 1047.9375
# TS start, end: 2.898813564000001, 590.798813564
# Time to index Done.
#
# Subject, Sess >>  15 3
# Resampling... Rate: 16
# Old start, end: 0.027148574, 972.736142774
# New start, end: 0.363650334, 972.736142774
# Sample Count old, new: 60045, 15558
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 972.786926269
# New start, end: 0.363650334, 972.736142774
# Sample Count old, new: 175310, 15558
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.363650334, 972.736142774
# New start, end: 0.363650334, 972.736142774
# Sample Count old, new: 60024, 15558
# Resampling Done
# Offset:  0.363650334
# Time to index ...
# Data start, end: 0.0, 972.3125
# TS start, end: 17.136349665999997, 824.0363496660001
# Time to index Done.
#
# Subject, Sess >>  15 4
# Resampling... Rate: 16
# Old start, end: 0.0286868, 2979.682556152
# New start, end: 0.39103944, 2979.682556152
# Sample Count old, new: 183079, 47669
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 2979.686889648
# New start, end: 0.39103944, 2979.682556152
# Sample Count old, new: 571295, 47669
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.39103944, 2979.682556152
# New start, end: 0.39103944, 2979.682556152
# Sample Count old, new: 183056, 47669
# Resampling Done
# Offset:  0.39103944
# Time to index ...
# Data start, end: 0.0, 2979.25
# TS start, end: 30.10896056, 1570.90896056
# Time to index Done.
#
# Subject, Sess >>  16 0
# Resampling... Rate: 16
# Old start, end: 0.0, 762.752685547
# New start, end: 0.733489991, 762.752685547
# Sample Count old, new: 48684, 12193
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.012237549, 762.75958252
# New start, end: 0.733489991, 762.752685547
# Sample Count old, new: 76290, 12193
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.733489991, 762.752685547
# New start, end: 0.733489991, 762.752685547
# Sample Count old, new: 48642, 12193
# Resampling Done
# Offset:  0.733489991
# Time to index ...
# Data start, end: 0.0, 762.0
# TS start, end: 15.766510009, 731.0665100089999
# Time to index Done.
#
# Subject, Sess >>  16 1
# Resampling... Rate: 16
# Old start, end: 0.0, 481.343475342
# New start, end: 0.336578369, 481.343475342
# Sample Count old, new: 30010, 7697
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.012695312, 481.348968506
# New start, end: 0.336578369, 481.343475342
# Sample Count old, new: 95825, 7697
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.336578369, 481.343475342
# New start, end: 0.336578369, 481.343475342
# Sample Count old, new: 29990, 7697
# Resampling Done
# Offset:  0.336578369
# Time to index ...
# Data start, end: 0.0, 481.0
# TS start, end: 19.663421631, 354.863421631
# Time to index Done.
#
# Subject, Sess >>  17 0
# Resampling... Rate: 16
# Old start, end: 0.0, 819.911224365
# New start, end: 0.457061767, 819.911224365
# Sample Count old, new: 52129, 13112
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.05380249, 819.921722412
# New start, end: 0.457061767, 819.911224365
# Sample Count old, new: 163628, 13112
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.457061767, 819.911224365
# New start, end: 0.457061767, 819.911224365
# Sample Count old, new: 52106, 13112
# Resampling Done
# Offset:  0.457061767
# Time to index ...
# Data start, end: 0.0, 819.4375
# TS start, end: 16.342938232999998, 806.742938233
# Time to index Done.
#
# Subject, Sess >>  17 1
# Resampling... Rate: 16
# Old start, end: 0.0, 510.698242187
# New start, end: 0.423950195, 510.698242187
# Sample Count old, new: 31978, 8165
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 510.703674316
# New start, end: 0.423950195, 510.698242187
# Sample Count old, new: 101804, 8165
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.423950195, 510.698242187
# New start, end: 0.423950195, 510.698242187
# Sample Count old, new: 31956, 8165
# Resampling Done
# Offset:  0.423950195
# Time to index ...
# Data start, end: 0.0, 510.25
# TS start, end: 15.176049805000002, 477.276049805
# Time to index Done.
#
# Subject, Sess >>  18 0
# Resampling... Rate: 16
# Old start, end: 0.0, 908.363891602
# New start, end: 0.413146973, 908.363891602
# Sample Count old, new: 57799, 14528
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 908.367279053
# New start, end: 0.413146973, 908.363891602
# Sample Count old, new: 181292, 14528
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.413146973, 908.363891602
# New start, end: 0.413146973, 908.363891602
# Sample Count old, new: 57778, 14528
# Resampling Done
# Offset:  0.413146973
# Time to index ...
# Data start, end: 0.0, 907.9375
# TS start, end: 16.586853027, 866.586853027
# Time to index Done.
#
# Subject, Sess >>  18 1
# Resampling... Rate: 16
# Old start, end: 0.0, 449.822479248
# New start, end: 0.349792481, 449.822479248
# Sample Count old, new: 28099, 7192
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.026611328, 449.834411621
# New start, end: 0.349792481, 449.822479248
# Sample Count old, new: 89492, 7192
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.349792481, 449.822479248
# New start, end: 0.349792481, 449.822479248
# Sample Count old, new: 28077, 7192
# Resampling Done
# Offset:  0.349792481
# Time to index ...
# Data start, end: 0.0, 449.4375
# TS start, end: 28.950207518999996, 421.650207519
# Time to index Done.
#
# Subject, Sess >>  18 2
# Resampling... Rate: 16
# Old start, end: -0.004387131, 280.166228979
# New start, end: 0.314532549, 280.166228979
# Sample Count old, new: 17588, 4478
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 280.183959961
# New start, end: 0.314532549, 280.166228979
# Sample Count old, new: 50069, 4478
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.314532549, 280.166228979
# New start, end: 0.314532549, 280.166228979
# Sample Count old, new: 17568, 4478
# Resampling Done
# Offset:  0.314532549
# Time to index ...
# Data start, end: 0.0, 279.8125
# TS start, end: 15.385467451, 260.485467451
# Time to index Done.
#
# Subject, Sess >>  18 3
# Resampling... Rate: 16
# Old start, end: 0.0, 562.965156314
# New start, end: 0.38616064, 562.965156314
# Sample Count old, new: 34811, 9002
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.052863833, 562.970130679
# New start, end: 0.38616064, 562.965156314
# Sample Count old, new: 102659, 9002
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.38616064, 562.965156314
# New start, end: 0.38616064, 562.965156314
# Sample Count old, new: 34787, 9002
# Resampling Done
# Offset:  0.38616064
# Time to index ...
# Data start, end: 0.0, 562.5625
# TS start, end: 31.51383936, 527.3138393600001
# Time to index Done.
#
# Subject, Sess >>  19 0
# Resampling... Rate: 16
# Old start, end: -0.03919033, 1114.887142274
# New start, end: 0.357593286, 1114.887142274
# Sample Count old, new: 71193, 17833
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 1114.948181152
# New start, end: 0.357593286, 1114.887142274
# Sample Count old, new: 197277, 17833
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.357593286, 1114.887142274
# New start, end: 0.357593286, 1114.887142274
# Sample Count old, new: 71167, 17833
# Resampling Done
# Offset:  0.357593286
# Time to index ...
# Data start, end: 0.0, 1114.5
# TS start, end: 12.242406714, 1054.742406714
# Time to index Done.
#
# Subject, Sess >>  19 1
# Resampling... Rate: 16
# Old start, end: 0.027356053, 567.9896813
# New start, end: 0.364452757, 567.9896813
# Sample Count old, new: 35036, 9083
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 568.02947998
# New start, end: 0.364452757, 567.9896813
# Sample Count old, new: 102478, 9083
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.364452757, 567.9896813
# New start, end: 0.364452757, 567.9896813
# Sample Count old, new: 35015, 9083
# Resampling Done
# Offset:  0.364452757
# Time to index ...
# Data start, end: 0.0, 567.625
# TS start, end: 17.135547242999998, 532.4355472430001
# Time to index Done.
#
# Subject, Sess >>  19 2
# Resampling... Rate: 16
# Old start, end: 0.0, 519.038743828
# New start, end: 0.365415424, 519.038743828
# Sample Count old, new: 32571, 8299
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.074820583, 519.0541907
# New start, end: 0.365415424, 519.038743828
# Sample Count old, new: 93951, 8299
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.365415424, 519.038743828
# New start, end: 0.365415424, 519.038743828
# Sample Count old, new: 32548, 8299
# Resampling Done
# Offset:  0.365415424
# Time to index ...
# Data start, end: 0.0, 518.625
# TS start, end: 38.234584576, 502.83458457600005
# Time to index Done.
#
# Subject, Sess >>  19 3
# Resampling... Rate: 16
# Old start, end: -0.003209701, 451.769283181
# New start, end: 0.319637019, 451.769283181
# Sample Count old, new: 28335, 7224
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 451.798492431
# New start, end: 0.319637019, 451.769283181
# Sample Count old, new: 80961, 7224
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.319637019, 451.769283181
# New start, end: 0.319637019, 451.769283181
# Sample Count old, new: 28315, 7224
# Resampling Done
# Offset:  0.319637019
# Time to index ...
# Data start, end: 0.0, 451.4375
# TS start, end: 58.180362980999995, 442.680362981
# Time to index Done.
#
# Subject, Sess >>  19 4
# Resampling... Rate: 16
# Old start, end: -0.087099713, 489.534512981
# New start, end: 0.278844095, 489.534512981
# Sample Count old, new: 31297, 7829
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 489.59399414
# New start, end: 0.278844095, 489.534512981
# Sample Count old, new: 83928, 7829
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.278844095, 489.534512981
# New start, end: 0.278844095, 489.534512981
# Sample Count old, new: 31274, 7829
# Resampling Done
# Offset:  0.278844095
# Time to index ...
# Data start, end: 0.0, 489.25
# TS start, end: 15.821155905000001, 468.12115590499997
# Time to index Done.
#
# Subject, Sess >>  20 0
# Resampling... Rate: 16
# Old start, end: 0.0, 599.494018555
# New start, end: 0.419952393, 599.494018555
# Sample Count old, new: 37507, 9586
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.0, 599.498901367
# New start, end: 0.419952393, 599.494018555
# Sample Count old, new: 119557, 9586
# Resampling Done
# Resampling... Rate: 16
# Old start, end: 0.419952393, 599.494018555
# New start, end: 0.419952393, 599.494018555
# Sample Count old, new: 37484, 9586
# Resampling Done
# Offset:  0.419952393
# Time to index ...
# Data start, end: 0.0, 599.0625
# TS start, end: 10.280047607, 572.780047607
# Time to index Done.

# %%
with open('C:/ASM/DevData/eating/data/uva_lab_data.pkl', 'wb') as file:
    pickle.dump(data, file)
